# %%
import numpy as np
import pandas as pd
num_retailers    = 1000
num_customers    = 2
treatment_effect = 0.01


# Create retailers, their order amount scalars, and the probability space.
retailer_ids = list(range(1, num_retailers + 1,1))
retailer_scalars = list(np.random.normal(loc = 1, scale = 0.05, size = num_retailers))
retailers = pd.DataFrame(list(zip(retailer_ids, retailer_scalars)), 
                         columns =['Retailer_ID', 'Retailer_Scalar']) 
delimiters = list(np.linspace(0.0, 1.0, num = num_retailers + 1))
retailers['a'] = delimiters[0:len(delimiters)-1]
retailers['b'] = delimiters[1:len(delimiters)]
print('Retailer data frame created.')

# Create customers, their mean order amount, whether or not they got the treatment, 
# and the number of orders placed.
customer_ids = list(range(1, num_customers + 1,1))
num_orders = [int(i*10) + 1 for i in list(np.random.exponential(scale = 1.0, size = num_customers))]
customers = pd.DataFrame(list(zip(customer_ids, num_orders)), columns =['Customer_ID', 'N_Orders']) 
customers['Mean_Order_Amt'] = list(np.random.normal(loc = 100, scale = 25, size = num_customers))
customers['Mean_Order_Amt'] = customers['Mean_Order_Amt'].apply(lambda x: round(x, 2))
treatment_probs = []
for i in list(range(0, len(customers), 1)):
    treatment_probs.append(np.random.uniform())
customers['Treatment_Prob'] = treatment_probs
customers['Treated'] = np.where(customers['Treatment_Prob'] <= 0.5, 1, 0)
customers['Treatment_Modifier'] = np.where(customers['Treatment_Prob'] <= 0.5, 1+treatment_effect, 1.0)
customers = customers[['Customer_ID', 'N_Orders', 'Mean_Order_Amt', 'Treated', 'Treatment_Modifier']]
print('Customer data frame created.')

# Explode the customers dataframe by number of orders the customer placed.
#     explodedDF = pd.DataFrame(columns = ['Customer_ID', 'N_Orders', 'Mean_Order_Amt'])
j = 0
master_customer_entry = []
for i in list(range(0, len(customers), 1)):
    counter = 1
    customer_entry = []
    while counter <= int(customers.loc[[i]]['N_Orders']):
        customer_entry.append(list(customers.loc[[i]].values)) 
        counter += 1
    master_customer_entry.append(customer_entry)    
    if i % 1000 == 0:
        j += 1
        print(str(j*1000) + ' customers allocated (expansion ' + \
              '{} complete).'.format(str((j*1000)/num_customers)))
newlist = [item for items in master_customer_entry for item in items]
newlist = [item for items in newlist for item in items]
explodedDF = pd.DataFrame(newlist)
explodedDF.columns = ['Customer_ID', 'Num_Orders', 'Mean_Order_Amt', 'Treated', 'Treatment_Modifier']
explodedDF = explodedDF[['Customer_ID', 'Mean_Order_Amt', 'Treated', 'Treatment_Modifier']]
explodedDF
# Out:
# Retailer data frame created.
# Customer data frame created.
# 1000 customers allocated (expansion 500.0 complete).
#    Customer_ID  Mean_Order_Amt  Treated  Treatment_Modifier
# 0          1.0          139.32      1.0                1.01
# 1          1.0          139.32      1.0                1.01
# 2          2.0          105.97      0.0                1.00
# 3          2.0          105.97      0.0                1.00
# 4          2.0          105.97      0.0                1.00
# 5          2.0          105.97      0.0                1.00
# 6          2.0          105.97      0.0                1.00
# 7          2.0          105.97      0.0                1.00

# %%
def create_sim_data(num_retailers, num_customers, treatment_effect, file_name):

    import numpy as np
    import pandas as pd

    # Create retailers, their order amount scalars, and the probability space.
    retailer_ids = list(range(1, num_retailers + 1,1))
    retailer_scalars = list(np.random.normal(loc = 1, scale = 0.05, size = num_retailers))
    retailers = pd.DataFrame(list(zip(retailer_ids, retailer_scalars)), 
                             columns =['Retailer_ID', 'Retailer_Scalar']) 
    delimiters = list(np.linspace(0.0, 1.0, num = num_retailers + 1))
    retailers['a'] = delimiters[0:len(delimiters)-1]
    retailers['b'] = delimiters[1:len(delimiters)]
    print('Retailer data frame created.')
    
    # Create customers, their mean order amount, whether or not they got the treatment, 
    # and the number of orders placed.
    customer_ids = list(range(1, num_customers + 1,1))
    num_orders = [int(i*10) + 1 for i in list(np.random.exponential(scale = 1.0, size = num_customers))]
    customers = pd.DataFrame(list(zip(customer_ids, num_orders)), columns =['Customer_ID', 'N_Orders']) 
    customers['Mean_Order_Amt'] = list(np.random.normal(loc = 100, scale = 25, size = num_customers))
    customers['Mean_Order_Amt'] = customers['Mean_Order_Amt'].apply(lambda x: round(x, 2))
    treatment_probs = []
    for i in list(range(0, len(customers), 1)):
        treatment_probs.append(np.random.uniform())
    customers['Treatment_Prob'] = treatment_probs
    customers['Treated'] = np.where(customers['Treatment_Prob'] <= 0.5, 1, 0)
    customers['Treatment_Modifier'] = np.where(customers['Treatment_Prob'] <= 0.5, 1+treatment_effect, 1.0)
    customers = customers[['Customer_ID', 'N_Orders', 'Mean_Order_Amt', 'Treated', 'Treatment_Modifier']]
    print('Customer data frame created.')
    
    j = 0
    master_customer_entry = []
    for i in list(range(0, len(customers), 1)):
        counter = 1
        customer_entry = []
        while counter <= int(customers.loc[[i]]['N_Orders']):
            customer_entry.append(list(customers.loc[[i]].values)) 
            counter += 1
        master_customer_entry.append(customer_entry)    
        if i % 1000 == 0:
            j += 1
            print(str(j*1000) + ' customers allocated (expansion ' + \
                  '{} complete).'.format(str((j*1000)/num_customers)))
    newlist = [item for items in master_customer_entry for item in items]
    newlist = [item for items in newlist for item in items]
    explodedDF = pd.DataFrame(newlist)
    explodedDF.columns = ['Customer_ID', 'Num_Orders', 'Mean_Order_Amt', 'Treated', 'Treatment_Modifier']
    explodedDF = explodedDF[['Customer_ID', 'Mean_Order_Amt', 'Treated', 'Treatment_Modifier']]
    print('Customer dataframe exploded to order dataframe.')

    float_list = []
    for i in list(range(0, len(explodedDF), 1)):
        float_list.append(np.random.uniform())
    explodedDF['Retailer_Prob'] = float_list
    
    # Map the orders randomly to retailers and their correponding scalar.
    a = explodedDF.Retailer_Prob.values
    bh = retailers.b.values
    bl = retailers.a.values

    i, j = np.where((a[:, None] >= bl) & (a[:, None] <= bh))

    result_df = pd.DataFrame(
                np.column_stack([explodedDF.values[i], retailers.values[j]]),
                columns=explodedDF.columns.append(retailers.columns))
    result_df = result_df[['Customer_ID', 'Mean_Order_Amt', 'Treated', 'Treatment_Modifier','Retailer_ID', 
                           'Retailer_Scalar']]
    print('Orders randomly assigned to retailers.')
    
    # Add random noise 
    result_df['Noise'] = list(np.random.normal(loc = 10.0, scale = 1.0, size = len(result_df)))
    result_df['Noise'] = result_df['Noise'].apply(lambda x: round(x, 2))
    result_df['Order_Amt'] = result_df['Mean_Order_Amt']*result_df['Treatment_Modifier']* \
                             result_df['Retailer_Scalar'] + result_df['Noise']
    result_df['Order_Amt'] = result_df['Order_Amt'].apply(lambda x: round(x, 2))
    print('Noise added.')

    # Save to .csv
    print(str(len(result_df)) + ' unique observations created.')
    #result_df = result_df.sample(sample_size, replace=True)
    result_df = result_df.reset_index(drop=True)
    result_df.to_csv(file_name)

# %%
import time
start_time = time.time()
create_sim_data(1000, 1000000, 0.01, 'data_c_1000000_mde_01.csv')
print("--- {} minutes ---".format(str((time.time() - start_time)/60.0)))
# Out:
# Retailer data frame created.
# Customer data frame created.
# 1000 customers allocated (expansion 0.001 complete).
# 2000 customers allocated (expansion 0.002 complete).
# 3000 customers allocated (expansion 0.003 complete).
# 4000 customers allocated (expansion 0.004 complete).
# 5000 customers allocated (expansion 0.005 complete).
# 6000 customers allocated (expansion 0.006 complete).
# 7000 customers allocated (expansion 0.007 complete).
# 8000 customers allocated (expansion 0.008 complete).
# 9000 customers allocated (expansion 0.009 complete).
# 10000 customers allocated (expansion 0.01 complete).
# 11000 customers allocated (expansion 0.011 complete).
# 12000 customers allocated (expansion 0.012 complete).
# 13000 customers allocated (expansion 0.013 complete).
# 14000 customers allocated (expansion 0.014 complete).
# 15000 customers allocated (expansion 0.015 complete).
# 16000 customers allocated (expansion 0.016 complete).
# 17000 customers allocated (expansion 0.017 complete).
# 18000 customers allocated (expansion 0.018 complete).
# 19000 customers allocated (expansion 0.019 complete).
# 20000 customers allocated (expansion 0.02 complete).
# 21000 customers allocated (expansion 0.021 complete).
# 22000 customers allocated (expansion 0.022 complete).
# 23000 customers allocated (expansion 0.023 complete).
# 24000 customers allocated (expansion 0.024 complete).
# 25000 customers allocated (expansion 0.025 complete).
# 26000 customers allocated (expansion 0.026 complete).
# 27000 customers allocated (expansion 0.027 complete).
# 28000 customers allocated (expansion 0.028 complete).
# 29000 customers allocated (expansion 0.029 complete).
# 30000 customers allocated (expansion 0.03 complete).
# 31000 customers allocated (expansion 0.031 complete).
# 32000 customers allocated (expansion 0.032 complete).
# 33000 customers allocated (expansion 0.033 complete).
# 34000 customers allocated (expansion 0.034 complete).
# 35000 customers allocated (expansion 0.035 complete).
# 36000 customers allocated (expansion 0.036 complete).
# 37000 customers allocated (expansion 0.037 complete).
# 38000 customers allocated (expansion 0.038 complete).
# 39000 customers allocated (expansion 0.039 complete).
# 40000 customers allocated (expansion 0.04 complete).
# 41000 customers allocated (expansion 0.041 complete).
# 42000 customers allocated (expansion 0.042 complete).
# 43000 customers allocated (expansion 0.043 complete).
# 44000 customers allocated (expansion 0.044 complete).
# 45000 customers allocated (expansion 0.045 complete).
# 46000 customers allocated (expansion 0.046 complete).
# 47000 customers allocated (expansion 0.047 complete).
# 48000 customers allocated (expansion 0.048 complete).
# 49000 customers allocated (expansion 0.049 complete).
# 50000 customers allocated (expansion 0.05 complete).
# 51000 customers allocated (expansion 0.051 complete).
# 52000 customers allocated (expansion 0.052 complete).
# 53000 customers allocated (expansion 0.053 complete).
# 54000 customers allocated (expansion 0.054 complete).
# 55000 customers allocated (expansion 0.055 complete).
# 56000 customers allocated (expansion 0.056 complete).
# 57000 customers allocated (expansion 0.057 complete).
# 58000 customers allocated (expansion 0.058 complete).
# 59000 customers allocated (expansion 0.059 complete).
# 60000 customers allocated (expansion 0.06 complete).
# 61000 customers allocated (expansion 0.061 complete).
# 62000 customers allocated (expansion 0.062 complete).
# 63000 customers allocated (expansion 0.063 complete).
# 64000 customers allocated (expansion 0.064 complete).
# 65000 customers allocated (expansion 0.065 complete).
# 66000 customers allocated (expansion 0.066 complete).
# 67000 customers allocated (expansion 0.067 complete).
# 68000 customers allocated (expansion 0.068 complete).
# 69000 customers allocated (expansion 0.069 complete).
# 70000 customers allocated (expansion 0.07 complete).
# 71000 customers allocated (expansion 0.071 complete).
# 72000 customers allocated (expansion 0.072 complete).
# 73000 customers allocated (expansion 0.073 complete).
# 74000 customers allocated (expansion 0.074 complete).
# 75000 customers allocated (expansion 0.075 complete).
# 76000 customers allocated (expansion 0.076 complete).
# 77000 customers allocated (expansion 0.077 complete).
# 78000 customers allocated (expansion 0.078 complete).
# 79000 customers allocated (expansion 0.079 complete).
# 80000 customers allocated (expansion 0.08 complete).
# 81000 customers allocated (expansion 0.081 complete).
# 82000 customers allocated (expansion 0.082 complete).
# 83000 customers allocated (expansion 0.083 complete).
# 84000 customers allocated (expansion 0.084 complete).
# 85000 customers allocated (expansion 0.085 complete).
# 86000 customers allocated (expansion 0.086 complete).
# 87000 customers allocated (expansion 0.087 complete).
# 88000 customers allocated (expansion 0.088 complete).
# 89000 customers allocated (expansion 0.089 complete).
# 90000 customers allocated (expansion 0.09 complete).
# 91000 customers allocated (expansion 0.091 complete).
# 92000 customers allocated (expansion 0.092 complete).
# 93000 customers allocated (expansion 0.093 complete).
# 94000 customers allocated (expansion 0.094 complete).
# 95000 customers allocated (expansion 0.095 complete).
# 96000 customers allocated (expansion 0.096 complete).
# 97000 customers allocated (expansion 0.097 complete).
# 98000 customers allocated (expansion 0.098 complete).
# 99000 customers allocated (expansion 0.099 complete).
# 100000 customers allocated (expansion 0.1 complete).
# 101000 customers allocated (expansion 0.101 complete).
# 102000 customers allocated (expansion 0.102 complete).
# 103000 customers allocated (expansion 0.103 complete).
# 104000 customers allocated (expansion 0.104 complete).
# 105000 customers allocated (expansion 0.105 complete).
# 106000 customers allocated (expansion 0.106 complete).
# 107000 customers allocated (expansion 0.107 complete).
# 108000 customers allocated (expansion 0.108 complete).
# 109000 customers allocated (expansion 0.109 complete).
# 110000 customers allocated (expansion 0.11 complete).
# 111000 customers allocated (expansion 0.111 complete).
# 112000 customers allocated (expansion 0.112 complete).
# 113000 customers allocated (expansion 0.113 complete).
# 114000 customers allocated (expansion 0.114 complete).
# 115000 customers allocated (expansion 0.115 complete).
# 116000 customers allocated (expansion 0.116 complete).
# 117000 customers allocated (expansion 0.117 complete).
# 118000 customers allocated (expansion 0.118 complete).
# 119000 customers allocated (expansion 0.119 complete).
# 120000 customers allocated (expansion 0.12 complete).
# 121000 customers allocated (expansion 0.121 complete).
# 122000 customers allocated (expansion 0.122 complete).
# 123000 customers allocated (expansion 0.123 complete).
# 124000 customers allocated (expansion 0.124 complete).
# 125000 customers allocated (expansion 0.125 complete).
# 126000 customers allocated (expansion 0.126 complete).
# 127000 customers allocated (expansion 0.127 complete).
# 128000 customers allocated (expansion 0.128 complete).
# 129000 customers allocated (expansion 0.129 complete).
# 130000 customers allocated (expansion 0.13 complete).
# 131000 customers allocated (expansion 0.131 complete).
# 132000 customers allocated (expansion 0.132 complete).
# 133000 customers allocated (expansion 0.133 complete).
# 134000 customers allocated (expansion 0.134 complete).
# 135000 customers allocated (expansion 0.135 complete).
# 136000 customers allocated (expansion 0.136 complete).
# 137000 customers allocated (expansion 0.137 complete).
# 138000 customers allocated (expansion 0.138 complete).
# 139000 customers allocated (expansion 0.139 complete).
# 140000 customers allocated (expansion 0.14 complete).
# 141000 customers allocated (expansion 0.141 complete).
# 142000 customers allocated (expansion 0.142 complete).
# 143000 customers allocated (expansion 0.143 complete).
# 144000 customers allocated (expansion 0.144 complete).
# 145000 customers allocated (expansion 0.145 complete).
# 146000 customers allocated (expansion 0.146 complete).
# 147000 customers allocated (expansion 0.147 complete).
# 148000 customers allocated (expansion 0.148 complete).
# 149000 customers allocated (expansion 0.149 complete).
# 150000 customers allocated (expansion 0.15 complete).
# 151000 customers allocated (expansion 0.151 complete).
# 152000 customers allocated (expansion 0.152 complete).
# 153000 customers allocated (expansion 0.153 complete).
# 154000 customers allocated (expansion 0.154 complete).
# 155000 customers allocated (expansion 0.155 complete).
# 156000 customers allocated (expansion 0.156 complete).
# 157000 customers allocated (expansion 0.157 complete).
# 158000 customers allocated (expansion 0.158 complete).
# 159000 customers allocated (expansion 0.159 complete).
# 160000 customers allocated (expansion 0.16 complete).
# 161000 customers allocated (expansion 0.161 complete).
# 162000 customers allocated (expansion 0.162 complete).
# 163000 customers allocated (expansion 0.163 complete).
# 164000 customers allocated (expansion 0.164 complete).
# 165000 customers allocated (expansion 0.165 complete).
# 166000 customers allocated (expansion 0.166 complete).
# 167000 customers allocated (expansion 0.167 complete).
# 168000 customers allocated (expansion 0.168 complete).
# 169000 customers allocated (expansion 0.169 complete).
# 170000 customers allocated (expansion 0.17 complete).
# 171000 customers allocated (expansion 0.171 complete).
# 172000 customers allocated (expansion 0.172 complete).
# 173000 customers allocated (expansion 0.173 complete).
# 174000 customers allocated (expansion 0.174 complete).
# 175000 customers allocated (expansion 0.175 complete).
# 176000 customers allocated (expansion 0.176 complete).
# 177000 customers allocated (expansion 0.177 complete).
# 178000 customers allocated (expansion 0.178 complete).
# 179000 customers allocated (expansion 0.179 complete).
# 180000 customers allocated (expansion 0.18 complete).
# 181000 customers allocated (expansion 0.181 complete).
# 182000 customers allocated (expansion 0.182 complete).
# 183000 customers allocated (expansion 0.183 complete).
# 184000 customers allocated (expansion 0.184 complete).
# 185000 customers allocated (expansion 0.185 complete).
# 186000 customers allocated (expansion 0.186 complete).
# 187000 customers allocated (expansion 0.187 complete).
# 188000 customers allocated (expansion 0.188 complete).
# 189000 customers allocated (expansion 0.189 complete).
# 190000 customers allocated (expansion 0.19 complete).
# 191000 customers allocated (expansion 0.191 complete).
# 192000 customers allocated (expansion 0.192 complete).
# 193000 customers allocated (expansion 0.193 complete).
# 194000 customers allocated (expansion 0.194 complete).
# 195000 customers allocated (expansion 0.195 complete).
# 196000 customers allocated (expansion 0.196 complete).
# 197000 customers allocated (expansion 0.197 complete).
# 198000 customers allocated (expansion 0.198 complete).
# 199000 customers allocated (expansion 0.199 complete).
# 200000 customers allocated (expansion 0.2 complete).
# 201000 customers allocated (expansion 0.201 complete).
# 202000 customers allocated (expansion 0.202 complete).
# 203000 customers allocated (expansion 0.203 complete).
# 204000 customers allocated (expansion 0.204 complete).
# 205000 customers allocated (expansion 0.205 complete).
# 206000 customers allocated (expansion 0.206 complete).
# 207000 customers allocated (expansion 0.207 complete).
# 208000 customers allocated (expansion 0.208 complete).
# 209000 customers allocated (expansion 0.209 complete).
# 210000 customers allocated (expansion 0.21 complete).
# 211000 customers allocated (expansion 0.211 complete).
# 212000 customers allocated (expansion 0.212 complete).
# 213000 customers allocated (expansion 0.213 complete).
# 214000 customers allocated (expansion 0.214 complete).
# 215000 customers allocated (expansion 0.215 complete).
# 216000 customers allocated (expansion 0.216 complete).
# 217000 customers allocated (expansion 0.217 complete).
# 218000 customers allocated (expansion 0.218 complete).
# 219000 customers allocated (expansion 0.219 complete).
# 220000 customers allocated (expansion 0.22 complete).
# 221000 customers allocated (expansion 0.221 complete).
# 222000 customers allocated (expansion 0.222 complete).
# 223000 customers allocated (expansion 0.223 complete).
# 224000 customers allocated (expansion 0.224 complete).
# 225000 customers allocated (expansion 0.225 complete).
# 226000 customers allocated (expansion 0.226 complete).
# 227000 customers allocated (expansion 0.227 complete).
# 228000 customers allocated (expansion 0.228 complete).
# 229000 customers allocated (expansion 0.229 complete).
# 230000 customers allocated (expansion 0.23 complete).
# 231000 customers allocated (expansion 0.231 complete).
# 232000 customers allocated (expansion 0.232 complete).
# 233000 customers allocated (expansion 0.233 complete).
# 234000 customers allocated (expansion 0.234 complete).
# 235000 customers allocated (expansion 0.235 complete).
# 236000 customers allocated (expansion 0.236 complete).
# 237000 customers allocated (expansion 0.237 complete).
# 238000 customers allocated (expansion 0.238 complete).
# 239000 customers allocated (expansion 0.239 complete).
# 240000 customers allocated (expansion 0.24 complete).
# 241000 customers allocated (expansion 0.241 complete).
# 242000 customers allocated (expansion 0.242 complete).
# 243000 customers allocated (expansion 0.243 complete).
# 244000 customers allocated (expansion 0.244 complete).
# 245000 customers allocated (expansion 0.245 complete).
# 246000 customers allocated (expansion 0.246 complete).
# 247000 customers allocated (expansion 0.247 complete).
# 248000 customers allocated (expansion 0.248 complete).
# 249000 customers allocated (expansion 0.249 complete).
# 250000 customers allocated (expansion 0.25 complete).
# 251000 customers allocated (expansion 0.251 complete).
# 252000 customers allocated (expansion 0.252 complete).
# 253000 customers allocated (expansion 0.253 complete).
# 254000 customers allocated (expansion 0.254 complete).
# 255000 customers allocated (expansion 0.255 complete).
# 256000 customers allocated (expansion 0.256 complete).
# 257000 customers allocated (expansion 0.257 complete).
# 258000 customers allocated (expansion 0.258 complete).
# 259000 customers allocated (expansion 0.259 complete).
# 260000 customers allocated (expansion 0.26 complete).
# 261000 customers allocated (expansion 0.261 complete).
# 262000 customers allocated (expansion 0.262 complete).
# 263000 customers allocated (expansion 0.263 complete).
# 264000 customers allocated (expansion 0.264 complete).
# 265000 customers allocated (expansion 0.265 complete).
# 266000 customers allocated (expansion 0.266 complete).
# 267000 customers allocated (expansion 0.267 complete).
# 268000 customers allocated (expansion 0.268 complete).
# 269000 customers allocated (expansion 0.269 complete).
# 270000 customers allocated (expansion 0.27 complete).
# 271000 customers allocated (expansion 0.271 complete).
# 272000 customers allocated (expansion 0.272 complete).
# 273000 customers allocated (expansion 0.273 complete).
# 274000 customers allocated (expansion 0.274 complete).
# 275000 customers allocated (expansion 0.275 complete).
# 276000 customers allocated (expansion 0.276 complete).
# 277000 customers allocated (expansion 0.277 complete).
# 278000 customers allocated (expansion 0.278 complete).
# 279000 customers allocated (expansion 0.279 complete).
# 280000 customers allocated (expansion 0.28 complete).
# 281000 customers allocated (expansion 0.281 complete).
# 282000 customers allocated (expansion 0.282 complete).
# 283000 customers allocated (expansion 0.283 complete).
# 284000 customers allocated (expansion 0.284 complete).
# 285000 customers allocated (expansion 0.285 complete).
# 286000 customers allocated (expansion 0.286 complete).
# 287000 customers allocated (expansion 0.287 complete).
# 288000 customers allocated (expansion 0.288 complete).
# 289000 customers allocated (expansion 0.289 complete).
# 290000 customers allocated (expansion 0.29 complete).
# 291000 customers allocated (expansion 0.291 complete).
# 292000 customers allocated (expansion 0.292 complete).
# 293000 customers allocated (expansion 0.293 complete).
# 294000 customers allocated (expansion 0.294 complete).
# 295000 customers allocated (expansion 0.295 complete).
# 296000 customers allocated (expansion 0.296 complete).
# 297000 customers allocated (expansion 0.297 complete).
# 298000 customers allocated (expansion 0.298 complete).
# 299000 customers allocated (expansion 0.299 complete).
# 300000 customers allocated (expansion 0.3 complete).
# 301000 customers allocated (expansion 0.301 complete).
# 302000 customers allocated (expansion 0.302 complete).
# 303000 customers allocated (expansion 0.303 complete).
# 304000 customers allocated (expansion 0.304 complete).
# 305000 customers allocated (expansion 0.305 complete).
# 306000 customers allocated (expansion 0.306 complete).
# 307000 customers allocated (expansion 0.307 complete).
# 308000 customers allocated (expansion 0.308 complete).
# 309000 customers allocated (expansion 0.309 complete).
# 310000 customers allocated (expansion 0.31 complete).
# 311000 customers allocated (expansion 0.311 complete).
# 312000 customers allocated (expansion 0.312 complete).
# 313000 customers allocated (expansion 0.313 complete).
# 314000 customers allocated (expansion 0.314 complete).
# 315000 customers allocated (expansion 0.315 complete).
# 316000 customers allocated (expansion 0.316 complete).
# 317000 customers allocated (expansion 0.317 complete).
# 318000 customers allocated (expansion 0.318 complete).
# 319000 customers allocated (expansion 0.319 complete).
# 320000 customers allocated (expansion 0.32 complete).
# 321000 customers allocated (expansion 0.321 complete).
# 322000 customers allocated (expansion 0.322 complete).
# 323000 customers allocated (expansion 0.323 complete).
# 324000 customers allocated (expansion 0.324 complete).
# 325000 customers allocated (expansion 0.325 complete).
# 326000 customers allocated (expansion 0.326 complete).
# 327000 customers allocated (expansion 0.327 complete).
# 328000 customers allocated (expansion 0.328 complete).
# 329000 customers allocated (expansion 0.329 complete).
# 330000 customers allocated (expansion 0.33 complete).
# 331000 customers allocated (expansion 0.331 complete).
# 332000 customers allocated (expansion 0.332 complete).
# 333000 customers allocated (expansion 0.333 complete).
# 334000 customers allocated (expansion 0.334 complete).
# 335000 customers allocated (expansion 0.335 complete).
# 336000 customers allocated (expansion 0.336 complete).
# 337000 customers allocated (expansion 0.337 complete).
# 338000 customers allocated (expansion 0.338 complete).
# 339000 customers allocated (expansion 0.339 complete).
# 340000 customers allocated (expansion 0.34 complete).
# 341000 customers allocated (expansion 0.341 complete).
# 342000 customers allocated (expansion 0.342 complete).
# 343000 customers allocated (expansion 0.343 complete).
# 344000 customers allocated (expansion 0.344 complete).
# 345000 customers allocated (expansion 0.345 complete).
# 346000 customers allocated (expansion 0.346 complete).
# 347000 customers allocated (expansion 0.347 complete).
# 348000 customers allocated (expansion 0.348 complete).
# 349000 customers allocated (expansion 0.349 complete).
# 350000 customers allocated (expansion 0.35 complete).
# 351000 customers allocated (expansion 0.351 complete).
# 352000 customers allocated (expansion 0.352 complete).
# 353000 customers allocated (expansion 0.353 complete).
# 354000 customers allocated (expansion 0.354 complete).
# 355000 customers allocated (expansion 0.355 complete).
# 356000 customers allocated (expansion 0.356 complete).
# 357000 customers allocated (expansion 0.357 complete).
# 358000 customers allocated (expansion 0.358 complete).
# 359000 customers allocated (expansion 0.359 complete).
# 360000 customers allocated (expansion 0.36 complete).
# 361000 customers allocated (expansion 0.361 complete).
# 362000 customers allocated (expansion 0.362 complete).
# 363000 customers allocated (expansion 0.363 complete).
# 364000 customers allocated (expansion 0.364 complete).
# 365000 customers allocated (expansion 0.365 complete).
# 366000 customers allocated (expansion 0.366 complete).
# 367000 customers allocated (expansion 0.367 complete).
# 368000 customers allocated (expansion 0.368 complete).
# 369000 customers allocated (expansion 0.369 complete).
# 370000 customers allocated (expansion 0.37 complete).
# 371000 customers allocated (expansion 0.371 complete).
# 372000 customers allocated (expansion 0.372 complete).
# 373000 customers allocated (expansion 0.373 complete).
# 374000 customers allocated (expansion 0.374 complete).
# 375000 customers allocated (expansion 0.375 complete).
# 376000 customers allocated (expansion 0.376 complete).
# 377000 customers allocated (expansion 0.377 complete).
# 378000 customers allocated (expansion 0.378 complete).
# 379000 customers allocated (expansion 0.379 complete).
# 380000 customers allocated (expansion 0.38 complete).
# 381000 customers allocated (expansion 0.381 complete).
# 382000 customers allocated (expansion 0.382 complete).
# 383000 customers allocated (expansion 0.383 complete).
# 384000 customers allocated (expansion 0.384 complete).
# 385000 customers allocated (expansion 0.385 complete).
# 386000 customers allocated (expansion 0.386 complete).
# 387000 customers allocated (expansion 0.387 complete).
# 388000 customers allocated (expansion 0.388 complete).
# 389000 customers allocated (expansion 0.389 complete).
# 390000 customers allocated (expansion 0.39 complete).
# 391000 customers allocated (expansion 0.391 complete).
# 392000 customers allocated (expansion 0.392 complete).
# 393000 customers allocated (expansion 0.393 complete).
# 394000 customers allocated (expansion 0.394 complete).
# 395000 customers allocated (expansion 0.395 complete).
# 396000 customers allocated (expansion 0.396 complete).
# 397000 customers allocated (expansion 0.397 complete).
# 398000 customers allocated (expansion 0.398 complete).
# 399000 customers allocated (expansion 0.399 complete).
# 400000 customers allocated (expansion 0.4 complete).
# 401000 customers allocated (expansion 0.401 complete).
# 402000 customers allocated (expansion 0.402 complete).
# 403000 customers allocated (expansion 0.403 complete).
# 404000 customers allocated (expansion 0.404 complete).
# 405000 customers allocated (expansion 0.405 complete).
# 406000 customers allocated (expansion 0.406 complete).
# 407000 customers allocated (expansion 0.407 complete).
# 408000 customers allocated (expansion 0.408 complete).
# 409000 customers allocated (expansion 0.409 complete).
# 410000 customers allocated (expansion 0.41 complete).
# 411000 customers allocated (expansion 0.411 complete).
# 412000 customers allocated (expansion 0.412 complete).
# 413000 customers allocated (expansion 0.413 complete).
# 414000 customers allocated (expansion 0.414 complete).
# 415000 customers allocated (expansion 0.415 complete).
# 416000 customers allocated (expansion 0.416 complete).
# 417000 customers allocated (expansion 0.417 complete).
# 418000 customers allocated (expansion 0.418 complete).
# 419000 customers allocated (expansion 0.419 complete).
# 420000 customers allocated (expansion 0.42 complete).
# 421000 customers allocated (expansion 0.421 complete).
# 422000 customers allocated (expansion 0.422 complete).
# 423000 customers allocated (expansion 0.423 complete).
# 424000 customers allocated (expansion 0.424 complete).
# 425000 customers allocated (expansion 0.425 complete).
# 426000 customers allocated (expansion 0.426 complete).
# 427000 customers allocated (expansion 0.427 complete).
# 428000 customers allocated (expansion 0.428 complete).
# 429000 customers allocated (expansion 0.429 complete).
# 430000 customers allocated (expansion 0.43 complete).
# 431000 customers allocated (expansion 0.431 complete).
# 432000 customers allocated (expansion 0.432 complete).
# 433000 customers allocated (expansion 0.433 complete).
# 434000 customers allocated (expansion 0.434 complete).
# 435000 customers allocated (expansion 0.435 complete).
# 436000 customers allocated (expansion 0.436 complete).
# 437000 customers allocated (expansion 0.437 complete).
# 438000 customers allocated (expansion 0.438 complete).
# 439000 customers allocated (expansion 0.439 complete).
# 440000 customers allocated (expansion 0.44 complete).
# 441000 customers allocated (expansion 0.441 complete).
# 442000 customers allocated (expansion 0.442 complete).
# 443000 customers allocated (expansion 0.443 complete).
# 444000 customers allocated (expansion 0.444 complete).
# 445000 customers allocated (expansion 0.445 complete).
# 446000 customers allocated (expansion 0.446 complete).
# 447000 customers allocated (expansion 0.447 complete).
# 448000 customers allocated (expansion 0.448 complete).
# 449000 customers allocated (expansion 0.449 complete).
# 450000 customers allocated (expansion 0.45 complete).
# 451000 customers allocated (expansion 0.451 complete).
# 452000 customers allocated (expansion 0.452 complete).
# 453000 customers allocated (expansion 0.453 complete).
# 454000 customers allocated (expansion 0.454 complete).
# 455000 customers allocated (expansion 0.455 complete).
# 456000 customers allocated (expansion 0.456 complete).
# 457000 customers allocated (expansion 0.457 complete).
# 458000 customers allocated (expansion 0.458 complete).
# 459000 customers allocated (expansion 0.459 complete).
# 460000 customers allocated (expansion 0.46 complete).
# 461000 customers allocated (expansion 0.461 complete).
# 462000 customers allocated (expansion 0.462 complete).
# 463000 customers allocated (expansion 0.463 complete).
# 464000 customers allocated (expansion 0.464 complete).
# 465000 customers allocated (expansion 0.465 complete).
# 466000 customers allocated (expansion 0.466 complete).
# 467000 customers allocated (expansion 0.467 complete).
# 468000 customers allocated (expansion 0.468 complete).
# 469000 customers allocated (expansion 0.469 complete).
# 470000 customers allocated (expansion 0.47 complete).
# 471000 customers allocated (expansion 0.471 complete).
# 472000 customers allocated (expansion 0.472 complete).
# 473000 customers allocated (expansion 0.473 complete).
# 474000 customers allocated (expansion 0.474 complete).
# 475000 customers allocated (expansion 0.475 complete).
# 476000 customers allocated (expansion 0.476 complete).
# 477000 customers allocated (expansion 0.477 complete).
# 478000 customers allocated (expansion 0.478 complete).
# 479000 customers allocated (expansion 0.479 complete).
# 480000 customers allocated (expansion 0.48 complete).
# 481000 customers allocated (expansion 0.481 complete).
# 482000 customers allocated (expansion 0.482 complete).
# 483000 customers allocated (expansion 0.483 complete).
# 484000 customers allocated (expansion 0.484 complete).
# 485000 customers allocated (expansion 0.485 complete).
# 486000 customers allocated (expansion 0.486 complete).
# 487000 customers allocated (expansion 0.487 complete).
# 488000 customers allocated (expansion 0.488 complete).
# 489000 customers allocated (expansion 0.489 complete).
# 490000 customers allocated (expansion 0.49 complete).
# 491000 customers allocated (expansion 0.491 complete).
# 492000 customers allocated (expansion 0.492 complete).
# 493000 customers allocated (expansion 0.493 complete).
# 494000 customers allocated (expansion 0.494 complete).
# 495000 customers allocated (expansion 0.495 complete).
# 496000 customers allocated (expansion 0.496 complete).
# 497000 customers allocated (expansion 0.497 complete).
# 498000 customers allocated (expansion 0.498 complete).
# 499000 customers allocated (expansion 0.499 complete).
# 500000 customers allocated (expansion 0.5 complete).
# 501000 customers allocated (expansion 0.501 complete).
# 502000 customers allocated (expansion 0.502 complete).
# 503000 customers allocated (expansion 0.503 complete).
# 504000 customers allocated (expansion 0.504 complete).
# 505000 customers allocated (expansion 0.505 complete).
# 506000 customers allocated (expansion 0.506 complete).
# 507000 customers allocated (expansion 0.507 complete).
# 508000 customers allocated (expansion 0.508 complete).
# 509000 customers allocated (expansion 0.509 complete).
# 510000 customers allocated (expansion 0.51 complete).
# 511000 customers allocated (expansion 0.511 complete).
# 512000 customers allocated (expansion 0.512 complete).
# 513000 customers allocated (expansion 0.513 complete).
# 514000 customers allocated (expansion 0.514 complete).
# 515000 customers allocated (expansion 0.515 complete).
# 516000 customers allocated (expansion 0.516 complete).
# 517000 customers allocated (expansion 0.517 complete).
# 518000 customers allocated (expansion 0.518 complete).
# 519000 customers allocated (expansion 0.519 complete).
# 520000 customers allocated (expansion 0.52 complete).
# 521000 customers allocated (expansion 0.521 complete).
# 522000 customers allocated (expansion 0.522 complete).
# 523000 customers allocated (expansion 0.523 complete).
# 524000 customers allocated (expansion 0.524 complete).
# 525000 customers allocated (expansion 0.525 complete).
# 526000 customers allocated (expansion 0.526 complete).
# 527000 customers allocated (expansion 0.527 complete).
# 528000 customers allocated (expansion 0.528 complete).
# 529000 customers allocated (expansion 0.529 complete).
# 530000 customers allocated (expansion 0.53 complete).
# 531000 customers allocated (expansion 0.531 complete).
# 532000 customers allocated (expansion 0.532 complete).
# 533000 customers allocated (expansion 0.533 complete).
# 534000 customers allocated (expansion 0.534 complete).
# 535000 customers allocated (expansion 0.535 complete).
# 536000 customers allocated (expansion 0.536 complete).
# 537000 customers allocated (expansion 0.537 complete).
# 538000 customers allocated (expansion 0.538 complete).
# 539000 customers allocated (expansion 0.539 complete).
# 540000 customers allocated (expansion 0.54 complete).
# 541000 customers allocated (expansion 0.541 complete).
# 542000 customers allocated (expansion 0.542 complete).
# 543000 customers allocated (expansion 0.543 complete).
# 544000 customers allocated (expansion 0.544 complete).
# 545000 customers allocated (expansion 0.545 complete).
# 546000 customers allocated (expansion 0.546 complete).
# 547000 customers allocated (expansion 0.547 complete).
# 548000 customers allocated (expansion 0.548 complete).
# 549000 customers allocated (expansion 0.549 complete).
# 550000 customers allocated (expansion 0.55 complete).
# 551000 customers allocated (expansion 0.551 complete).
# 552000 customers allocated (expansion 0.552 complete).
# 553000 customers allocated (expansion 0.553 complete).
# 554000 customers allocated (expansion 0.554 complete).
# 555000 customers allocated (expansion 0.555 complete).
# 556000 customers allocated (expansion 0.556 complete).
# 557000 customers allocated (expansion 0.557 complete).
# 558000 customers allocated (expansion 0.558 complete).
# 559000 customers allocated (expansion 0.559 complete).
# 560000 customers allocated (expansion 0.56 complete).
# 561000 customers allocated (expansion 0.561 complete).
# 562000 customers allocated (expansion 0.562 complete).
# 563000 customers allocated (expansion 0.563 complete).
# 564000 customers allocated (expansion 0.564 complete).
# 565000 customers allocated (expansion 0.565 complete).
# 566000 customers allocated (expansion 0.566 complete).
# 567000 customers allocated (expansion 0.567 complete).
# 568000 customers allocated (expansion 0.568 complete).
# 569000 customers allocated (expansion 0.569 complete).
# 570000 customers allocated (expansion 0.57 complete).
# 571000 customers allocated (expansion 0.571 complete).
# 572000 customers allocated (expansion 0.572 complete).
# 573000 customers allocated (expansion 0.573 complete).
# 574000 customers allocated (expansion 0.574 complete).
# 575000 customers allocated (expansion 0.575 complete).
# 576000 customers allocated (expansion 0.576 complete).
# 577000 customers allocated (expansion 0.577 complete).
# 578000 customers allocated (expansion 0.578 complete).
# 579000 customers allocated (expansion 0.579 complete).
# 580000 customers allocated (expansion 0.58 complete).
# 581000 customers allocated (expansion 0.581 complete).
# 582000 customers allocated (expansion 0.582 complete).
# 583000 customers allocated (expansion 0.583 complete).
# 584000 customers allocated (expansion 0.584 complete).
# 585000 customers allocated (expansion 0.585 complete).
# 586000 customers allocated (expansion 0.586 complete).
# 587000 customers allocated (expansion 0.587 complete).
# 588000 customers allocated (expansion 0.588 complete).
# 589000 customers allocated (expansion 0.589 complete).
# 590000 customers allocated (expansion 0.59 complete).
# 591000 customers allocated (expansion 0.591 complete).
# 592000 customers allocated (expansion 0.592 complete).
# 593000 customers allocated (expansion 0.593 complete).
# 594000 customers allocated (expansion 0.594 complete).
# 595000 customers allocated (expansion 0.595 complete).
# 596000 customers allocated (expansion 0.596 complete).
# 597000 customers allocated (expansion 0.597 complete).
# 598000 customers allocated (expansion 0.598 complete).
# 599000 customers allocated (expansion 0.599 complete).
# 600000 customers allocated (expansion 0.6 complete).
# 601000 customers allocated (expansion 0.601 complete).
# 602000 customers allocated (expansion 0.602 complete).
# 603000 customers allocated (expansion 0.603 complete).
# 604000 customers allocated (expansion 0.604 complete).
# 605000 customers allocated (expansion 0.605 complete).
# 606000 customers allocated (expansion 0.606 complete).
# 607000 customers allocated (expansion 0.607 complete).
# 608000 customers allocated (expansion 0.608 complete).
# 609000 customers allocated (expansion 0.609 complete).
# 610000 customers allocated (expansion 0.61 complete).
# 611000 customers allocated (expansion 0.611 complete).
# 612000 customers allocated (expansion 0.612 complete).
# 613000 customers allocated (expansion 0.613 complete).
# 614000 customers allocated (expansion 0.614 complete).
# 615000 customers allocated (expansion 0.615 complete).
# 616000 customers allocated (expansion 0.616 complete).
# 617000 customers allocated (expansion 0.617 complete).
# 618000 customers allocated (expansion 0.618 complete).
# 619000 customers allocated (expansion 0.619 complete).
# 620000 customers allocated (expansion 0.62 complete).
# 621000 customers allocated (expansion 0.621 complete).
# 622000 customers allocated (expansion 0.622 complete).
# 623000 customers allocated (expansion 0.623 complete).
# 624000 customers allocated (expansion 0.624 complete).
# 625000 customers allocated (expansion 0.625 complete).
# 626000 customers allocated (expansion 0.626 complete).
# 627000 customers allocated (expansion 0.627 complete).
# 628000 customers allocated (expansion 0.628 complete).
# 629000 customers allocated (expansion 0.629 complete).
# 630000 customers allocated (expansion 0.63 complete).
# 631000 customers allocated (expansion 0.631 complete).
# 632000 customers allocated (expansion 0.632 complete).
# 633000 customers allocated (expansion 0.633 complete).
# 634000 customers allocated (expansion 0.634 complete).
# 635000 customers allocated (expansion 0.635 complete).
# 636000 customers allocated (expansion 0.636 complete).
# 637000 customers allocated (expansion 0.637 complete).
# 638000 customers allocated (expansion 0.638 complete).
# 639000 customers allocated (expansion 0.639 complete).
# 640000 customers allocated (expansion 0.64 complete).
# 641000 customers allocated (expansion 0.641 complete).
# 642000 customers allocated (expansion 0.642 complete).
# 643000 customers allocated (expansion 0.643 complete).
# 644000 customers allocated (expansion 0.644 complete).
# 645000 customers allocated (expansion 0.645 complete).
# 646000 customers allocated (expansion 0.646 complete).
# 647000 customers allocated (expansion 0.647 complete).
# 648000 customers allocated (expansion 0.648 complete).
# 649000 customers allocated (expansion 0.649 complete).
# 650000 customers allocated (expansion 0.65 complete).
# 651000 customers allocated (expansion 0.651 complete).
# 652000 customers allocated (expansion 0.652 complete).
# 653000 customers allocated (expansion 0.653 complete).
# 654000 customers allocated (expansion 0.654 complete).
# 655000 customers allocated (expansion 0.655 complete).
# 656000 customers allocated (expansion 0.656 complete).
# 657000 customers allocated (expansion 0.657 complete).
# 658000 customers allocated (expansion 0.658 complete).
# 659000 customers allocated (expansion 0.659 complete).
# 660000 customers allocated (expansion 0.66 complete).
# 661000 customers allocated (expansion 0.661 complete).
# 662000 customers allocated (expansion 0.662 complete).
# 663000 customers allocated (expansion 0.663 complete).
# 664000 customers allocated (expansion 0.664 complete).
# 665000 customers allocated (expansion 0.665 complete).
# 666000 customers allocated (expansion 0.666 complete).
# 667000 customers allocated (expansion 0.667 complete).
# 668000 customers allocated (expansion 0.668 complete).
# 669000 customers allocated (expansion 0.669 complete).
# 670000 customers allocated (expansion 0.67 complete).
# 671000 customers allocated (expansion 0.671 complete).
# 672000 customers allocated (expansion 0.672 complete).
# 673000 customers allocated (expansion 0.673 complete).
# 674000 customers allocated (expansion 0.674 complete).
# 675000 customers allocated (expansion 0.675 complete).
# 676000 customers allocated (expansion 0.676 complete).
# 677000 customers allocated (expansion 0.677 complete).
# 678000 customers allocated (expansion 0.678 complete).
# 679000 customers allocated (expansion 0.679 complete).
# 680000 customers allocated (expansion 0.68 complete).
# 681000 customers allocated (expansion 0.681 complete).
# 682000 customers allocated (expansion 0.682 complete).
# 683000 customers allocated (expansion 0.683 complete).
# 684000 customers allocated (expansion 0.684 complete).
# 685000 customers allocated (expansion 0.685 complete).
# 686000 customers allocated (expansion 0.686 complete).
# 687000 customers allocated (expansion 0.687 complete).
# 688000 customers allocated (expansion 0.688 complete).
# 689000 customers allocated (expansion 0.689 complete).
# 690000 customers allocated (expansion 0.69 complete).
# 691000 customers allocated (expansion 0.691 complete).
# 692000 customers allocated (expansion 0.692 complete).
# 693000 customers allocated (expansion 0.693 complete).
# 694000 customers allocated (expansion 0.694 complete).
# 695000 customers allocated (expansion 0.695 complete).
# 696000 customers allocated (expansion 0.696 complete).
# 697000 customers allocated (expansion 0.697 complete).
# 698000 customers allocated (expansion 0.698 complete).
# 699000 customers allocated (expansion 0.699 complete).
# 700000 customers allocated (expansion 0.7 complete).
# 701000 customers allocated (expansion 0.701 complete).
# 702000 customers allocated (expansion 0.702 complete).
# 703000 customers allocated (expansion 0.703 complete).
# 704000 customers allocated (expansion 0.704 complete).
# 705000 customers allocated (expansion 0.705 complete).
# 706000 customers allocated (expansion 0.706 complete).
# 707000 customers allocated (expansion 0.707 complete).
# 708000 customers allocated (expansion 0.708 complete).
# 709000 customers allocated (expansion 0.709 complete).
# 710000 customers allocated (expansion 0.71 complete).
# 711000 customers allocated (expansion 0.711 complete).
# 712000 customers allocated (expansion 0.712 complete).
# 713000 customers allocated (expansion 0.713 complete).
# 714000 customers allocated (expansion 0.714 complete).
# 715000 customers allocated (expansion 0.715 complete).
# 716000 customers allocated (expansion 0.716 complete).
# 717000 customers allocated (expansion 0.717 complete).
# 718000 customers allocated (expansion 0.718 complete).
# 719000 customers allocated (expansion 0.719 complete).
# 720000 customers allocated (expansion 0.72 complete).
# 721000 customers allocated (expansion 0.721 complete).
# 722000 customers allocated (expansion 0.722 complete).
# 723000 customers allocated (expansion 0.723 complete).
# 724000 customers allocated (expansion 0.724 complete).
# 725000 customers allocated (expansion 0.725 complete).
# 726000 customers allocated (expansion 0.726 complete).
# 727000 customers allocated (expansion 0.727 complete).
# 728000 customers allocated (expansion 0.728 complete).
# 729000 customers allocated (expansion 0.729 complete).
# 730000 customers allocated (expansion 0.73 complete).
# 731000 customers allocated (expansion 0.731 complete).
# 732000 customers allocated (expansion 0.732 complete).
# 733000 customers allocated (expansion 0.733 complete).
# 734000 customers allocated (expansion 0.734 complete).
# 735000 customers allocated (expansion 0.735 complete).
# 736000 customers allocated (expansion 0.736 complete).
# 737000 customers allocated (expansion 0.737 complete).
# 738000 customers allocated (expansion 0.738 complete).
# 739000 customers allocated (expansion 0.739 complete).
# 740000 customers allocated (expansion 0.74 complete).
# 741000 customers allocated (expansion 0.741 complete).
# 742000 customers allocated (expansion 0.742 complete).
# 743000 customers allocated (expansion 0.743 complete).
# 744000 customers allocated (expansion 0.744 complete).
# 745000 customers allocated (expansion 0.745 complete).
# 746000 customers allocated (expansion 0.746 complete).
# 747000 customers allocated (expansion 0.747 complete).
# 748000 customers allocated (expansion 0.748 complete).
# 749000 customers allocated (expansion 0.749 complete).
# 750000 customers allocated (expansion 0.75 complete).
# 751000 customers allocated (expansion 0.751 complete).
# 752000 customers allocated (expansion 0.752 complete).
# 753000 customers allocated (expansion 0.753 complete).
# 754000 customers allocated (expansion 0.754 complete).
# 755000 customers allocated (expansion 0.755 complete).
# 756000 customers allocated (expansion 0.756 complete).
# 757000 customers allocated (expansion 0.757 complete).
# 758000 customers allocated (expansion 0.758 complete).
# 759000 customers allocated (expansion 0.759 complete).
# 760000 customers allocated (expansion 0.76 complete).
# 761000 customers allocated (expansion 0.761 complete).
# 762000 customers allocated (expansion 0.762 complete).
# 763000 customers allocated (expansion 0.763 complete).
# 764000 customers allocated (expansion 0.764 complete).
# 765000 customers allocated (expansion 0.765 complete).
# 766000 customers allocated (expansion 0.766 complete).
# 767000 customers allocated (expansion 0.767 complete).
# 768000 customers allocated (expansion 0.768 complete).
# 769000 customers allocated (expansion 0.769 complete).
# 770000 customers allocated (expansion 0.77 complete).
# 771000 customers allocated (expansion 0.771 complete).
# 772000 customers allocated (expansion 0.772 complete).
# 773000 customers allocated (expansion 0.773 complete).
# 774000 customers allocated (expansion 0.774 complete).
# 775000 customers allocated (expansion 0.775 complete).
# 776000 customers allocated (expansion 0.776 complete).
# 777000 customers allocated (expansion 0.777 complete).
# 778000 customers allocated (expansion 0.778 complete).
# 779000 customers allocated (expansion 0.779 complete).
# 780000 customers allocated (expansion 0.78 complete).
# 781000 customers allocated (expansion 0.781 complete).
# 782000 customers allocated (expansion 0.782 complete).
# 783000 customers allocated (expansion 0.783 complete).
# 784000 customers allocated (expansion 0.784 complete).
# 785000 customers allocated (expansion 0.785 complete).
# 786000 customers allocated (expansion 0.786 complete).
# 787000 customers allocated (expansion 0.787 complete).
# 788000 customers allocated (expansion 0.788 complete).
# 789000 customers allocated (expansion 0.789 complete).
# 790000 customers allocated (expansion 0.79 complete).
# 791000 customers allocated (expansion 0.791 complete).
# 792000 customers allocated (expansion 0.792 complete).
# 793000 customers allocated (expansion 0.793 complete).
# 794000 customers allocated (expansion 0.794 complete).
# 795000 customers allocated (expansion 0.795 complete).
# 796000 customers allocated (expansion 0.796 complete).
# 797000 customers allocated (expansion 0.797 complete).
# 798000 customers allocated (expansion 0.798 complete).
# 799000 customers allocated (expansion 0.799 complete).
# 800000 customers allocated (expansion 0.8 complete).
# 801000 customers allocated (expansion 0.801 complete).
# 802000 customers allocated (expansion 0.802 complete).
# 803000 customers allocated (expansion 0.803 complete).
# 804000 customers allocated (expansion 0.804 complete).
# 805000 customers allocated (expansion 0.805 complete).
# 806000 customers allocated (expansion 0.806 complete).
# 807000 customers allocated (expansion 0.807 complete).
# 808000 customers allocated (expansion 0.808 complete).
# 809000 customers allocated (expansion 0.809 complete).
# 810000 customers allocated (expansion 0.81 complete).
# 811000 customers allocated (expansion 0.811 complete).
# 812000 customers allocated (expansion 0.812 complete).
# 813000 customers allocated (expansion 0.813 complete).
# 814000 customers allocated (expansion 0.814 complete).
# 815000 customers allocated (expansion 0.815 complete).
# 816000 customers allocated (expansion 0.816 complete).
# 817000 customers allocated (expansion 0.817 complete).
# 818000 customers allocated (expansion 0.818 complete).
# 819000 customers allocated (expansion 0.819 complete).
# 820000 customers allocated (expansion 0.82 complete).
# 821000 customers allocated (expansion 0.821 complete).
# 822000 customers allocated (expansion 0.822 complete).
# 823000 customers allocated (expansion 0.823 complete).
# 824000 customers allocated (expansion 0.824 complete).
# 825000 customers allocated (expansion 0.825 complete).
# 826000 customers allocated (expansion 0.826 complete).
# 827000 customers allocated (expansion 0.827 complete).
# 828000 customers allocated (expansion 0.828 complete).
# 829000 customers allocated (expansion 0.829 complete).
# 830000 customers allocated (expansion 0.83 complete).
# 831000 customers allocated (expansion 0.831 complete).
# 832000 customers allocated (expansion 0.832 complete).
# 833000 customers allocated (expansion 0.833 complete).
# 834000 customers allocated (expansion 0.834 complete).
# 835000 customers allocated (expansion 0.835 complete).
# 836000 customers allocated (expansion 0.836 complete).
# 837000 customers allocated (expansion 0.837 complete).
# 838000 customers allocated (expansion 0.838 complete).
# 839000 customers allocated (expansion 0.839 complete).
# 840000 customers allocated (expansion 0.84 complete).
# 841000 customers allocated (expansion 0.841 complete).
# 842000 customers allocated (expansion 0.842 complete).
# 843000 customers allocated (expansion 0.843 complete).
# 844000 customers allocated (expansion 0.844 complete).
# 845000 customers allocated (expansion 0.845 complete).
# 846000 customers allocated (expansion 0.846 complete).
# 847000 customers allocated (expansion 0.847 complete).
# 848000 customers allocated (expansion 0.848 complete).
# 849000 customers allocated (expansion 0.849 complete).
# 850000 customers allocated (expansion 0.85 complete).
# 851000 customers allocated (expansion 0.851 complete).
# 852000 customers allocated (expansion 0.852 complete).
# 853000 customers allocated (expansion 0.853 complete).
# 854000 customers allocated (expansion 0.854 complete).
# 855000 customers allocated (expansion 0.855 complete).
# 856000 customers allocated (expansion 0.856 complete).
# 857000 customers allocated (expansion 0.857 complete).
# 858000 customers allocated (expansion 0.858 complete).
# 859000 customers allocated (expansion 0.859 complete).
# 860000 customers allocated (expansion 0.86 complete).
# 861000 customers allocated (expansion 0.861 complete).
# 862000 customers allocated (expansion 0.862 complete).
# 863000 customers allocated (expansion 0.863 complete).
# 864000 customers allocated (expansion 0.864 complete).
# 865000 customers allocated (expansion 0.865 complete).
# 866000 customers allocated (expansion 0.866 complete).
# 867000 customers allocated (expansion 0.867 complete).
# 868000 customers allocated (expansion 0.868 complete).
# 869000 customers allocated (expansion 0.869 complete).
# 870000 customers allocated (expansion 0.87 complete).
# 871000 customers allocated (expansion 0.871 complete).
# 872000 customers allocated (expansion 0.872 complete).
# 873000 customers allocated (expansion 0.873 complete).
# 874000 customers allocated (expansion 0.874 complete).
# 875000 customers allocated (expansion 0.875 complete).
# 876000 customers allocated (expansion 0.876 complete).
# 877000 customers allocated (expansion 0.877 complete).
# 878000 customers allocated (expansion 0.878 complete).
# 879000 customers allocated (expansion 0.879 complete).
# 880000 customers allocated (expansion 0.88 complete).
# 881000 customers allocated (expansion 0.881 complete).
# 882000 customers allocated (expansion 0.882 complete).
# 883000 customers allocated (expansion 0.883 complete).
# 884000 customers allocated (expansion 0.884 complete).
# 885000 customers allocated (expansion 0.885 complete).
# 886000 customers allocated (expansion 0.886 complete).
# 887000 customers allocated (expansion 0.887 complete).
# 888000 customers allocated (expansion 0.888 complete).
# 889000 customers allocated (expansion 0.889 complete).
# 890000 customers allocated (expansion 0.89 complete).
# 891000 customers allocated (expansion 0.891 complete).
# 892000 customers allocated (expansion 0.892 complete).
# 893000 customers allocated (expansion 0.893 complete).
# 894000 customers allocated (expansion 0.894 complete).
# 895000 customers allocated (expansion 0.895 complete).
# 896000 customers allocated (expansion 0.896 complete).
# 897000 customers allocated (expansion 0.897 complete).
# 898000 customers allocated (expansion 0.898 complete).
# 899000 customers allocated (expansion 0.899 complete).
# 900000 customers allocated (expansion 0.9 complete).
# 901000 customers allocated (expansion 0.901 complete).
# 902000 customers allocated (expansion 0.902 complete).
# 903000 customers allocated (expansion 0.903 complete).
# 904000 customers allocated (expansion 0.904 complete).
# 905000 customers allocated (expansion 0.905 complete).
# 906000 customers allocated (expansion 0.906 complete).
# 907000 customers allocated (expansion 0.907 complete).
# 908000 customers allocated (expansion 0.908 complete).
# 909000 customers allocated (expansion 0.909 complete).
# 910000 customers allocated (expansion 0.91 complete).
# 911000 customers allocated (expansion 0.911 complete).
# 912000 customers allocated (expansion 0.912 complete).
# 913000 customers allocated (expansion 0.913 complete).
# 914000 customers allocated (expansion 0.914 complete).
# 915000 customers allocated (expansion 0.915 complete).
# 916000 customers allocated (expansion 0.916 complete).
# 917000 customers allocated (expansion 0.917 complete).
# 918000 customers allocated (expansion 0.918 complete).
# 919000 customers allocated (expansion 0.919 complete).
# 920000 customers allocated (expansion 0.92 complete).
# 921000 customers allocated (expansion 0.921 complete).
# 922000 customers allocated (expansion 0.922 complete).
# 923000 customers allocated (expansion 0.923 complete).
# 924000 customers allocated (expansion 0.924 complete).
# 925000 customers allocated (expansion 0.925 complete).
# 926000 customers allocated (expansion 0.926 complete).
# 927000 customers allocated (expansion 0.927 complete).
# 928000 customers allocated (expansion 0.928 complete).
# 929000 customers allocated (expansion 0.929 complete).
# 930000 customers allocated (expansion 0.93 complete).
# 931000 customers allocated (expansion 0.931 complete).
# 932000 customers allocated (expansion 0.932 complete).
# 933000 customers allocated (expansion 0.933 complete).
# 934000 customers allocated (expansion 0.934 complete).
# 935000 customers allocated (expansion 0.935 complete).
# 936000 customers allocated (expansion 0.936 complete).
# 937000 customers allocated (expansion 0.937 complete).
# 938000 customers allocated (expansion 0.938 complete).
# 939000 customers allocated (expansion 0.939 complete).
# 940000 customers allocated (expansion 0.94 complete).
# 941000 customers allocated (expansion 0.941 complete).
# 942000 customers allocated (expansion 0.942 complete).
# 943000 customers allocated (expansion 0.943 complete).
# 944000 customers allocated (expansion 0.944 complete).
# 945000 customers allocated (expansion 0.945 complete).
# 946000 customers allocated (expansion 0.946 complete).
# 947000 customers allocated (expansion 0.947 complete).
# 948000 customers allocated (expansion 0.948 complete).
# 949000 customers allocated (expansion 0.949 complete).
# 950000 customers allocated (expansion 0.95 complete).
# 951000 customers allocated (expansion 0.951 complete).
# 952000 customers allocated (expansion 0.952 complete).
# 953000 customers allocated (expansion 0.953 complete).
# 954000 customers allocated (expansion 0.954 complete).
# 955000 customers allocated (expansion 0.955 complete).
# 956000 customers allocated (expansion 0.956 complete).
# 957000 customers allocated (expansion 0.957 complete).
# 958000 customers allocated (expansion 0.958 complete).
# 959000 customers allocated (expansion 0.959 complete).
# 960000 customers allocated (expansion 0.96 complete).
# 961000 customers allocated (expansion 0.961 complete).
# 962000 customers allocated (expansion 0.962 complete).
# 963000 customers allocated (expansion 0.963 complete).
# 964000 customers allocated (expansion 0.964 complete).
# 965000 customers allocated (expansion 0.965 complete).
# 966000 customers allocated (expansion 0.966 complete).
# 967000 customers allocated (expansion 0.967 complete).
# 968000 customers allocated (expansion 0.968 complete).
# 969000 customers allocated (expansion 0.969 complete).
# 970000 customers allocated (expansion 0.97 complete).
# 971000 customers allocated (expansion 0.971 complete).
# 972000 customers allocated (expansion 0.972 complete).
# 973000 customers allocated (expansion 0.973 complete).
# 974000 customers allocated (expansion 0.974 complete).
# 975000 customers allocated (expansion 0.975 complete).
# 976000 customers allocated (expansion 0.976 complete).
# 977000 customers allocated (expansion 0.977 complete).
# 978000 customers allocated (expansion 0.978 complete).
# 979000 customers allocated (expansion 0.979 complete).
# 980000 customers allocated (expansion 0.98 complete).
# 981000 customers allocated (expansion 0.981 complete).
# 982000 customers allocated (expansion 0.982 complete).
# 983000 customers allocated (expansion 0.983 complete).
# 984000 customers allocated (expansion 0.984 complete).
# 985000 customers allocated (expansion 0.985 complete).
# 986000 customers allocated (expansion 0.986 complete).
# 987000 customers allocated (expansion 0.987 complete).
# 988000 customers allocated (expansion 0.988 complete).
# 989000 customers allocated (expansion 0.989 complete).
# 990000 customers allocated (expansion 0.99 complete).
# 991000 customers allocated (expansion 0.991 complete).
# 992000 customers allocated (expansion 0.992 complete).
# 993000 customers allocated (expansion 0.993 complete).
# 994000 customers allocated (expansion 0.994 complete).
# 995000 customers allocated (expansion 0.995 complete).
# 996000 customers allocated (expansion 0.996 complete).
# 997000 customers allocated (expansion 0.997 complete).
# 998000 customers allocated (expansion 0.998 complete).
# 999000 customers allocated (expansion 0.999 complete).
# 1000000 customers allocated (expansion 1.0 complete).
# Customer dataframe exploded to order dataframe.
# Orders randomly assigned to retailers.
# Noise added.
# 10517204 unique observations created.
# --- 250.62060267130533 minutes ---
