# %%
def create_sim_data(num_retailers, num_customers, treatment_effect, file_name):

    import os
    import random 
    import numpy as np
    import pandas as pd

    # Create retailers, their order amount scalars, and the probability space.
    retailer_ids = list(range(1, num_retailers + 1,1))
    retailer_scalars = list(np.random.normal(loc = 1, scale = 0.05, size = num_retailers))
    retailers = pd.DataFrame(list(zip(retailer_ids, retailer_scalars)), 
                             columns =['Retailer_ID', 'Retailer_Scalar']) 
    delimiters = list(np.linspace(0.0, 1.0, num = num_retailers + 1))
    retailers['a'] = delimiters[0:len(delimiters)-1]
    retailers['b'] = delimiters[1:len(delimiters)]
    print('Retailer data frame created.')
    
    # Create customers, their mean order amount, whether or not they got the treatment, 
    # and the number of orders placed.
    customer_ids = list(range(1, num_customers + 1,1))
    num_orders = [int(i*10) + 1 for i in list(np.random.exponential(scale = 1.0, size = num_customers))]
    customers = pd.DataFrame(list(zip(customer_ids, num_orders)), columns =['Customer_ID', 'N_Orders']) 
    customers['Mean_Order_Amt'] = list(np.random.normal(loc = 100, scale = 25, size = num_customers))
    customers['Mean_Order_Amt'] = customers['Mean_Order_Amt'].apply(lambda x: round(x, 2))
    treatment_probs = []
    for i in list(range(0, len(customers), 1)):
        treatment_probs.append(np.random.uniform())
    customers['Treatment_Prob'] = treatment_probs
    customers['Treated'] = np.where(customers['Treatment_Prob'] <= 0.5, 1, 0)
    customers['Treatment_Modifier'] = np.where(customers['Treatment_Prob'] <= 0.5, 1+treatment_effect, 1.0)
    customers = customers[['Customer_ID', 'N_Orders', 'Mean_Order_Amt', 'Treated', 'Treatment_Modifier']]
    print('Customer data frame created.')
    
    j = 0
    master_customer_entry = []
    for i in list(range(0, len(customers), 1)):
        counter = 1
        customer_entry = []
        while counter <= int(customers.loc[[i]]['N_Orders']):
            customer_entry.append(list(customers.loc[[i]].values)) 
            counter += 1
        master_customer_entry.append(customer_entry)    
        if i % 1000 == 0:
            j += 1
            print(str(j*1000) + ' customers allocated (expansion ' + \
                  '{} complete).'.format(str((j*1000)/num_customers)))
    newlist = [item for items in master_customer_entry for item in items]
    newlist = [item for items in newlist for item in items]
    explodedDF = pd.DataFrame(newlist)
    explodedDF.columns = ['Customer_ID', 'Num_Orders', 'Mean_Order_Amt', 'Treated', 'Treatment_Modifier']
    explodedDF = explodedDF[['Customer_ID', 'Mean_Order_Amt', 'Treated', 'Treatment_Modifier']]
    print('Customer dataframe exploded to order dataframe.')

    float_list = []
    for i in list(range(0, len(explodedDF), 1)):
        float_list.append(np.random.uniform())
    explodedDF['Retailer_Prob'] = float_list
    
    # Map the orders randomly to retailers and their correponding scalar.
    a = explodedDF.Retailer_Prob.values
    bh = retailers.b.values
    bl = retailers.a.values

    i, j = np.where((a[:, None] >= bl) & (a[:, None] <= bh))

    result_df = pd.DataFrame(
                np.column_stack([explodedDF.values[i], retailers.values[j]]),
                columns=explodedDF.columns.append(retailers.columns))
    result_df = result_df[['Customer_ID', 'Mean_Order_Amt', 'Treated', 'Treatment_Modifier','Retailer_ID', 
                           'Retailer_Scalar']]
    print('Orders randomly assigned to retailers.')
    
    
    # Add DoW 
    dow = []
    z = 0
    while z < len(result_df):
        dow.append(random.randint(1, 7))
        z += 1
        
    result_df['Dow_Rand'] = dow
    result_df['DOW'] = 0
    result_df['DOW'] = np.where(result_df['Dow_Rand'] == 1, 0.7, result_df['DOW'])    
    result_df['DOW'] = np.where(result_df['Dow_Rand'] == 2, 0.8, result_df['DOW'])  
    result_df['DOW'] = np.where(result_df['Dow_Rand'] == 3, 0.9, result_df['DOW'])  
    result_df['DOW'] = np.where(result_df['Dow_Rand'] == 4, 1.0, result_df['DOW'])  
    result_df['DOW'] = np.where(result_df['Dow_Rand'] == 5, 1.1, result_df['DOW'])  
    result_df['DOW'] = np.where(result_df['Dow_Rand'] == 6, 1.2, result_df['DOW'])  
    result_df['DOW'] = np.where(result_df['Dow_Rand'] == 7, 1.3, result_df['DOW'])  
    
    # Add random noise 
    result_df['Noise'] = list(np.random.normal(loc = 25.0, scale = 5.0, size = len(result_df)))
    result_df['Noise'] = result_df['Noise'].apply(lambda x: round(x, 2))
    result_df['Order_Amt'] = result_df['Mean_Order_Amt']*result_df['Treatment_Modifier']* \
                             result_df['Retailer_Scalar']*result_df['DOW'] + result_df['Noise']
    result_df['Order_Amt'] = result_df['Order_Amt'].apply(lambda x: round(x, 2))
    print('Noise added.')
    
    # Save to .csv
    print(str(len(result_df)) + ' unique observations created.')
    #result_df = result_df.sample(sample_size, replace=True)
    result_df = result_df.reset_index(drop=True)
    
    # Save to .csv
    if not os.path.exists('./residual_dfs'):
        os.makedirs('./residual_dfs')
    
    result_df.to_csv('./residual_dfs/' + file_name)
    print("{} was saved to disk.".format('./residual_dfs/' + file_name))

# %%
labels = ['part_II_df_mde_0_001_n_100000_c.csv']
mde = [0.05]

# %%
for i in list(range(0,len(labels))):
    import time
    start_time = time.time()
    create_sim_data(1000, 500000, mde[i], labels[i])
    print("--- {} minutes ---".format(str((time.time() - start_time)/60.0)))
# Out:
# Retailer data frame created.
# Customer data frame created.
# 1000 customers allocated (expansion 0.002 complete).
# 2000 customers allocated (expansion 0.004 complete).
# 3000 customers allocated (expansion 0.006 complete).
# 4000 customers allocated (expansion 0.008 complete).
# 5000 customers allocated (expansion 0.01 complete).
# 6000 customers allocated (expansion 0.012 complete).
# 7000 customers allocated (expansion 0.014 complete).
# 8000 customers allocated (expansion 0.016 complete).
# 9000 customers allocated (expansion 0.018 complete).
# 10000 customers allocated (expansion 0.02 complete).
# 11000 customers allocated (expansion 0.022 complete).
# 12000 customers allocated (expansion 0.024 complete).
# 13000 customers allocated (expansion 0.026 complete).
# 14000 customers allocated (expansion 0.028 complete).
# 15000 customers allocated (expansion 0.03 complete).
# 16000 customers allocated (expansion 0.032 complete).
# 17000 customers allocated (expansion 0.034 complete).
# 18000 customers allocated (expansion 0.036 complete).
# 19000 customers allocated (expansion 0.038 complete).
# 20000 customers allocated (expansion 0.04 complete).
# 21000 customers allocated (expansion 0.042 complete).
# 22000 customers allocated (expansion 0.044 complete).
# 23000 customers allocated (expansion 0.046 complete).
# 24000 customers allocated (expansion 0.048 complete).
# 25000 customers allocated (expansion 0.05 complete).
# 26000 customers allocated (expansion 0.052 complete).
# 27000 customers allocated (expansion 0.054 complete).
# 28000 customers allocated (expansion 0.056 complete).
# 29000 customers allocated (expansion 0.058 complete).
# 30000 customers allocated (expansion 0.06 complete).
# 31000 customers allocated (expansion 0.062 complete).
# 32000 customers allocated (expansion 0.064 complete).
# 33000 customers allocated (expansion 0.066 complete).
# 34000 customers allocated (expansion 0.068 complete).
# 35000 customers allocated (expansion 0.07 complete).
# 36000 customers allocated (expansion 0.072 complete).
# 37000 customers allocated (expansion 0.074 complete).
# 38000 customers allocated (expansion 0.076 complete).
# 39000 customers allocated (expansion 0.078 complete).
# 40000 customers allocated (expansion 0.08 complete).
# 41000 customers allocated (expansion 0.082 complete).
# 42000 customers allocated (expansion 0.084 complete).
# 43000 customers allocated (expansion 0.086 complete).
# 44000 customers allocated (expansion 0.088 complete).
# 45000 customers allocated (expansion 0.09 complete).
# 46000 customers allocated (expansion 0.092 complete).
# 47000 customers allocated (expansion 0.094 complete).
# 48000 customers allocated (expansion 0.096 complete).
# 49000 customers allocated (expansion 0.098 complete).
# 50000 customers allocated (expansion 0.1 complete).
# 51000 customers allocated (expansion 0.102 complete).
# 52000 customers allocated (expansion 0.104 complete).
# 53000 customers allocated (expansion 0.106 complete).
# 54000 customers allocated (expansion 0.108 complete).
# 55000 customers allocated (expansion 0.11 complete).
# 56000 customers allocated (expansion 0.112 complete).
# 57000 customers allocated (expansion 0.114 complete).
# 58000 customers allocated (expansion 0.116 complete).
# 59000 customers allocated (expansion 0.118 complete).
# 60000 customers allocated (expansion 0.12 complete).
# 61000 customers allocated (expansion 0.122 complete).
# 62000 customers allocated (expansion 0.124 complete).
# 63000 customers allocated (expansion 0.126 complete).
# 64000 customers allocated (expansion 0.128 complete).
# 65000 customers allocated (expansion 0.13 complete).
# 66000 customers allocated (expansion 0.132 complete).
# 67000 customers allocated (expansion 0.134 complete).
# 68000 customers allocated (expansion 0.136 complete).
# 69000 customers allocated (expansion 0.138 complete).
# 70000 customers allocated (expansion 0.14 complete).
# 71000 customers allocated (expansion 0.142 complete).
# 72000 customers allocated (expansion 0.144 complete).
# 73000 customers allocated (expansion 0.146 complete).
# 74000 customers allocated (expansion 0.148 complete).
# 75000 customers allocated (expansion 0.15 complete).
# 76000 customers allocated (expansion 0.152 complete).
# 77000 customers allocated (expansion 0.154 complete).
# 78000 customers allocated (expansion 0.156 complete).
# 79000 customers allocated (expansion 0.158 complete).
# 80000 customers allocated (expansion 0.16 complete).
# 81000 customers allocated (expansion 0.162 complete).
# 82000 customers allocated (expansion 0.164 complete).
# 83000 customers allocated (expansion 0.166 complete).
# 84000 customers allocated (expansion 0.168 complete).
# 85000 customers allocated (expansion 0.17 complete).
# 86000 customers allocated (expansion 0.172 complete).
# 87000 customers allocated (expansion 0.174 complete).
# 88000 customers allocated (expansion 0.176 complete).
# 89000 customers allocated (expansion 0.178 complete).
# 90000 customers allocated (expansion 0.18 complete).
# 91000 customers allocated (expansion 0.182 complete).
# 92000 customers allocated (expansion 0.184 complete).
# 93000 customers allocated (expansion 0.186 complete).
# 94000 customers allocated (expansion 0.188 complete).
# 95000 customers allocated (expansion 0.19 complete).
# 96000 customers allocated (expansion 0.192 complete).
# 97000 customers allocated (expansion 0.194 complete).
# 98000 customers allocated (expansion 0.196 complete).
# 99000 customers allocated (expansion 0.198 complete).
# 100000 customers allocated (expansion 0.2 complete).
# 101000 customers allocated (expansion 0.202 complete).
# 102000 customers allocated (expansion 0.204 complete).
# 103000 customers allocated (expansion 0.206 complete).
# 104000 customers allocated (expansion 0.208 complete).
# 105000 customers allocated (expansion 0.21 complete).
# 106000 customers allocated (expansion 0.212 complete).
# 107000 customers allocated (expansion 0.214 complete).
# 108000 customers allocated (expansion 0.216 complete).
# 109000 customers allocated (expansion 0.218 complete).
# 110000 customers allocated (expansion 0.22 complete).
# 111000 customers allocated (expansion 0.222 complete).
# 112000 customers allocated (expansion 0.224 complete).
# 113000 customers allocated (expansion 0.226 complete).
# 114000 customers allocated (expansion 0.228 complete).
# 115000 customers allocated (expansion 0.23 complete).
# 116000 customers allocated (expansion 0.232 complete).
# 117000 customers allocated (expansion 0.234 complete).
# 118000 customers allocated (expansion 0.236 complete).
# 119000 customers allocated (expansion 0.238 complete).
# 120000 customers allocated (expansion 0.24 complete).
# 121000 customers allocated (expansion 0.242 complete).
# 122000 customers allocated (expansion 0.244 complete).
# 123000 customers allocated (expansion 0.246 complete).
# 124000 customers allocated (expansion 0.248 complete).
# 125000 customers allocated (expansion 0.25 complete).
# 126000 customers allocated (expansion 0.252 complete).
# 127000 customers allocated (expansion 0.254 complete).
# 128000 customers allocated (expansion 0.256 complete).
# 129000 customers allocated (expansion 0.258 complete).
# 130000 customers allocated (expansion 0.26 complete).
# 131000 customers allocated (expansion 0.262 complete).
# 132000 customers allocated (expansion 0.264 complete).
# 133000 customers allocated (expansion 0.266 complete).
# 134000 customers allocated (expansion 0.268 complete).
# 135000 customers allocated (expansion 0.27 complete).
# 136000 customers allocated (expansion 0.272 complete).
# 137000 customers allocated (expansion 0.274 complete).
# 138000 customers allocated (expansion 0.276 complete).
# 139000 customers allocated (expansion 0.278 complete).
# 140000 customers allocated (expansion 0.28 complete).
# 141000 customers allocated (expansion 0.282 complete).
# 142000 customers allocated (expansion 0.284 complete).
# 143000 customers allocated (expansion 0.286 complete).
# 144000 customers allocated (expansion 0.288 complete).
# 145000 customers allocated (expansion 0.29 complete).
# 146000 customers allocated (expansion 0.292 complete).
# 147000 customers allocated (expansion 0.294 complete).
# 148000 customers allocated (expansion 0.296 complete).
# 149000 customers allocated (expansion 0.298 complete).
# 150000 customers allocated (expansion 0.3 complete).
# 151000 customers allocated (expansion 0.302 complete).
# 152000 customers allocated (expansion 0.304 complete).
# 153000 customers allocated (expansion 0.306 complete).
# 154000 customers allocated (expansion 0.308 complete).
# 155000 customers allocated (expansion 0.31 complete).
# 156000 customers allocated (expansion 0.312 complete).
# 157000 customers allocated (expansion 0.314 complete).
# 158000 customers allocated (expansion 0.316 complete).
# 159000 customers allocated (expansion 0.318 complete).
# 160000 customers allocated (expansion 0.32 complete).
# 161000 customers allocated (expansion 0.322 complete).
# 162000 customers allocated (expansion 0.324 complete).
# 163000 customers allocated (expansion 0.326 complete).
# 164000 customers allocated (expansion 0.328 complete).
# 165000 customers allocated (expansion 0.33 complete).
# 166000 customers allocated (expansion 0.332 complete).
# 167000 customers allocated (expansion 0.334 complete).
# 168000 customers allocated (expansion 0.336 complete).
# 169000 customers allocated (expansion 0.338 complete).
# 170000 customers allocated (expansion 0.34 complete).
# 171000 customers allocated (expansion 0.342 complete).
# 172000 customers allocated (expansion 0.344 complete).
# 173000 customers allocated (expansion 0.346 complete).
# 174000 customers allocated (expansion 0.348 complete).
# 175000 customers allocated (expansion 0.35 complete).
# 176000 customers allocated (expansion 0.352 complete).
# 177000 customers allocated (expansion 0.354 complete).
# 178000 customers allocated (expansion 0.356 complete).
# 179000 customers allocated (expansion 0.358 complete).
# 180000 customers allocated (expansion 0.36 complete).
# 181000 customers allocated (expansion 0.362 complete).
# 182000 customers allocated (expansion 0.364 complete).
# 183000 customers allocated (expansion 0.366 complete).
# 184000 customers allocated (expansion 0.368 complete).
# 185000 customers allocated (expansion 0.37 complete).
# 186000 customers allocated (expansion 0.372 complete).
# 187000 customers allocated (expansion 0.374 complete).
# 188000 customers allocated (expansion 0.376 complete).
# 189000 customers allocated (expansion 0.378 complete).
# 190000 customers allocated (expansion 0.38 complete).
# 191000 customers allocated (expansion 0.382 complete).
# 192000 customers allocated (expansion 0.384 complete).
# 193000 customers allocated (expansion 0.386 complete).
# 194000 customers allocated (expansion 0.388 complete).
# 195000 customers allocated (expansion 0.39 complete).
# 196000 customers allocated (expansion 0.392 complete).
# 197000 customers allocated (expansion 0.394 complete).
# 198000 customers allocated (expansion 0.396 complete).
# 199000 customers allocated (expansion 0.398 complete).
# 200000 customers allocated (expansion 0.4 complete).
# 201000 customers allocated (expansion 0.402 complete).
# 202000 customers allocated (expansion 0.404 complete).
# 203000 customers allocated (expansion 0.406 complete).
# 204000 customers allocated (expansion 0.408 complete).
# 205000 customers allocated (expansion 0.41 complete).
# 206000 customers allocated (expansion 0.412 complete).
# 207000 customers allocated (expansion 0.414 complete).
# 208000 customers allocated (expansion 0.416 complete).
# 209000 customers allocated (expansion 0.418 complete).
# 210000 customers allocated (expansion 0.42 complete).
# 211000 customers allocated (expansion 0.422 complete).
# 212000 customers allocated (expansion 0.424 complete).
# 213000 customers allocated (expansion 0.426 complete).
# 214000 customers allocated (expansion 0.428 complete).
# 215000 customers allocated (expansion 0.43 complete).
# 216000 customers allocated (expansion 0.432 complete).
# 217000 customers allocated (expansion 0.434 complete).
# 218000 customers allocated (expansion 0.436 complete).
# 219000 customers allocated (expansion 0.438 complete).
# 220000 customers allocated (expansion 0.44 complete).
# 221000 customers allocated (expansion 0.442 complete).
# 222000 customers allocated (expansion 0.444 complete).
# 223000 customers allocated (expansion 0.446 complete).
# 224000 customers allocated (expansion 0.448 complete).
# 225000 customers allocated (expansion 0.45 complete).
# 226000 customers allocated (expansion 0.452 complete).
# 227000 customers allocated (expansion 0.454 complete).
# 228000 customers allocated (expansion 0.456 complete).
# 229000 customers allocated (expansion 0.458 complete).
# 230000 customers allocated (expansion 0.46 complete).
# 231000 customers allocated (expansion 0.462 complete).
# 232000 customers allocated (expansion 0.464 complete).
# 233000 customers allocated (expansion 0.466 complete).
# 234000 customers allocated (expansion 0.468 complete).
# 235000 customers allocated (expansion 0.47 complete).
# 236000 customers allocated (expansion 0.472 complete).
# 237000 customers allocated (expansion 0.474 complete).
# 238000 customers allocated (expansion 0.476 complete).
# 239000 customers allocated (expansion 0.478 complete).
# 240000 customers allocated (expansion 0.48 complete).
# 241000 customers allocated (expansion 0.482 complete).
# 242000 customers allocated (expansion 0.484 complete).
# 243000 customers allocated (expansion 0.486 complete).
# 244000 customers allocated (expansion 0.488 complete).
# 245000 customers allocated (expansion 0.49 complete).
# 246000 customers allocated (expansion 0.492 complete).
# 247000 customers allocated (expansion 0.494 complete).
# 248000 customers allocated (expansion 0.496 complete).
# 249000 customers allocated (expansion 0.498 complete).
# 250000 customers allocated (expansion 0.5 complete).
# 251000 customers allocated (expansion 0.502 complete).
# 252000 customers allocated (expansion 0.504 complete).
# 253000 customers allocated (expansion 0.506 complete).
# 254000 customers allocated (expansion 0.508 complete).
# 255000 customers allocated (expansion 0.51 complete).
# 256000 customers allocated (expansion 0.512 complete).
# 257000 customers allocated (expansion 0.514 complete).
# 258000 customers allocated (expansion 0.516 complete).
# 259000 customers allocated (expansion 0.518 complete).
# 260000 customers allocated (expansion 0.52 complete).
# 261000 customers allocated (expansion 0.522 complete).
# 262000 customers allocated (expansion 0.524 complete).
# 263000 customers allocated (expansion 0.526 complete).
# 264000 customers allocated (expansion 0.528 complete).
# 265000 customers allocated (expansion 0.53 complete).
# 266000 customers allocated (expansion 0.532 complete).
# 267000 customers allocated (expansion 0.534 complete).
# 268000 customers allocated (expansion 0.536 complete).
# 269000 customers allocated (expansion 0.538 complete).
# 270000 customers allocated (expansion 0.54 complete).
# 271000 customers allocated (expansion 0.542 complete).
# 272000 customers allocated (expansion 0.544 complete).
# 273000 customers allocated (expansion 0.546 complete).
# 274000 customers allocated (expansion 0.548 complete).
# 275000 customers allocated (expansion 0.55 complete).
# 276000 customers allocated (expansion 0.552 complete).
# 277000 customers allocated (expansion 0.554 complete).
# 278000 customers allocated (expansion 0.556 complete).
# 279000 customers allocated (expansion 0.558 complete).
# 280000 customers allocated (expansion 0.56 complete).
# 281000 customers allocated (expansion 0.562 complete).
# 282000 customers allocated (expansion 0.564 complete).
# 283000 customers allocated (expansion 0.566 complete).
# 284000 customers allocated (expansion 0.568 complete).
# 285000 customers allocated (expansion 0.57 complete).
# 286000 customers allocated (expansion 0.572 complete).
# 287000 customers allocated (expansion 0.574 complete).
# 288000 customers allocated (expansion 0.576 complete).
# 289000 customers allocated (expansion 0.578 complete).
# 290000 customers allocated (expansion 0.58 complete).
# 291000 customers allocated (expansion 0.582 complete).
# 292000 customers allocated (expansion 0.584 complete).
# 293000 customers allocated (expansion 0.586 complete).
# 294000 customers allocated (expansion 0.588 complete).
# 295000 customers allocated (expansion 0.59 complete).
# 296000 customers allocated (expansion 0.592 complete).
# 297000 customers allocated (expansion 0.594 complete).
# 298000 customers allocated (expansion 0.596 complete).
# 299000 customers allocated (expansion 0.598 complete).
# 300000 customers allocated (expansion 0.6 complete).
# 301000 customers allocated (expansion 0.602 complete).
# 302000 customers allocated (expansion 0.604 complete).
# 303000 customers allocated (expansion 0.606 complete).
# 304000 customers allocated (expansion 0.608 complete).
# 305000 customers allocated (expansion 0.61 complete).
# 306000 customers allocated (expansion 0.612 complete).
# 307000 customers allocated (expansion 0.614 complete).
# 308000 customers allocated (expansion 0.616 complete).
# 309000 customers allocated (expansion 0.618 complete).
# 310000 customers allocated (expansion 0.62 complete).
# 311000 customers allocated (expansion 0.622 complete).
# 312000 customers allocated (expansion 0.624 complete).
# 313000 customers allocated (expansion 0.626 complete).
# 314000 customers allocated (expansion 0.628 complete).
# 315000 customers allocated (expansion 0.63 complete).
# 316000 customers allocated (expansion 0.632 complete).
# 317000 customers allocated (expansion 0.634 complete).
# 318000 customers allocated (expansion 0.636 complete).
# 319000 customers allocated (expansion 0.638 complete).
# 320000 customers allocated (expansion 0.64 complete).
# 321000 customers allocated (expansion 0.642 complete).
# 322000 customers allocated (expansion 0.644 complete).
# 323000 customers allocated (expansion 0.646 complete).
# 324000 customers allocated (expansion 0.648 complete).
# 325000 customers allocated (expansion 0.65 complete).
# 326000 customers allocated (expansion 0.652 complete).
# 327000 customers allocated (expansion 0.654 complete).
# 328000 customers allocated (expansion 0.656 complete).
# 329000 customers allocated (expansion 0.658 complete).
# 330000 customers allocated (expansion 0.66 complete).
# 331000 customers allocated (expansion 0.662 complete).
# 332000 customers allocated (expansion 0.664 complete).
# 333000 customers allocated (expansion 0.666 complete).
# 334000 customers allocated (expansion 0.668 complete).
# 335000 customers allocated (expansion 0.67 complete).
# 336000 customers allocated (expansion 0.672 complete).
# 337000 customers allocated (expansion 0.674 complete).
# 338000 customers allocated (expansion 0.676 complete).
# 339000 customers allocated (expansion 0.678 complete).
# 340000 customers allocated (expansion 0.68 complete).
# 341000 customers allocated (expansion 0.682 complete).
# 342000 customers allocated (expansion 0.684 complete).
# 343000 customers allocated (expansion 0.686 complete).
# 344000 customers allocated (expansion 0.688 complete).
# 345000 customers allocated (expansion 0.69 complete).
# 346000 customers allocated (expansion 0.692 complete).
# 347000 customers allocated (expansion 0.694 complete).
# 348000 customers allocated (expansion 0.696 complete).
# 349000 customers allocated (expansion 0.698 complete).
# 350000 customers allocated (expansion 0.7 complete).
# 351000 customers allocated (expansion 0.702 complete).
# 352000 customers allocated (expansion 0.704 complete).
# 353000 customers allocated (expansion 0.706 complete).
# 354000 customers allocated (expansion 0.708 complete).
# 355000 customers allocated (expansion 0.71 complete).
# 356000 customers allocated (expansion 0.712 complete).
# 357000 customers allocated (expansion 0.714 complete).
# 358000 customers allocated (expansion 0.716 complete).
# 359000 customers allocated (expansion 0.718 complete).
# 360000 customers allocated (expansion 0.72 complete).
# 361000 customers allocated (expansion 0.722 complete).
# 362000 customers allocated (expansion 0.724 complete).
# 363000 customers allocated (expansion 0.726 complete).
# 364000 customers allocated (expansion 0.728 complete).
# 365000 customers allocated (expansion 0.73 complete).
# 366000 customers allocated (expansion 0.732 complete).
# 367000 customers allocated (expansion 0.734 complete).
# 368000 customers allocated (expansion 0.736 complete).
# 369000 customers allocated (expansion 0.738 complete).
# 370000 customers allocated (expansion 0.74 complete).
# 371000 customers allocated (expansion 0.742 complete).
# 372000 customers allocated (expansion 0.744 complete).
# 373000 customers allocated (expansion 0.746 complete).
# 374000 customers allocated (expansion 0.748 complete).
# 375000 customers allocated (expansion 0.75 complete).
# 376000 customers allocated (expansion 0.752 complete).
# 377000 customers allocated (expansion 0.754 complete).
# 378000 customers allocated (expansion 0.756 complete).
# 379000 customers allocated (expansion 0.758 complete).
# 380000 customers allocated (expansion 0.76 complete).
# 381000 customers allocated (expansion 0.762 complete).
# 382000 customers allocated (expansion 0.764 complete).
# 383000 customers allocated (expansion 0.766 complete).
# 384000 customers allocated (expansion 0.768 complete).
# 385000 customers allocated (expansion 0.77 complete).
# 386000 customers allocated (expansion 0.772 complete).
# 387000 customers allocated (expansion 0.774 complete).
# 388000 customers allocated (expansion 0.776 complete).
# 389000 customers allocated (expansion 0.778 complete).
# 390000 customers allocated (expansion 0.78 complete).
# 391000 customers allocated (expansion 0.782 complete).
# 392000 customers allocated (expansion 0.784 complete).
# 393000 customers allocated (expansion 0.786 complete).
# 394000 customers allocated (expansion 0.788 complete).
# 395000 customers allocated (expansion 0.79 complete).
# 396000 customers allocated (expansion 0.792 complete).
# 397000 customers allocated (expansion 0.794 complete).
# 398000 customers allocated (expansion 0.796 complete).
# 399000 customers allocated (expansion 0.798 complete).
# 400000 customers allocated (expansion 0.8 complete).
# 401000 customers allocated (expansion 0.802 complete).
# 402000 customers allocated (expansion 0.804 complete).
# 403000 customers allocated (expansion 0.806 complete).
# 404000 customers allocated (expansion 0.808 complete).
# 405000 customers allocated (expansion 0.81 complete).
# 406000 customers allocated (expansion 0.812 complete).
# 407000 customers allocated (expansion 0.814 complete).
# 408000 customers allocated (expansion 0.816 complete).
# 409000 customers allocated (expansion 0.818 complete).
# 410000 customers allocated (expansion 0.82 complete).
# 411000 customers allocated (expansion 0.822 complete).
# 412000 customers allocated (expansion 0.824 complete).
# 413000 customers allocated (expansion 0.826 complete).
# 414000 customers allocated (expansion 0.828 complete).
# 415000 customers allocated (expansion 0.83 complete).
# 416000 customers allocated (expansion 0.832 complete).
# 417000 customers allocated (expansion 0.834 complete).
# 418000 customers allocated (expansion 0.836 complete).
# 419000 customers allocated (expansion 0.838 complete).
# 420000 customers allocated (expansion 0.84 complete).
# 421000 customers allocated (expansion 0.842 complete).
# 422000 customers allocated (expansion 0.844 complete).
# 423000 customers allocated (expansion 0.846 complete).
# 424000 customers allocated (expansion 0.848 complete).
# 425000 customers allocated (expansion 0.85 complete).
# 426000 customers allocated (expansion 0.852 complete).
# 427000 customers allocated (expansion 0.854 complete).
# 428000 customers allocated (expansion 0.856 complete).
# 429000 customers allocated (expansion 0.858 complete).
# 430000 customers allocated (expansion 0.86 complete).
# 431000 customers allocated (expansion 0.862 complete).
# 432000 customers allocated (expansion 0.864 complete).
# 433000 customers allocated (expansion 0.866 complete).
# 434000 customers allocated (expansion 0.868 complete).
# 435000 customers allocated (expansion 0.87 complete).
# 436000 customers allocated (expansion 0.872 complete).
# 437000 customers allocated (expansion 0.874 complete).
# 438000 customers allocated (expansion 0.876 complete).
# 439000 customers allocated (expansion 0.878 complete).
# 440000 customers allocated (expansion 0.88 complete).
# 441000 customers allocated (expansion 0.882 complete).
# 442000 customers allocated (expansion 0.884 complete).
# 443000 customers allocated (expansion 0.886 complete).
# 444000 customers allocated (expansion 0.888 complete).
# 445000 customers allocated (expansion 0.89 complete).
# 446000 customers allocated (expansion 0.892 complete).
# 447000 customers allocated (expansion 0.894 complete).
# 448000 customers allocated (expansion 0.896 complete).
# 449000 customers allocated (expansion 0.898 complete).
# 450000 customers allocated (expansion 0.9 complete).
# 451000 customers allocated (expansion 0.902 complete).
# 452000 customers allocated (expansion 0.904 complete).
# 453000 customers allocated (expansion 0.906 complete).
# 454000 customers allocated (expansion 0.908 complete).
# 455000 customers allocated (expansion 0.91 complete).
# 456000 customers allocated (expansion 0.912 complete).
# 457000 customers allocated (expansion 0.914 complete).
# 458000 customers allocated (expansion 0.916 complete).
# 459000 customers allocated (expansion 0.918 complete).
# 460000 customers allocated (expansion 0.92 complete).
# 461000 customers allocated (expansion 0.922 complete).
# 462000 customers allocated (expansion 0.924 complete).
# 463000 customers allocated (expansion 0.926 complete).
# 464000 customers allocated (expansion 0.928 complete).
# 465000 customers allocated (expansion 0.93 complete).
# 466000 customers allocated (expansion 0.932 complete).
# 467000 customers allocated (expansion 0.934 complete).
# 468000 customers allocated (expansion 0.936 complete).
# 469000 customers allocated (expansion 0.938 complete).
# 470000 customers allocated (expansion 0.94 complete).
# 471000 customers allocated (expansion 0.942 complete).
# 472000 customers allocated (expansion 0.944 complete).
# 473000 customers allocated (expansion 0.946 complete).
# 474000 customers allocated (expansion 0.948 complete).
# 475000 customers allocated (expansion 0.95 complete).
# 476000 customers allocated (expansion 0.952 complete).
# 477000 customers allocated (expansion 0.954 complete).
# 478000 customers allocated (expansion 0.956 complete).
# 479000 customers allocated (expansion 0.958 complete).
# 480000 customers allocated (expansion 0.96 complete).
# 481000 customers allocated (expansion 0.962 complete).
# 482000 customers allocated (expansion 0.964 complete).
# 483000 customers allocated (expansion 0.966 complete).
# 484000 customers allocated (expansion 0.968 complete).
# 485000 customers allocated (expansion 0.97 complete).
# 486000 customers allocated (expansion 0.972 complete).
# 487000 customers allocated (expansion 0.974 complete).
# 488000 customers allocated (expansion 0.976 complete).
# 489000 customers allocated (expansion 0.978 complete).
# 490000 customers allocated (expansion 0.98 complete).
# 491000 customers allocated (expansion 0.982 complete).
# 492000 customers allocated (expansion 0.984 complete).
# 493000 customers allocated (expansion 0.986 complete).
# 494000 customers allocated (expansion 0.988 complete).
# 495000 customers allocated (expansion 0.99 complete).
# 496000 customers allocated (expansion 0.992 complete).
# 497000 customers allocated (expansion 0.994 complete).
# 498000 customers allocated (expansion 0.996 complete).
# 499000 customers allocated (expansion 0.998 complete).
# 500000 customers allocated (expansion 1.0 complete).
# Customer dataframe exploded to order dataframe.
# Orders randomly assigned to retailers.
# Noise added.
# 5245412 unique observations created.
# ./residual_dfs/part_II_df_mde_0_001_n_100000_c.csv was saved to disk.
# --- 129.4960591673851 minutes ---
