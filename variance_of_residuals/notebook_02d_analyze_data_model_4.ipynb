# %%
def create_sample_size_rec(data_src, data_labels, rejection_region, desired_power):
    
    import random
    import numpy as np
    import pandas as pd
    import statsmodels.api as sm
    
    data_src.columns = data_labels
    
    absolute_mde = data_src[data_src['Treated'] == 1]['Order_Amt'].mean() - \
                   data_src[data_src['Treated'] == 0]['Order_Amt'].mean()

    
    print("The absolute MDE was estimated as {}.".format(absolute_mde))
    
    df = data_src[data_src['Treated'] == 0]
    assignment = []
    i = 0
    while i < len(df):
        assignment.append(random.randint(0,1)) 
        i += 1
    df['Partition'] = assignment
    power_analysis_df = df[df['Partition'] == 0]
    analysis_df = df[df['Partition'] == 1]

    del df                     
    
    analysis_df = analysis_df[['Order_Amt', 'Customer_ID']]
    analysis_df = sm.add_constant(analysis_df)

    X = analysis_df[['const']]
    Y = analysis_df[['Order_Amt']]
    residuals_df = sm.OLS(Y.astype(float), X.astype(float)).fit()

    
    X2 = analysis_df[['Customer_ID']]
    X2['Residual'] = residuals_df.resid
    X2['Constant'] = 1
    clustered_res = sm.OLS(X2['Residual'], X2['Constant']).fit(method='pinv'). \
                       get_robustcov_results('cluster', groups = X2['Customer_ID'], 
                       use_correction=True, df_correction=True)
    
    clustered_sd = clustered_res.bse[0] * np.sqrt(analysis_df.shape[0])
    effect_size = absolute_mde / clustered_sd
    recommended_n = int(sm.stats.tt_ind_solve_power(effect_size = effect_size, 
                        alpha = rejection_region, power = desired_power, 
                        alternative = 'larger'))
    print("A sample size of {} was recommended.".format(recommended_n ))
    return recommended_n, absolute_mde

# %%
def verify_sample_size_est(sample_size, data_src, data_labels, alpha, verify_n_times):

    import statsmodels.api as sm
    import pandas as pd
    
    SAMPLE_SIZE = sample_size
    VERIFICATION_ITERATIONS = verify_n_times
    ALPHA = alpha

    i = 0
    pvals  = []
    r_sqr  = []
    cond_n = []
    while i < VERIFICATION_ITERATIONS:
        working_df = data_src.sample(SAMPLE_SIZE, replace=False)
        ###############################################################################
        pa_dow_means = pd.DataFrame(working_df.groupby(['Dow_Rand'])['Order_Amt'].mean())
        pa_dow_means.reset_index(inplace=True)
        pa_dow_means.columns = ['Dow_Rand', 'Mean_DOW_Order_Amt']
        ###############################################################################
        analysis_df = pd.merge(working_df, pa_dow_means, on='Dow_Rand', how='left')
        ###############################################################################
        analysis_df = analysis_df[['Order_Amt', 'Customer_ID', 'Treated', 'Mean_Order_Amt', 
                                   'Mean_DOW_Order_Amt']]
        ###############################################################################
        X = analysis_df[['Treated']]
        X = sm.add_constant(X)
        Y = analysis_df[['Order_Amt']]
        model = sm.OLS(Y.astype(float), X.astype(float)).fit(method='pinv'). \
                       get_robustcov_results('cluster', groups = analysis_df['Customer_ID'], 
                       use_correction=True, df_correction=True)
        if model.pvalues[1] < ALPHA: 
            pvals.append(1)
        else:
            pvals.append(0)  
        r_sqr.append(model.rsquared_adj)
        cond_n.append(model.condition_number)
        i += 1
        if i % int((VERIFICATION_ITERATIONS)/10.0) == 0:
            completion = str(round((i/VERIFICATION_ITERATIONS)*100, 2))+'%'
            print(completion + ' complete.')
            
    # ----- Exit inner loop     
    x = ['Treated']
    str_out = 'Order_Amt =' 
    d = 0
    for i in x:
        if d < 1:
            k = " '" + i + "'"
        else:
            k = " + '" + i + "'"
        str_out += k
        d += 1    
    
    actual_power = sum(pvals)/len(pvals)  
    mean_r_sqr   = sum(r_sqr)/len(r_sqr)   
    mean_cond_n  = sum(cond_n)/len(cond_n)  
    print("Actual power was estimated at {}.".format(actual_power))
    return actual_power, mean_r_sqr, mean_cond_n, str_out

# %%
def meta_assess(sub_iterations, meta_iterations, alpha, target_power, 
                pa_file, analysis_file, file_name):

    ALPHA = alpha
    SUB_ITERATIONS = sub_iterations
    META_ITERATIONS = meta_iterations
    TARGET_POWER = target_power

    dir = './residual_dfs/'
    import pandas as pd
    import os

    i = 0
    results      = []
    r_sqr_list   = []
    cond_n_list  = []
    abs_mde      = []
    sample_sizes = []
    while i < META_ITERATIONS:

        data_src_a = pd.read_csv(dir + pa_file)
        data_src_b = pd.read_csv(dir + analysis_file)
        data_labels = ['Order_ID', 'Customer_ID', 'Mean_Order_Amt', 'Treated',
                       'Treatment_Modifier', 'Retailer_ID', 'Retailer_Scalar',
                       'Dow_Rand', 'DOW', 'Noise', 'Order_Amt']

        recommended_n, absolute_mde = create_sample_size_rec(data_src_a, data_labels, 
                                               ALPHA, TARGET_POWER)

        actual_power,r_sqr,mean_cond_n, str_out = verify_sample_size_est(recommended_n, data_src_b, 
                                                  data_labels, ALPHA, SUB_ITERATIONS)   

        results.append(actual_power)
        r_sqr_list.append(r_sqr)
        cond_n_list.append(mean_cond_n)
        abs_mde.append(absolute_mde)
        sample_sizes.append(recommended_n)
        i += 1
        print("{} of {} iterations completed.".format(i, META_ITERATIONS))
    results                          = pd.DataFrame(results)    
    results['Target Power']          = TARGET_POWER
    results.columns                  = ['Achieved Power', 'Target Power']
    results['Abs. MDE']              = absolute_mde
    results['Model']                 = str_out
    results['Delta']                 = results['Achieved Power'] - results['Target Power']
    results['N']                     = sample_sizes
    results['Mean_R_Sqr']            = r_sqr_list
    results['Mean_Condition_Number'] = cond_n_list

        # Save to .csv
    if not os.path.exists('./residual_dfs/results'):
        os.makedirs('./residual_dfs/results')
    
    results.to_csv('./residual_dfs/results/' + file_name)
    print("{} was saved to disk.".format('./residual_dfs/results/' + file_name))

# %%
meta_assess(500, 100, 0.05, 0.8, 
            'part_II_df_mde_0_005_n_100000_a.csv', 
            'part_II_df_mde_0_005_n_100000_b.csv', 
            'mde_0_005_n_100000_model_IV.csv')
# Out:
# The absolute MDE was estimated as 0.42411496603367027.
# /home/bknight/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/bknight/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# A sample size of 494783 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.68.
# 1 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 493669 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.66.
# 2 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 489048 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.664.
# 3 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 489430 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.646.
# 4 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 493068 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.698.
# 5 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 491712 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.684.
# 6 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 486230 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.648.
# 7 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 492923 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.692.
# 8 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 487684 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.682.
# 9 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 489588 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.674.
# 10 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 494440 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.678.
# 11 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 491857 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.73.
# 12 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 493015 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.66.
# 13 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 488108 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.626.
# 14 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 491358 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.708.
# 15 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 495273 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.68.
# 16 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 490610 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.644.
# 17 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 490332 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.674.
# 18 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 493393 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.666.
# 19 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 488565 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.634.
# 20 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 489283 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.688.
# 21 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 494263 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.7.
# 22 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 490486 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.704.
# 23 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 493865 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.65.
# 24 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 496534 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.684.
# 25 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 494167 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.68.
# 26 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 493458 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.688.
# 27 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 492920 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.65.
# 28 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 489228 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.656.
# 29 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 492642 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.694.
# 30 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 497650 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.702.
# 31 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 488812 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.638.
# 32 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 495372 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.68.
# 33 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 492150 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.748.
# 34 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 491707 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.696.
# 35 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 492711 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.656.
# 36 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 494543 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.692.
# 37 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 489441 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.674.
# 38 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 489604 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.672.
# 39 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 489954 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.672.
# 40 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 491649 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.656.
# 41 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 496051 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.694.
# 42 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 489169 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.674.
# 43 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 494642 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.694.
# 44 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 488602 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.678.
# 45 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 489376 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.702.
# 46 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 491200 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.696.
# 47 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 489146 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.672.
# 48 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 487911 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.698.
# 49 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 486434 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.688.
# 50 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 492565 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.672.
# 51 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 489133 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.61.
# 52 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 492891 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.668.
# 53 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 492878 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.66.
# 54 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 490918 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.648.
# 55 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 490764 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.664.
# 56 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 499407 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.674.
# 57 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 495696 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.66.
# 58 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 488752 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.674.
# 59 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 491505 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.684.
# 60 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 496618 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.686.
# 61 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 488112 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.66.
# 62 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 488076 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.696.
# 63 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 494999 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.666.
# 64 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 488032 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.668.
# 65 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 496324 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.656.
# 66 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 497250 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.636.
# 67 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 487636 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.712.
# 68 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 490211 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.658.
# 69 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 489980 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.692.
# 70 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 496644 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.708.
# 71 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 489272 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.682.
# 72 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 493119 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.698.
# 73 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 493414 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.674.
# 74 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 492351 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.636.
# 75 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 489212 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.664.
# 76 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 492854 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.704.
# 77 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 489665 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.67.
# 78 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 490613 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.704.
# 79 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 490169 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.712.
# 80 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 491787 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.668.
# 81 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 492092 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.652.
# 82 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 485588 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.694.
# 83 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 485991 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.682.
# 84 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 493556 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.668.
# 85 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 486632 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.698.
# 86 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 492011 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.692.
# 87 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 495325 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.684.
# 88 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 491366 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.64.
# 89 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 488639 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.68.
# 90 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 490936 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.718.
# 91 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 486382 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.652.
# 92 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 488789 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.648.
# 93 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 493471 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.662.
# 94 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 494430 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.678.
# 95 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 495268 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.658.
# 96 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 489158 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.662.
# 97 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 491198 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.664.
# 98 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 491190 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.72.
# 99 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 491943 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.654.
# 100 of 100 iterations completed.
# ./residual_dfs/results/mde_0_005_n_100000_model_IV.csv was saved to disk.
