# %%
def create_sample_size_rec(data_src, data_labels, rejection_region, desired_power):
    
    import random
    import numpy as np
    import pandas as pd
    import statsmodels.api as sm
    
    data_src.columns = data_labels
    
    absolute_mde = data_src[data_src['Treated'] == 1]['Order_Amt'].mean() - \
                   data_src[data_src['Treated'] == 0]['Order_Amt'].mean()

    
    print("The absolute MDE was estimated as {}.".format(absolute_mde))
    
    df = data_src[data_src['Treated'] == 0]
    assignment = []
    i = 0
    while i < len(df):
        assignment.append(random.randint(0,1)) 
        i += 1
    df['Partition'] = assignment
    power_analysis_df = df[df['Partition'] == 0]
    analysis_df = df[df['Partition'] == 1]

    del df                     
    
    analysis_df = analysis_df[['Order_Amt', 'Customer_ID']]
    analysis_df = sm.add_constant(analysis_df)

    X = analysis_df[['const']]
    Y = analysis_df[['Order_Amt']]
    residuals_df = sm.OLS(Y.astype(float), X.astype(float)).fit()

    
    X2 = analysis_df[['Customer_ID']]
    X2['Residual'] = residuals_df.resid
    X2['Constant'] = 1
    clustered_res = sm.OLS(X2['Residual'], X2['Constant']).fit(method='pinv'). \
                       get_robustcov_results('cluster', groups = X2['Customer_ID'], 
                       use_correction=True, df_correction=True)
    
    clustered_sd = clustered_res.bse[0] * np.sqrt(analysis_df.shape[0])
    effect_size = absolute_mde / clustered_sd
    recommended_n = int(sm.stats.tt_ind_solve_power(effect_size = effect_size, 
                        alpha = rejection_region, power = desired_power, 
                        alternative = 'larger'))
    print("A sample size of {} was recommended.".format(recommended_n ))
    return recommended_n, absolute_mde

# %%
def verify_sample_size_est(sample_size, data_src, data_labels, alpha, verify_n_times):

    import statsmodels.api as sm
    import pandas as pd
    
    SAMPLE_SIZE = sample_size
    VERIFICATION_ITERATIONS = verify_n_times
    ALPHA = alpha

    i = 0
    pvals  = []
    r_sqr  = []
    cond_n = []
    while i < VERIFICATION_ITERATIONS:
        working_df = data_src.sample(SAMPLE_SIZE, replace=False)
        ###############################################################################
        pa_dow_means = pd.DataFrame(working_df.groupby(['Dow_Rand'])['Order_Amt'].mean())
        pa_dow_means.reset_index(inplace=True)
        pa_dow_means.columns = ['Dow_Rand', 'Mean_DOW_Order_Amt']
        ###############################################################################
        analysis_df = pd.merge(working_df, pa_dow_means, on='Dow_Rand', how='left')
        ###############################################################################
        analysis_df = analysis_df[['Order_Amt', 'Customer_ID', 'Treated', 'Mean_Order_Amt', 
                                   'Mean_DOW_Order_Amt']]
        ###############################################################################
        X = analysis_df[['Treated']]
        X = sm.add_constant(X)
        Y = analysis_df[['Order_Amt']]
        model = sm.OLS(Y.astype(float), X.astype(float)).fit(method='pinv'). \
                       get_robustcov_results('cluster', groups = analysis_df['Customer_ID'], 
                       use_correction=True, df_correction=True)
        if model.pvalues[1] < ALPHA: 
            pvals.append(1)
        else:
            pvals.append(0)  
        r_sqr.append(model.rsquared_adj)
        cond_n.append(model.condition_number)
        i += 1
        if i % int((VERIFICATION_ITERATIONS)/10.0) == 0:
            completion = str(round((i/VERIFICATION_ITERATIONS)*100, 2))+'%'
            print(completion + ' complete.')
            
    # ----- Exit inner loop     
    x = ['Treated']
    str_out = 'Order_Amt =' 
    d = 0
    for i in x:
        if d < 1:
            k = " '" + i + "'"
        else:
            k = " + '" + i + "'"
        str_out += k
        d += 1    
    
    actual_power = sum(pvals)/len(pvals)  
    mean_r_sqr   = sum(r_sqr)/len(r_sqr)   
    mean_cond_n  = sum(cond_n)/len(cond_n)  
    print("Actual power was estimated at {}.".format(actual_power))
    return actual_power, mean_r_sqr, mean_cond_n, str_out

# %%
def meta_assess(sub_iterations, meta_iterations, alpha, target_power, 
                pa_file, analysis_file, file_name):

    ALPHA = alpha
    SUB_ITERATIONS = sub_iterations
    META_ITERATIONS = meta_iterations
    TARGET_POWER = target_power

    dir = './residual_dfs/'
    import pandas as pd
    import os

    i = 0
    results      = []
    r_sqr_list   = []
    cond_n_list  = []
    abs_mde      = []
    sample_sizes = []
    while i < META_ITERATIONS:

        data_src_a = pd.read_csv(dir + pa_file)
        data_src_b = pd.read_csv(dir + analysis_file)
        data_labels = ['Order_ID', 'Customer_ID', 'Mean_Order_Amt', 'Treated',
                       'Treatment_Modifier', 'Retailer_ID', 'Retailer_Scalar',
                       'Dow_Rand', 'DOW', 'Noise', 'Order_Amt']

        recommended_n, absolute_mde = create_sample_size_rec(data_src_a, data_labels, 
                                               ALPHA, TARGET_POWER)

        actual_power,r_sqr,mean_cond_n, str_out = verify_sample_size_est(recommended_n, data_src_b, 
                                                  data_labels, ALPHA, SUB_ITERATIONS)   

        results.append(actual_power)
        r_sqr_list.append(r_sqr)
        cond_n_list.append(mean_cond_n)
        abs_mde.append(absolute_mde)
        sample_sizes.append(recommended_n)
        i += 1
        print("{} of {} iterations completed.".format(i, META_ITERATIONS))
    results                          = pd.DataFrame(results)    
    results['Target Power']          = TARGET_POWER
    results.columns                  = ['Achieved Power', 'Target Power']
    results['Abs. MDE']              = absolute_mde
    results['Model']                 = str_out
    results['Delta']                 = results['Achieved Power'] - results['Target Power']
    results['N']                     = sample_sizes
    results['Mean_R_Sqr']            = r_sqr_list
    results['Mean_Condition_Number'] = cond_n_list

        # Save to .csv
    if not os.path.exists('./residual_dfs/results'):
        os.makedirs('./residual_dfs/results')
    
    results.to_csv('./residual_dfs/results/' + file_name)
    print("{} was saved to disk.".format('./residual_dfs/results/' + file_name))

# %%
meta_assess(500, 100, 0.05, 0.8, 
            'part_II_df_mde_0_01_n_100000_a.csv', 
            'part_II_df_mde_0_01_n_100000_b.csv', 
            'mde_0_01_n_100000_model_IV.csv')
# Out:
# The absolute MDE was estimated as 1.0092294331238776.
# /home/bknight/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/bknight/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# A sample size of 89075 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.978.
# 1 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89674 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.982.
# 2 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 90294 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.992.
# 3 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88665 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.98.
# 4 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88531 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.992.
# 5 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88535 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.986.
# 6 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88145 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.988.
# 7 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89214 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.982.
# 8 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89109 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.99.
# 9 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88700 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.98.
# 10 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88174 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.98.
# 11 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89765 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 1.0.
# 12 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89664 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.982.
# 13 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89041 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.98.
# 14 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88849 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.982.
# 15 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88816 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.994.
# 16 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89135 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.988.
# 17 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89561 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.988.
# 18 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88527 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.984.
# 19 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88631 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.984.
# 20 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89053 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.988.
# 21 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89048 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.988.
# 22 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88320 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.992.
# 23 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89234 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.992.
# 24 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89325 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.986.
# 25 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88597 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.982.
# 26 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89447 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.992.
# 27 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88851 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.984.
# 28 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88932 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.992.
# 29 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89439 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.992.
# 30 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88219 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.998.
# 31 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89119 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.988.
# 32 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88728 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.978.
# 33 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89303 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.99.
# 34 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88868 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.986.
# 35 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88760 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.982.
# 36 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88785 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.978.
# 37 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89276 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.984.
# 38 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89140 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.986.
# 39 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89489 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.982.
# 40 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89658 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.988.
# 41 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88583 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.986.
# 42 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88348 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.982.
# 43 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89008 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.98.
# 44 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88639 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.986.
# 45 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89874 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.994.
# 46 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88746 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.986.
# 47 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89645 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.99.
# 48 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89033 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.978.
# 49 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88127 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.988.
# 50 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88086 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.98.
# 51 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89270 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.986.
# 52 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89745 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.986.
# 53 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89521 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.99.
# 54 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88882 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.984.
# 55 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88730 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.986.
# 56 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89640 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.984.
# 57 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89223 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.972.
# 58 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88807 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.988.
# 59 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88290 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.996.
# 60 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89237 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.988.
# 61 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88716 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.986.
# 62 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89147 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.99.
# 63 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89351 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.984.
# 64 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 87664 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.976.
# 65 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89327 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.984.
# 66 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 87846 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.988.
# 67 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88984 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.986.
# 68 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89394 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.984.
# 69 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88672 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.986.
# 70 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88491 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.986.
# 71 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88657 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.99.
# 72 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88272 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.986.
# 73 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89013 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.992.
# 74 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88266 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.978.
# 75 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88993 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.99.
# 76 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88515 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.99.
# 77 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88619 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.988.
# 78 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88654 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.984.
# 79 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88048 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.992.
# 80 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88744 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.978.
# 81 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89518 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.988.
# 82 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89277 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.992.
# 83 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89271 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.988.
# 84 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88793 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.976.
# 85 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89627 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.982.
# 86 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89288 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.988.
# 87 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88310 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.98.
# 88 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89698 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.986.
# 89 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88867 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.986.
# 90 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88749 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.99.
# 91 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88783 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.984.
# 92 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88758 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.982.
# 93 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 89487 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.988.
# 94 of 100 iterations completed.
# The absolute MDE was estimated as 1.0092294331238776.
# A sample size of 88968 was recommended.
# 10.0% complete.
