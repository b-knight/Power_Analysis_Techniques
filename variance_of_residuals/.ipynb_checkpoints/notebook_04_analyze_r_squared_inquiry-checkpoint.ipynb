# %%
import pandas as pd

# %%
df1a = pd.read_csv("./residual_dfs/results/mde_0_05_n_100000_model_I.csv") 
df1b = pd.read_csv("./residual_dfs/results/mde_0_05_n_100000_model_II.csv")
df1c = pd.read_csv("./residual_dfs/results/mde_0_05_n_100000_model_III.csv") 
df1d = pd.read_csv("./residual_dfs/results/mde_0_05_n_100000_model_IV.csv")
df2a = pd.read_csv("./residual_dfs/results/mde_0_025_n_100000_model_I.csv") 
df2b = pd.read_csv("./residual_dfs/results/mde_0_025_n_100000_model_II.csv")
df2c = pd.read_csv("./residual_dfs/results/mde_0_025_n_100000_model_III.csv") 
df2d = pd.read_csv("./residual_dfs/results/mde_0_025_n_100000_model_IV.csv")
df3a = pd.read_csv("./residual_dfs/results/mde_0_01_n_100000_model_I.csv") 
df3b = pd.read_csv("./residual_dfs/results/mde_0_01_n_100000_model_II.csv")
df3c = pd.read_csv("./residual_dfs/results/mde_0_01_n_100000_model_III.csv") 
df3d = pd.read_csv("./residual_dfs/results/mde_0_01_n_100000_model_IV.csv")
df4a = pd.read_csv("./residual_dfs/results/mde_0_005_n_100000_model_I.csv") 
df4b = pd.read_csv("./residual_dfs/results/mde_0_005_n_100000_model_II.csv")
df4c = pd.read_csv("./residual_dfs/results/mde_0_005_n_100000_model_III.csv") 
df4d = pd.read_csv("./residual_dfs/results/mde_0_005_n_100000_model_IV.csv")
df = pd.concat([df1a, df1b], axis=0)
df = pd.concat([df,   df1c], axis=0)
df = pd.concat([df,   df1d], axis=0)
df = pd.concat([df,   df2a], axis=0)
df = pd.concat([df,   df2b], axis=0)
df = pd.concat([df,   df2c], axis=0)
df = pd.concat([df,   df2d], axis=0)
df = pd.concat([df,   df3a], axis=0)
df = pd.concat([df,   df3b], axis=0)
df = pd.concat([df,   df3c], axis=0)
df = pd.concat([df,   df3d], axis=0)
df = pd.concat([df,   df4a], axis=0)
df = pd.concat([df,   df4b], axis=0)
df = pd.concat([df,   df4c], axis=0)
df = pd.concat([df,   df4d], axis=0)

# %%
df4d
# Out:
#     Unnamed: 0  Achieved Power  Target Power  Abs. MDE  \
# 0            0           0.680           0.8  0.424115
# 1            1           0.660           0.8  0.424115
# 2            2           0.664           0.8  0.424115
# 3            3           0.646           0.8  0.424115
# 4            4           0.698           0.8  0.424115
# 5            5           0.684           0.8  0.424115
# 6            6           0.648           0.8  0.424115
# 7            7           0.692           0.8  0.424115
# 8            8           0.682           0.8  0.424115
# 9            9           0.674           0.8  0.424115
# 10          10           0.678           0.8  0.424115
# 11          11           0.730           0.8  0.424115
# 12          12           0.660           0.8  0.424115
# 13          13           0.626           0.8  0.424115
# 14          14           0.708           0.8  0.424115
# 15          15           0.680           0.8  0.424115
# 16          16           0.644           0.8  0.424115
# 17          17           0.674           0.8  0.424115
# 18          18           0.666           0.8  0.424115
# 19          19           0.634           0.8  0.424115
# 20          20           0.688           0.8  0.424115
# 21          21           0.700           0.8  0.424115
# 22          22           0.704           0.8  0.424115
# 23          23           0.650           0.8  0.424115
# 24          24           0.684           0.8  0.424115
# 25          25           0.680           0.8  0.424115
# 26          26           0.688           0.8  0.424115
# 27          27           0.650           0.8  0.424115
# 28          28           0.656           0.8  0.424115
# 29          29           0.694           0.8  0.424115
# ..         ...             ...           ...       ...
# 70          70           0.708           0.8  0.424115
# 71          71           0.682           0.8  0.424115
# 72          72           0.698           0.8  0.424115
# 73          73           0.674           0.8  0.424115
# 74          74           0.636           0.8  0.424115
# 75          75           0.664           0.8  0.424115
# 76          76           0.704           0.8  0.424115
# 77          77           0.670           0.8  0.424115
# 78          78           0.704           0.8  0.424115
# 79          79           0.712           0.8  0.424115
# 80          80           0.668           0.8  0.424115
# 81          81           0.652           0.8  0.424115
# 82          82           0.694           0.8  0.424115
# 83          83           0.682           0.8  0.424115
# 84          84           0.668           0.8  0.424115
# 85          85           0.698           0.8  0.424115
# 86          86           0.692           0.8  0.424115
# 87          87           0.684           0.8  0.424115
# 88          88           0.640           0.8  0.424115
# 89          89           0.680           0.8  0.424115
# 90          90           0.718           0.8  0.424115
# 91          91           0.652           0.8  0.424115
# 92          92           0.648           0.8  0.424115
# 93          93           0.662           0.8  0.424115
# 94          94           0.678           0.8  0.424115
# 95          95           0.658           0.8  0.424115
# 96          96           0.662           0.8  0.424115
# 97          97           0.664           0.8  0.424115
# 98          98           0.720           0.8  0.424115
# 99          99           0.654           0.8  0.424115
#
#                      Model  Delta       N  Mean_R_Sqr  Mean_Condition_Number
# 0   Order_Amt = 'Treated'  -0.120  494783    0.000053               2.623340
# 1   Order_Amt = 'Treated'  -0.140  493669    0.000053               2.623378
# 2   Order_Amt = 'Treated'  -0.136  489048    0.000053               2.623238
# 3   Order_Amt = 'Treated'  -0.154  489430    0.000052               2.623339
# 4   Order_Amt = 'Treated'  -0.102  493068    0.000054               2.623360
# 5   Order_Amt = 'Treated'  -0.116  491712    0.000054               2.623422
# 6   Order_Amt = 'Treated'  -0.152  486230    0.000052               2.623385
# 7   Order_Amt = 'Treated'  -0.108  492923    0.000054               2.623402
# 8   Order_Amt = 'Treated'  -0.118  487684    0.000054               2.623307
# 9   Order_Amt = 'Treated'  -0.126  489588    0.000053               2.623329
# 10  Order_Amt = 'Treated'  -0.122  494440    0.000054               2.623372
# 11  Order_Amt = 'Treated'  -0.070  491857    0.000055               2.623292
# 12  Order_Amt = 'Treated'  -0.140  493015    0.000051               2.623379
# 13  Order_Amt = 'Treated'  -0.174  488108    0.000052               2.623394
# 14  Order_Amt = 'Treated'  -0.092  491358    0.000055               2.623308
# 15  Order_Amt = 'Treated'  -0.120  495273    0.000053               2.623366
# 16  Order_Amt = 'Treated'  -0.156  490610    0.000052               2.623363
# 17  Order_Amt = 'Treated'  -0.126  490332    0.000054               2.623382
# 18  Order_Amt = 'Treated'  -0.134  493393    0.000053               2.623307
# 19  Order_Amt = 'Treated'  -0.166  488565    0.000052               2.623375
# 20  Order_Amt = 'Treated'  -0.112  489283    0.000053               2.623436
# 21  Order_Amt = 'Treated'  -0.100  494263    0.000054               2.623365
# 22  Order_Amt = 'Treated'  -0.096  490486    0.000053               2.623329
# 23  Order_Amt = 'Treated'  -0.150  493865    0.000052               2.623293
# 24  Order_Amt = 'Treated'  -0.116  496534    0.000053               2.623282
# 25  Order_Amt = 'Treated'  -0.120  494167    0.000054               2.623422
# 26  Order_Amt = 'Treated'  -0.112  493458    0.000053               2.623359
# 27  Order_Amt = 'Treated'  -0.150  492920    0.000053               2.623392
# 28  Order_Amt = 'Treated'  -0.144  489228    0.000052               2.623340
# 29  Order_Amt = 'Treated'  -0.106  492642    0.000053               2.623320
# ..                     ...    ...     ...         ...                    ...
# 70  Order_Amt = 'Treated'  -0.092  496644    0.000053               2.623289
# 71  Order_Amt = 'Treated'  -0.118  489272    0.000053               2.623313
# 72  Order_Amt = 'Treated'  -0.102  493119    0.000054               2.623374
# 73  Order_Amt = 'Treated'  -0.126  493414    0.000054               2.623351
# 74  Order_Amt = 'Treated'  -0.164  492351    0.000051               2.623330
# 75  Order_Amt = 'Treated'  -0.136  489212    0.000053               2.623298
# 76  Order_Amt = 'Treated'  -0.096  492854    0.000053               2.623391
# 77  Order_Amt = 'Treated'  -0.130  489665    0.000053               2.623434
# 78  Order_Amt = 'Treated'  -0.096  490613    0.000053               2.623239
# 79  Order_Amt = 'Treated'  -0.088  490169    0.000054               2.623336
# 80  Order_Amt = 'Treated'  -0.132  491787    0.000053               2.623457
# 81  Order_Amt = 'Treated'  -0.148  492092    0.000052               2.623335
# 82  Order_Amt = 'Treated'  -0.106  485588    0.000054               2.623305
# 83  Order_Amt = 'Treated'  -0.118  485991    0.000054               2.623367
# 84  Order_Amt = 'Treated'  -0.132  493556    0.000053               2.623366
# 85  Order_Amt = 'Treated'  -0.102  486632    0.000054               2.623355
# 86  Order_Amt = 'Treated'  -0.108  492011    0.000054               2.623379
# 87  Order_Amt = 'Treated'  -0.116  495325    0.000053               2.623283
# 88  Order_Amt = 'Treated'  -0.160  491366    0.000053               2.623279
# 89  Order_Amt = 'Treated'  -0.120  488639    0.000054               2.623270
# 90  Order_Amt = 'Treated'  -0.082  490936    0.000054               2.623415
# 91  Order_Amt = 'Treated'  -0.148  486382    0.000052               2.623338
# 92  Order_Amt = 'Treated'  -0.152  488789    0.000053               2.623433
# 93  Order_Amt = 'Treated'  -0.138  493471    0.000053               2.623291
# 94  Order_Amt = 'Treated'  -0.122  494430    0.000053               2.623360
# 95  Order_Amt = 'Treated'  -0.142  495268    0.000053               2.623321
# 96  Order_Amt = 'Treated'  -0.138  489158    0.000053               2.623450
# 97  Order_Amt = 'Treated'  -0.136  491198    0.000053               2.623324
# 98  Order_Amt = 'Treated'  -0.080  491190    0.000054               2.623292
# 99  Order_Amt = 'Treated'  -0.146  491943    0.000052               2.623289
#
# [100 rows x 9 columns]

# %%
len(df)
# Out:
# 1600

# %%
df.head()
# Out:
#    Unnamed: 0  Achieved Power  Target Power  Abs. MDE  \
# 0           0           0.082           0.8  4.678331
# 1           1           0.064           0.8  4.678331
# 2           2           0.096           0.8  4.678331
# 3           3           0.072           0.8  4.678331
# 4           4           0.084           0.8  4.678331
#
#                                                Model  Delta   N  Mean_R_Sqr  \
# 0  Order_Amt = 'Treated' + 'Mean_Order_Amt' + 'Me... -0.718  32    0.989774
# 1  Order_Amt = 'Treated' + 'Mean_Order_Amt' + 'Me... -0.736  31    0.990991
# 2  Order_Amt = 'Treated' + 'Mean_Order_Amt' + 'Me... -0.704  31    0.989640
# 3  Order_Amt = 'Treated' + 'Mean_Order_Amt' + 'Me... -0.728  32    0.989298
# 4  Order_Amt = 'Treated' + 'Mean_Order_Amt' + 'Me... -0.716  31    0.989237
#
#    Mean_Condition_Number
# 0            2007.391194
# 1            2004.171273
# 2            2003.509725
# 3            1984.253844
# 4            2031.952146

# %%
df['Model'].unique()
# Out:
# array(["Order_Amt = 'Treated' + 'Mean_Order_Amt' + 'Mean_Retailer_Order_Amt' + 'Mean_DOW_Order_Amt'",
#        "Order_Amt = 'Treated' + 'Mean_Retailer_Order_Amt' + 'Mean_DOW_Order_Amt'",
#        "Order_Amt = 'Treated' + 'Mean_DOW_Order_Amt'",
#        "Order_Amt = 'Treated'", "Order_Amt = 'Treated' "], dtype=object)

# %%
df[df['Model'] == df['Model'].unique()[2]].groupby('Abs. MDE')['Mean_R_Sqr'].mean()
# Out:
# Abs. MDE
# 0.424115    0.362256
# 1.009229    0.360700
# 2.386897    0.363232
# 4.678331    0.366688
# Name: Mean_R_Sqr, dtype: float64

# %%
df[df['Model'] == df['Model'].unique()[2]].groupby('Abs. MDE')['Delta'].mean()
# Out:
# Abs. MDE
# 0.424115    0.10548
# 1.009229    0.19938
# 2.386897    0.19968
# 4.678331    0.19960
# Name: Delta, dtype: float64

# %%
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.nonparametric.smoothers_lowess import lowess
import matplotlib.patches as patches

import matplotlib as mpl 
mpl.use('agg')
# %matplotlib inline

import matplotlib.pyplot as plt 
from matplotlib import rc, rcParams

rcParams['text.latex.preamble'] = [r'\usepackage{sfmath} \boldmath']
rc('text', usetex=True)
rc('axes', linewidth=2)
rc('font', weight='bold')

fig = plt.figure(1, figsize=(12, 5))
ax  = fig.add_subplot(111)


x = df['Mean_R_Sqr']
y = df['Delta']

area = np.pi*25
plt.scatter(x, y, s=area, alpha=0.05)
plt.xlabel(r"\textbf{Adjusted R-Squared}", size = 18)
plt.ylabel(r" \phantom{aa}\textbf{Delta:} \\\\ \phantom{aa}Desired \\\\ \phantom{aa}Power - \\\\"
           + r" \phantom{a}Achieved \\\\ \phantom{aa}Power",
           rotation = 0, 
           labelpad = 60,
           size = 20)

ax.yaxis.set_label_coords(-0.12,0.4)
ax.tick_params(axis='y', which='major', labelsize=16)
ax.tick_params(axis='x', which='major', labelsize=16)

smoothed = lowess(y, x, is_sorted=False, delta=0.01, frac=1.0, it=0)
plt.plot(smoothed[:,0], smoothed[:,1], 'black', ls='--')

plt.figtext(.5,0.98,'Impact of Multicollinearity on Power Estimation (LOWESS)', 
            fontsize=30, ha='center')
plt.figtext(.5,.91,'Inappropriate model specification leads to drastic underestimation of required sample size.',
            fontsize=20, ha='center')

rect1 = patches.Rectangle((0.92,-0.78),0.1,0.5, linewidth=1, edgecolor='r',facecolor='none')
rect2 = patches.Rectangle((-0.025, -0.19),0.05,0.42, linewidth=1, edgecolor='r',facecolor='none')
rect3 = patches.Rectangle((0.35, 0.06),0.025, 0.17, linewidth=1, edgecolor='r',facecolor='none')
rect4 = patches.Rectangle((0.38, 0.10),0.13, 0.13, linewidth=1, edgecolor='r',facecolor='none')
ax.add_patch(rect1)
ax.add_patch(rect2)
ax.add_patch(rect3)
ax.add_patch(rect4)


plt.annotate(r"\textbf{Model IV}",
             xy=(160, 190), 
             xycoords='figure pixels',
             fontsize=14)

plt.annotate(r"\textbf{Model III}",
             xy=(345, 255), 
             xycoords='figure pixels',
             fontsize=14)

plt.annotate(r"\textbf{Model II}",
             xy=(400, 268), 
             xycoords='figure pixels',
             fontsize=14)

plt.annotate(r"\textbf{Model I}",
             xy=(720, 190), 
             xycoords='figure pixels',
             fontsize=14)

plt.show()

# %% [markdown]
# https://jakevdp.github.io/PythonDataScienceHandbook/04.12-three-dimensional-plotting.html

# %%
# %matplotlib inline
# import matplotlib.pyplot as plt
# plt.style.use('seaborn-white')
# import numpy as np

# %%
# x = df['Mean_Condition_Number']
# y = df['Abs. MDE']

# X, Y = np.meshgrid(x, y)

# list_out =[]
# for i in range(0, len(df['Delta'])):
#     list_out.append(list(df['Delta'].abs()))
# Z = np.array(list_out)

# plt.contour(X, Y, Z, colors='black');
