# %%
def create_sample_size_rec(data_src, data_labels, rejection_region, desired_power):
    
    import random
    import numpy as np
    import pandas as pd
    import statsmodels.api as sm
    
    data_src.columns = data_labels
    
    absolute_mde = data_src[data_src['Treated'] == 1]['Order_Amt'].mean() - \
                   data_src[data_src['Treated'] == 0]['Order_Amt'].mean()

    
    print("The absolute MDE was estimated as {}.".format(absolute_mde))
    
    df = data_src[data_src['Treated'] == 0]
    assignment = []
    i = 0
    while i < len(df):
        assignment.append(random.randint(0,1)) 
        i += 1
    df['Partition'] = assignment
    power_analysis_df = df[df['Partition'] == 0]
    analysis_df = df[df['Partition'] == 1]
        
    del df
    
    pa_retailer_means = pd.DataFrame(power_analysis_df.groupby(['Retailer_ID'])['Order_Amt'].mean())
    pa_retailer_means.reset_index(inplace=True)
    pa_retailer_means.columns = ['Retailer_ID', 'Mean_Retailer_Order_Amt']
    ###############################################################################
    pa_dow_means = pd.DataFrame(power_analysis_df.groupby(['Dow_Rand'])['Order_Amt'].mean())
    pa_dow_means.reset_index(inplace=True)
    pa_dow_means.columns = ['Dow_Rand', 'Mean_DOW_Order_Amt']
    ###############################################################################
    analysis_df = pd.merge(analysis_df, pa_retailer_means, on='Retailer_ID', how='left')
    analysis_df = pd.merge(analysis_df, pa_dow_means, on='Dow_Rand', how='left')
    ###############################################################################
    analysis_df = analysis_df[['Order_Amt', 'Customer_ID', 'Mean_Retailer_Order_Amt',
                               'Mean_DOW_Order_Amt']]
    
    X = analysis_df[['Mean_Retailer_Order_Amt','Mean_DOW_Order_Amt']]
    X = sm.add_constant(X)
    Y = analysis_df[['Order_Amt']]
    residuals_df = sm.OLS(Y.astype(float), X.astype(float)).fit()
    
    X2 = analysis_df[['Customer_ID']]
    X2['Residual'] = residuals_df.resid
    X2['Constant'] = 1
    clustered_res = sm.OLS(X2['Residual'], X2['Constant']).fit(method='pinv'). \
                       get_robustcov_results('cluster', groups = X2['Customer_ID'], 
                       use_correction=True, df_correction=True)
    
    clustered_sd = clustered_res.bse[0] * np.sqrt(analysis_df.shape[0])
    effect_size = absolute_mde / clustered_sd
    recommended_n = int(sm.stats.tt_ind_solve_power(effect_size = effect_size, 
                        alpha = rejection_region, power = desired_power, 
                        alternative = 'larger'))
    print("A sample size of {} was recommended.".format(recommended_n ))
    return recommended_n, absolute_mde

# %%
def verify_sample_size_est(sample_size, data_src, data_labels, alpha, verify_n_times):

    import statsmodels.api as sm
    import pandas as pd
    
    SAMPLE_SIZE = sample_size
    VERIFICATION_ITERATIONS = verify_n_times
    ALPHA = alpha

    i = 0
    pvals  = []
    r_sqr  = []
    cond_n = []
    while i < VERIFICATION_ITERATIONS:
        working_df = data_src.sample(SAMPLE_SIZE, replace=False)
        ###############################################################################
        pa_retailer_means = pd.DataFrame(working_df.groupby(['Retailer_ID'])['Order_Amt'].mean())
        pa_retailer_means.reset_index(inplace=True)
        pa_retailer_means.columns = ['Retailer_ID', 'Mean_Retailer_Order_Amt']
        ###############################################################################
        pa_dow_means = pd.DataFrame(working_df.groupby(['Dow_Rand'])['Order_Amt'].mean())
        pa_dow_means.reset_index(inplace=True)
        pa_dow_means.columns = ['Dow_Rand', 'Mean_DOW_Order_Amt']
        ###############################################################################
        analysis_df = pd.merge(working_df, pa_retailer_means, on='Retailer_ID', how='left')
        analysis_df = pd.merge(analysis_df, pa_dow_means, on='Dow_Rand', how='left')
        ###############################################################################
        analysis_df = analysis_df[['Order_Amt', 'Customer_ID', 'Treated', 'Mean_Order_Amt', 
                                 'Mean_Retailer_Order_Amt','Mean_DOW_Order_Amt']]
        ###############################################################################
        X = analysis_df[['Treated', 'Mean_Retailer_Order_Amt','Mean_DOW_Order_Amt']]
        X = sm.add_constant(X)
        Y = analysis_df[['Order_Amt']]
        model = sm.OLS(Y.astype(float), X.astype(float)).fit(method='pinv'). \
                       get_robustcov_results('cluster', groups = analysis_df['Customer_ID'], 
                       use_correction=True, df_correction=True)
        if model.pvalues[1] < ALPHA: 
            pvals.append(1)
        else:
            pvals.append(0)  
        r_sqr.append(model.rsquared_adj)
        cond_n.append(model.condition_number)
        i += 1
        if i % int((VERIFICATION_ITERATIONS)/10.0) == 0:
            completion = str(round((i/VERIFICATION_ITERATIONS)*100, 2))+'%'
            print(completion + ' complete.')
            
    # ----- Exit inner loop     
    x = ['Treated', 'Mean_Retailer_Order_Amt','Mean_DOW_Order_Amt']
    str_out = 'Order_Amt =' 
    d = 0
    for i in x:
        if d < 1:
            k = " '" + i + "'"
        else:
            k = " + '" + i + "'"
        str_out += k
        d += 1    
    
    actual_power = sum(pvals)/len(pvals)  
    mean_r_sqr   = sum(r_sqr)/len(r_sqr)   
    mean_cond_n  = sum(cond_n)/len(cond_n)  
    print("Actual power was estimated at {}.".format(actual_power))
    return actual_power, mean_r_sqr, mean_cond_n, str_out

# %%
def meta_assess(sub_iterations, meta_iterations, alpha, target_power, 
                pa_file, analysis_file, file_name):

    ALPHA = alpha
    SUB_ITERATIONS = sub_iterations
    META_ITERATIONS = meta_iterations
    TARGET_POWER = target_power

    dir = './residual_dfs/'
    import pandas as pd
    import os

    i = 0
    results      = []
    r_sqr_list   = []
    cond_n_list  = []
    abs_mde      = []
    sample_sizes = []
    while i < META_ITERATIONS:

        data_src_a = pd.read_csv(dir + pa_file)
        data_src_b = pd.read_csv(dir + analysis_file)
        data_labels = ['Order_ID', 'Customer_ID', 'Mean_Order_Amt', 'Treated',
                       'Treatment_Modifier', 'Retailer_ID', 'Retailer_Scalar',
                       'Dow_Rand', 'DOW', 'Noise', 'Order_Amt']

        recommended_n, absolute_mde = create_sample_size_rec(data_src_a, data_labels, 
                                               ALPHA, TARGET_POWER)

        actual_power,r_sqr,mean_cond_n, str_out = verify_sample_size_est(recommended_n, data_src_b, 
                                                  data_labels, ALPHA, SUB_ITERATIONS)   

        results.append(actual_power)
        r_sqr_list.append(r_sqr)
        cond_n_list.append(mean_cond_n)
        abs_mde.append(absolute_mde)
        sample_sizes.append(recommended_n)
        i += 1
        print("{} of {} iterations completed.".format(i, META_ITERATIONS))
    results                          = pd.DataFrame(results)    
    results['Target Power']          = TARGET_POWER
    results.columns                  = ['Achieved Power', 'Target Power']
    results['Abs. MDE']              = absolute_mde
    results['Model']                 = str_out
    results['Delta']                 = results['Achieved Power'] - results['Target Power']
    results['N']                     = sample_sizes
    results['Mean_R_Sqr']            = r_sqr_list
    results['Mean_Condition_Number'] = cond_n_list

        # Save to .csv
    if not os.path.exists('./residual_dfs/results'):
        os.makedirs('./residual_dfs/results')
    
    results.to_csv('./residual_dfs/results/' + file_name)
    print("{} was saved to disk.".format('./residual_dfs/results/' + file_name))

# %%
meta_assess(500, 100, 0.05, 0.8, 
            'part_II_df_mde_0_01_n_100000_a.csv', 
            'part_II_df_mde_0_01_n_100000_b.csv', 
            'mde_0_01_n_100000_model_II.csv')
# Out:
# The absolute MDE was estimated as 0.42411496603367027.
# /home/bknight/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/bknight/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/bknight/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# A sample size of 461642 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.948.
# 1 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 463384 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.96.
# 2 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 459433 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.946.
# 3 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 460829 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.948.
# 4 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 458055 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.938.
# 5 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 461534 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.938.
# 6 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 461673 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.94.
# 7 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 460239 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.952.
# 8 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 462154 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.964.
# 9 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 457595 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.934.
# 10 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 460260 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.944.
# 11 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 455405 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.932.
# 12 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 462853 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.932.
# 13 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 464279 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.94.
# 14 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 459939 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.936.
# 15 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 460969 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.94.
# 16 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 458040 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.95.
# 17 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 458977 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.928.
# 18 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 455261 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.946.
# 19 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 456281 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.944.
# 20 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 461630 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.928.
# 21 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 457092 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.944.
# 22 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 460840 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.95.
# 23 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 458304 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.932.
# 24 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 460408 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.95.
# 25 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 460022 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.924.
# 26 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 460634 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.934.
# 27 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 458948 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.938.
# 28 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 462383 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.946.
# 29 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 460214 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.952.
# 30 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 456387 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.94.
# 31 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 458955 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.908.
# 32 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 460196 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.946.
# 33 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 465518 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.95.
# 34 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 461939 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.938.
# 35 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 460111 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.932.
# 36 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 461523 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.946.
# 37 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 457139 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.954.
# 38 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 458861 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.944.
# 39 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 458262 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.944.
# 40 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 462172 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.936.
# 41 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 461158 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.958.
# 42 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 461282 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.942.
# 43 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 458104 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.934.
# 44 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 460348 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.942.
# 45 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 459070 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.934.
# 46 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 460586 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.944.
# 47 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 461050 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.936.
# 48 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 462047 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.924.
# 49 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 459123 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.934.
# 50 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 458394 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.948.
# 51 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 456877 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.962.
# 52 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 461760 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.95.
# 53 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 463753 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.944.
# 54 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 459969 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.946.
# 55 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 459774 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.93.
# 56 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 463070 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.944.
# 57 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 460447 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.954.
# 58 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 461058 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.954.
# 59 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 462307 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.948.
# 60 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 459240 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.938.
# 61 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 458527 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.938.
# 62 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 466545 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.932.
# 63 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 464243 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.952.
# 64 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 458085 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.944.
# 65 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 454600 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.924.
# 66 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 462933 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.942.
# 67 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 456879 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.952.
# 68 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 461477 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.948.
# 69 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 461847 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.958.
# 70 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 461133 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.946.
# 71 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 459720 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.944.
# 72 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 461662 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.956.
# 73 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 457479 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.93.
# 74 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 458089 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.944.
# 75 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 457208 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.946.
# 76 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 459058 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.936.
# 77 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 459923 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.944.
# 78 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 460087 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.956.
# 79 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 459942 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.934.
# 80 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 461669 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.926.
# 81 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 459104 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.958.
# 82 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 460559 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.948.
# 83 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 459489 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.958.
# 84 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 458546 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.946.
# 85 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 460062 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.948.
# 86 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 460886 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.952.
# 87 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 462606 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.948.
# 88 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 460561 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.966.
# 89 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 461018 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.946.
# 90 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 458032 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.932.
# 91 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 460123 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.932.
# 92 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 459679 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.942.
# 93 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 463549 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.938.
# 94 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 460182 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.93.
# 95 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 461199 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.948.
# 96 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 464279 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.94.
# 97 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 460829 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.962.
# 98 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 462605 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.938.
# 99 of 100 iterations completed.
# The absolute MDE was estimated as 0.42411496603367027.
# A sample size of 458983 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.966.
# 100 of 100 iterations completed.
# ./residual_dfs/results/mde_0_005_n_100000_model_II.csv was saved to disk.
