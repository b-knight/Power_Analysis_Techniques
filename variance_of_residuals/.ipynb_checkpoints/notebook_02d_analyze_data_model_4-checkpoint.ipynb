# %%
def create_sample_size_rec(data_src, data_labels, rejection_region, desired_power, absolute_mde):
    
    import random
    import numpy as np
    import pandas as pd
    import statsmodels.api as sm
    
    data_src.columns = data_labels
    
#     absolute_mde = data_src[data_src['Treated'] == 1]['Order_Amt'].mean() - \
#                    data_src[data_src['Treated'] == 0]['Order_Amt'].mean()

    
    print("The absolute MDE was estimated as {}.".format(absolute_mde))
    
    df = data_src[data_src['Treated'] == 0]
    assignment = []
    i = 0
    while i < len(df):
        assignment.append(random.randint(0,1)) 
        i += 1
    df['Partition'] = assignment
    power_analysis_df = df[df['Partition'] == 0]
    analysis_df = df[df['Partition'] == 1]
        
    del df
    
    pa_retailer_means = pd.DataFrame(power_analysis_df.groupby(['Retailer_ID'])['Order_Amt'].mean())
    pa_retailer_means.reset_index(inplace=True)
    pa_retailer_means.columns = ['Retailer_ID', 'Mean_Retailer_Order_Amt']
    ###############################################################################
    pa_dow_means = pd.DataFrame(power_analysis_df.groupby(['Dow_Rand'])['Order_Amt'].mean())
    pa_dow_means.reset_index(inplace=True)
    pa_dow_means.columns = ['Dow_Rand', 'Mean_DOW_Order_Amt']
    ###############################################################################
    analysis_df = pd.merge(analysis_df, pa_retailer_means, on='Retailer_ID', how='left')
    analysis_df = pd.merge(analysis_df, pa_dow_means, on='Dow_Rand', how='left')
    ###############################################################################
    analysis_df = analysis_df[['Order_Amt', 'Customer_ID', 'Mean_Order_Amt', 
                               'Mean_Retailer_Order_Amt','Mean_DOW_Order_Amt']]
    analysis_df['Constant'] = 1
    X = analysis_df['Constant']
    Y = analysis_df[['Order_Amt']]
    residuals_df = sm.OLS(Y.astype(float), X.astype(float)).fit()
    
    X2 = analysis_df[['Customer_ID']]
    X2['Residual'] = residuals_df.resid
    X2['Constant'] = 1
    clustered_res = sm.OLS(X2['Residual'], X2['Constant']).fit(method='pinv'). \
                       get_robustcov_results('cluster', groups = X2['Customer_ID'], 
                       use_correction=True, df_correction=True)
    
    clustered_sd = clustered_res.bse[0] * np.sqrt(analysis_df.shape[0])
    effect_size = absolute_mde / clustered_sd
    recommended_n = int(sm.stats.tt_ind_solve_power(effect_size = effect_size, 
                        alpha = rejection_region, power = desired_power, 
                        alternative = 'larger'))
    print("A sample size of {} was recommended.".format(recommended_n ))
    return recommended_n

# %%
def verify_sample_size_est(sample_size, data_src, data_labels, alpha, verify_n_times):

    import statsmodels.api as sm
    import pandas as pd
    
    SAMPLE_SIZE = sample_size
    VERIFICATION_ITERATIONS = verify_n_times
    ALPHA = alpha

    i = 0
    pvals  = []
    r_sqr  = []
    cond_n = []
    while i < VERIFICATION_ITERATIONS:
        working_df = data_src.sample(SAMPLE_SIZE, replace=False)
        ###############################################################################
        pa_retailer_means = pd.DataFrame(working_df.groupby(['Retailer_ID'])['Order_Amt'].mean())
        pa_retailer_means.reset_index(inplace=True)
        pa_retailer_means.columns = ['Retailer_ID', 'Mean_Retailer_Order_Amt']
        ###############################################################################
        pa_dow_means = pd.DataFrame(working_df.groupby(['Dow_Rand'])['Order_Amt'].mean())
        pa_dow_means.reset_index(inplace=True)
        pa_dow_means.columns = ['Dow_Rand', 'Mean_DOW_Order_Amt']
        ###############################################################################
        analysis_df = pd.merge(working_df, pa_retailer_means, on='Retailer_ID', how='left')
        analysis_df = pd.merge(analysis_df, pa_dow_means, on='Dow_Rand', how='left')
        ###############################################################################
        analysis_df = analysis_df[['Order_Amt', 'Customer_ID', 'Treated', 'Mean_Order_Amt', 
                                 'Mean_Retailer_Order_Amt','Mean_DOW_Order_Amt']]
        ###############################################################################
        X = analysis_df[['Treated']]
        X = sm.add_constant(X)
        Y = analysis_df[['Order_Amt']]
        model = sm.OLS(Y.astype(float), X.astype(float)).fit(method='pinv'). \
                       get_robustcov_results('cluster', groups = analysis_df['Customer_ID'], 
                       use_correction=True, df_correction=True)
        if model.pvalues[1] < ALPHA: 
            pvals.append(1)
        else:
            pvals.append(0)  
        r_sqr.append(model.rsquared_adj)
        cond_n.append(model.condition_number)
        i += 1
        if i % int((VERIFICATION_ITERATIONS)/10.0) == 0:
            completion = str(round((i/VERIFICATION_ITERATIONS)*100, 2))+'%'
            print(completion + ' complete.')
    # ----- Exit inner loop        
    actual_power = sum(pvals)/len(pvals)  
    mean_r_sqr   = sum(r_sqr)/len(r_sqr)   
    mean_cond_n  = sum(cond_n)/len(cond_n)  
    print("Actual power was estimated at {}.".format(actual_power))
    return actual_power, mean_r_sqr, mean_cond_n

# %%
def meta_assess(sub_iterations, meta_iterations, absolute_mde, 
                alpha, target_power, pa_file, analysis_file, file_name):

    ALPHA = alpha
    SUB_ITERATIONS = sub_iterations
    META_ITERATIONS = meta_iterations
    TARGET_POWER = target_power

    dir = './residual_dfs/'
    import pandas as pd
    import os

    i = 0
    results     = []
    r_sqr_list  = []
    cond_n_list = []
    abs_mde     = []
    while i < META_ITERATIONS:

        data_src_a = pd.read_csv(dir + pa_file)
        data_src_b = pd.read_csv(dir + analysis_file)
        data_labels = ['Order_ID', 'Customer_ID', 'Mean_Order_Amt', 'Treated',
                       'Treatment_Modifier', 'Retailer_ID', 'Retailer_Scalar',
                       'Dow_Rand', 'DOW', 'Noise', 'Order_Amt']

        recommended_n = create_sample_size_rec(data_src_a, data_labels, 
                                               ALPHA, TARGET_POWER, absolute_mde)

        actual_power, r_sqr, mean_cond_n = verify_sample_size_est(recommended_n, data_src_b, 
                                               data_labels, ALPHA, SUB_ITERATIONS)   

        results.append(actual_power)
        r_sqr_list.append(r_sqr)
        cond_n_list.append(mean_cond_n)
        abs_mde.append(absolute_mde)
        i += 1
        print("{} of {} iterations completed.".format(i, META_ITERATIONS))
    results                          = pd.DataFrame(results)    
    results['Target Power']          = TARGET_POWER
    results.columns                  = ['Achieved Power', 'Abs. MDE', 'Target Power']
    results['Delta']                 = results['Achieved Power'] - results['Target Power']
    results['Mean_R_Sqr']            = r_sqr_list
    results['Mean_Condition_Number'] = cond_n_list

        # Save to .csv
    if not os.path.exists('./residual_dfs/results'):
        os.makedirs('./residual_dfs/results')
    
    results.to_csv('./residual_dfs/results/' + file_name)
    print("{} was saved to disk.".format('./residual_dfs/results/' + file_name))

# %%
meta_assess(500, 100, 0.5, 0.05, 0.8, 
            'part_II_df_mde_0_005_n_100000_a.csv', 
            'part_II_df_mde_0_005_n_100000_b.csv', 
            'mde_0_005_n_100000_model_IV.csv')
# Out:
# The absolute MDE was estimated as 1.
# /home/bknight/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/bknight/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/bknight/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# A sample size of 80269 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 79188 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 77960 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 78511 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 80205 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 76799 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 79179 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 77950 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 80754 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 79865 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 80217 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 77440 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 81725 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 80387 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 78703 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 79102 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 78877 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 77549 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 80439 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 78488 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 78196 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 79673 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 80524 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 81166 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 81031 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 79036 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 79726 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 79161 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 79752 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 78663 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 78918 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 78348 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 80564 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 77819 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 80509 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 80522 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 79308 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 78070 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 81035 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 78359 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 79011 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 80977 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 79013 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 79434 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 78549 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 80190 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 79271 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 79352 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 81815 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 80792 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 79828 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 78896 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 79753 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 78527 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 79006 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 78902 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 79876 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 77675 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 76763 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 78755 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 79018 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 80373 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 78082 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 79121 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 78361 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 82237 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 81234 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 80237 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 81627 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 79554 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 81571 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 77252 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 77166 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 80945 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 79037 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 82231 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 79515 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 78621 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 80726 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 78533 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 79312 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 77339 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 82166 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 77398 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 80921 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 77604 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 80678 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 80239 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 78618 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 79439 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 80270 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 78269 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 79447 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 80705 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 76648 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 79052 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 78691 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 80271 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 77229 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# The absolute MDE was estimated as 1.
# A sample size of 78364 was recommended.
# 10.0% complete.
# 20.0% complete.
# 30.0% complete.
# 40.0% complete.
# 50.0% complete.
# 60.0% complete.
# 70.0% complete.
# 80.0% complete.
# 90.0% complete.
# 100.0% complete.
# Actual power was estimated at 0.0.
# ./residual_dfs/results/mde_0_01_n_10000_model_IV.csv was saved to disk.
