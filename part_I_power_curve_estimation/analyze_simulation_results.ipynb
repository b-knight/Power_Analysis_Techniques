# %%
import pandas as pd

# %%
df1
# Out:
#     Unnamed: 0  Recommended N  Time Required  Desired Power  Actual Power  \
# 0            0          26390       0.551483            0.8         0.880
# 1            1          30496       0.531087            0.8         0.904
# 2            2          21400       1.243160            0.8         0.838
# 3            3          27348       0.239439            0.8         0.882
# 4            4          26697       0.478943            0.8         0.872
# 5            5          29480       0.764979            0.8         0.890
# 6            6          22442       0.303151            0.8         0.814
# 7            7          24930       1.604142            0.8         0.856
# 8            8          21587       2.077221            0.8         0.784
# 9            9          16429       2.995851            0.8         0.676
# 10          10          28450       1.143640            0.8         0.896
# 11          11          28059       0.978175            0.8         0.896
# 12          12          28778       2.053177            0.8         0.900
# 13          13          29206       0.655628            0.8         0.894
# 14          14          23138       1.812428            0.8         0.848
# 15          15          25510       0.308178            0.8         0.862
# 16          16          27018       0.284645            0.8         0.904
# 17          17           7023       0.577187            0.8         0.374
# 18          18          23658       0.847136            0.8         0.840
# 19          19          27386       1.391504            0.8         0.870
# 20          20          23138       0.296040            0.8         0.824
# 21          21          28713       0.283234            0.8         0.880
# 22          22          28651       0.574379            0.8         0.928
# 23          23          19421       0.323337            0.8         0.784
# 24          24          29537       0.598705            0.8         0.904
# 25          25          28146       0.826531            0.8         0.900
# 26          26          25237       0.607941            0.8         0.858
# 27          27          29401       0.279247            0.8         0.888
# 28          28          25678       0.271666            0.8         0.850
# 29          29          24989       0.279256            0.8         0.884
# ..         ...            ...            ...            ...           ...
# 70          70          20753       1.057512            0.8         0.784
# 71          71          15655       0.259802            0.8         0.668
# 72          72          26476       0.533966            0.8         0.856
# 73          73           7023       0.527964            0.8         0.382
# 74          74          29339       0.267212            0.8         0.886
# 75          75          29835       0.265698            0.8         0.906
# 76          76          16126       0.260592            0.8         0.648
# 77          77           6745       0.270183            0.8         0.404
# 78          78          15601       0.795452            0.8         0.682
# 79          79          27386       1.055011            0.8         0.864
# 80          80          28882       0.530931            0.8         0.906
# 81          81          26826       0.525136            0.8         0.902
# 82          82          28326       1.067614            0.8         0.862
# 83          83          28651       0.268355            0.8         0.882
# 84          84          29118       0.837456            0.8         0.916
# 85          85          20594       0.868758            0.8         0.770
# 86          86          15747       0.876329            0.8         0.700
# 87          87          22442       1.132458            0.8         0.840
# 88          88          21808       1.203997            0.8         0.806
# 89          89          18794       2.906431            0.8         0.698
# 90          90          25703       0.281790            0.8         0.874
# 91          91          21400       2.475077            0.8         0.806
# 92          92          25832       0.267470            0.8         0.848
# 93          93          22510       0.539344            0.8         0.788
# 94          94          29787       0.541646            0.8         0.914
# 95          95          29370       0.805066            0.8         0.914
# 96          96          22510       0.809420            0.8         0.806
# 97          97          16429       0.271357            0.8         0.696
# 98          98          29544       0.273855            0.8         0.888
# 99          99          29595       0.264729            0.8         0.896
#
#     Avg. R-Squared  Mean Cond. Number  \
# 0         0.381569        4683.881344
# 1         0.381796        4683.013772
# 2         0.382017        4683.363969
# 3         0.381780        4684.789184
# 4         0.382306        4682.798307
# 5         0.381760        4682.734888
# 6         0.381782        4682.218210
# 7         0.381828        4683.536766
# 8         0.381854        4683.691751
# 9         0.381700        4683.697268
# 10        0.381982        4683.611738
# 11        0.381569        4682.466871
# 12        0.381819        4682.831910
# 13        0.382015        4684.089681
# 14        0.381697        4684.128024
# 15        0.381912        4683.338385
# 16        0.382269        4682.713969
# 17        0.382083        4685.624217
# 18        0.382156        4681.489865
# 19        0.381849        4682.536951
# 20        0.381978        4683.795544
# 21        0.381851        4681.918876
# 22        0.381983        4682.957431
# 23        0.381738        4683.795798
# 24        0.382033        4682.428813
# 25        0.382142        4683.308778
# 26        0.382266        4683.325938
# 27        0.381657        4682.106968
# 28        0.381638        4681.624558
# 29        0.381964        4683.794232
# ..             ...                ...
# 70        0.381794        4683.478494
# 71        0.381371        4683.945233
# 72        0.381706        4684.297495
# 73        0.381117        4686.975977
# 74        0.381844        4682.381143
# 75        0.381498        4682.400428
# 76        0.381626        4684.894158
# 77        0.381236        4684.157442
# 78        0.381831        4682.998747
# 79        0.381941        4683.524978
# 80        0.381898        4682.805148
# 81        0.381984        4684.045589
# 82        0.381762        4682.967616
# 83        0.381996        4682.633903
# 84        0.382001        4683.051718
# 85        0.382104        4682.532855
# 86        0.381622        4684.752689
# 87        0.382171        4681.825506
# 88        0.381970        4683.975473
# 89        0.381813        4682.255978
# 90        0.381716        4682.536998
# 91        0.381521        4681.966215
# 92        0.382079        4682.099364
# 93        0.381445        4684.806671
# 94        0.382193        4682.318263
# 95        0.381882        4681.591486
# 96        0.381656        4682.759036
# 97        0.382088        4684.681336
# 98        0.381551        4682.134751
# 99        0.382152        4682.734546
#
#                                   Model Specification  # Points  \
# 0   Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 1   Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 2   Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 3   Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 4   Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 5   Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 6   Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 7   Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 8   Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 9   Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 10  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 11  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 12  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 13  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 14  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 15  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 16  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 17  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 18  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 19  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 20  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 21  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 22  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 23  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 24  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 25  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 26  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 27  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 28  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 29  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# ..                                                ...       ...
# 70  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 71  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 72  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 73  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 74  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 75  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 76  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 77  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 78  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 79  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 80  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 81  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 82  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 83  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 84  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 85  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 86  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 87  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 88  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 89  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 90  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 91  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 92  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 93  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 94  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 95  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 96  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 97  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 98  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
# 99  Order_Amt = 'Treated' + 'Mean_Retailer_Order_A...         3
#
#                    Points  Simulations per Point  Verification Simulations  \
# 0   [30000, 40000, 50000]                    100                       500
# 1   [30000, 40000, 50000]                    100                       500
# 2   [30000, 40000, 50000]                    100                       500
# 3   [30000, 40000, 50000]                    100                       500
# 4   [30000, 40000, 50000]                    100                       500
# 5   [30000, 40000, 50000]                    100                       500
# 6   [30000, 40000, 50000]                    100                       500
# 7   [30000, 40000, 50000]                    100                       500
# 8   [30000, 40000, 50000]                    100                       500
# 9   [30000, 40000, 50000]                    100                       500
# 10  [30000, 40000, 50000]                    100                       500
# 11  [30000, 40000, 50000]                    100                       500
# 12  [30000, 40000, 50000]                    100                       500
# 13  [30000, 40000, 50000]                    100                       500
# 14  [30000, 40000, 50000]                    100                       500
# 15  [30000, 40000, 50000]                    100                       500
# 16  [30000, 40000, 50000]                    100                       500
# 17  [30000, 40000, 50000]                    100                       500
# 18  [30000, 40000, 50000]                    100                       500
# 19  [30000, 40000, 50000]                    100                       500
# 20  [30000, 40000, 50000]                    100                       500
# 21  [30000, 40000, 50000]                    100                       500
# 22  [30000, 40000, 50000]                    100                       500
# 23  [30000, 40000, 50000]                    100                       500
# 24  [30000, 40000, 50000]                    100                       500
# 25  [30000, 40000, 50000]                    100                       500
# 26  [30000, 40000, 50000]                    100                       500
# 27  [30000, 40000, 50000]                    100                       500
# 28  [30000, 40000, 50000]                    100                       500
# 29  [30000, 40000, 50000]                    100                       500
# ..                    ...                    ...                       ...
# 70  [30000, 40000, 50000]                    100                       500
# 71  [30000, 40000, 50000]                    100                       500
# 72  [30000, 40000, 50000]                    100                       500
# 73  [30000, 40000, 50000]                    100                       500
# 74  [30000, 40000, 50000]                    100                       500
# 75  [30000, 40000, 50000]                    100                       500
# 76  [30000, 40000, 50000]                    100                       500
# 77  [30000, 40000, 50000]                    100                       500
# 78  [30000, 40000, 50000]                    100                       500
# 79  [30000, 40000, 50000]                    100                       500
# 80  [30000, 40000, 50000]                    100                       500
# 81  [30000, 40000, 50000]                    100                       500
# 82  [30000, 40000, 50000]                    100                       500
# 83  [30000, 40000, 50000]                    100                       500
# 84  [30000, 40000, 50000]                    100                       500
# 85  [30000, 40000, 50000]                    100                       500
# 86  [30000, 40000, 50000]                    100                       500
# 87  [30000, 40000, 50000]                    100                       500
# 88  [30000, 40000, 50000]                    100                       500
# 89  [30000, 40000, 50000]                    100                       500
# 90  [30000, 40000, 50000]                    100                       500
# 91  [30000, 40000, 50000]                    100                       500
# 92  [30000, 40000, 50000]                    100                       500
# 93  [30000, 40000, 50000]                    100                       500
# 94  [30000, 40000, 50000]                    100                       500
# 95  [30000, 40000, 50000]                    100                       500
# 96  [30000, 40000, 50000]                    100                       500
# 97  [30000, 40000, 50000]                    100                       500
# 98  [30000, 40000, 50000]                    100                       500
# 99  [30000, 40000, 50000]                    100                       500
#
#     New_Error
# 0       0.080
# 1       0.104
# 2       0.038
# 3       0.082
# 4       0.072
# 5       0.090
# 6       0.014
# 7       0.056
# 8      -0.016
# 9      -0.124
# 10      0.096
# 11      0.096
# 12      0.100
# 13      0.094
# 14      0.048
# 15      0.062
# 16      0.104
# 17     -0.426
# 18      0.040
# 19      0.070
# 20      0.024
# 21      0.080
# 22      0.128
# 23     -0.016
# 24      0.104
# 25      0.100
# 26      0.058
# 27      0.088
# 28      0.050
# 29      0.084
# ..        ...
# 70     -0.016
# 71     -0.132
# 72      0.056
# 73     -0.418
# 74      0.086
# 75      0.106
# 76     -0.152
# 77     -0.396
# 78     -0.118
# 79      0.064
# 80      0.106
# 81      0.102
# 82      0.062
# 83      0.082
# 84      0.116
# 85     -0.030
# 86     -0.100
# 87      0.040
# 88      0.006
# 89     -0.102
# 90      0.074
# 91      0.006
# 92      0.048
# 93     -0.012
# 94      0.114
# 95      0.114
# 96      0.006
# 97     -0.104
# 98      0.088
# 99      0.096
#
# [100 rows x 13 columns]

# %%
df1              = pd.read_csv("Model_II_3_Points_100_Iterations.csv")
df1['New_Error'] = df1['Actual Power'] - df1['Desired Power']
results_1        = df1['Actual Power'].tolist()
df_1_n_mu        = df1['Recommended N'].mean()
df_1_n_std       = df1['Recommended N'].std()
df_1_t_mu        = df1['Time Required'].mean()
df_1_t_std        = df1['Time Required'].std()

df2              = pd.read_csv("Model_II_5_Points_100_Iterations.csv")
df2['New_Error'] = df2['Actual Power'] - df2['Desired Power']
results_2        = df2['Actual Power'].tolist()
df_2_n_mu        = df2['Recommended N'].mean()
df_2_n_std       = df2['Recommended N'].std()
df_2_t_mu        = df2['Time Required'].mean()
df_2_t_std       = df2['Time Required'].std()

df3              = pd.read_csv("Model_II_7_Points_100_Iterations.csv")
df3['New_Error'] = df3['Actual Power'] - df3['Desired Power']
results_3        = df3['Actual Power'].tolist()
df_3_n_mu        = df3['Recommended N'].mean()
df_3_n_std       = df3['Recommended N'].std()
df_3_t_mu        = df3['Time Required'].mean()
df_3_t_std       = df3['Time Required'].std()

df4              = pd.read_csv("Model_II_3_Points_200_Iterations.csv")
df4['New_Error'] = df4['Actual Power'] - df4['Desired Power']
results_4        = df4['Actual Power'].tolist()
df_4_n_mu        = df4['Recommended N'].mean()
df_4_n_std       = df4['Recommended N'].std()
df_4_t_mu        = df4['Time Required'].mean()
df_4_t_std       = df4['Time Required'].std()

df5              = pd.read_csv("Model_II_5_Points_200_Iterations.csv")
df5['New_Error'] = df5['Actual Power'] - df5['Desired Power']
results_5        = df5['Actual Power'].tolist()
df_5_n_mu        = df5['Recommended N'].mean()
df_5_n_std       = df5['Recommended N'].std()
df_5_t_mu        = df5['Time Required'].mean()
df_5_t_std       = df5['Time Required'].std()

df6              = pd.read_csv("Model_II_7_Points_200_Iterations.csv")
df6['New_Error'] = df6['Actual Power'] - df6['Desired Power']
results_6        = df6['Actual Power'].tolist()
df_6_n_mu        = df6['Recommended N'].mean()
df_6_n_std       = df6['Recommended N'].std()
df_6_t_mu        = df6['Time Required'].mean()
df_6_t_std       = df6['Time Required'].std()


df7              = pd.read_csv("Model_II_3_Points_300_Iterations.csv")
df7['New_Error'] = df7['Actual Power'] - df7['Desired Power']
results_7        = df7['Actual Power'].tolist()
df_7_n_mu        = df7['Recommended N'].mean()
df_7_n_std       = df7['Recommended N'].std()
df_7_t_mu        = df7['Time Required'].mean()
df_7_t_std       = df7['Time Required'].std()

df8              = pd.read_csv("Model_II_5_Points_300_Iterations.csv")
df8['New_Error'] = df8['Actual Power'] - df8['Desired Power']
results_8        = df8['Actual Power'].tolist()
df_8_n_mu        = df8['Recommended N'].mean()
df_8_n_std       = df8['Recommended N'].std()
df_8_t_mu        = df8['Time Required'].mean()
df_8_t_std       = df8['Time Required'].std()

df9              = pd.read_csv("Model_II_7_Points_300_Iterations.csv")
df9['New_Error'] = df9['Actual Power'] - df9['Desired Power']
results_9        = df9['Actual Power'].tolist()
df_9_n_mu        = df9['Recommended N'].mean()
df_9_n_std       = df9['Recommended N'].std()
df_9_t_mu        = df9['Time Required'].mean()
df_9_t_std       = df9['Time Required'].std()

data_to_plot = [results_1,results_2,results_3,results_4,results_5,results_6,results_7,results_8,results_9]

# %%
means = [df1['New_Error'].mean(), df2['New_Error'].mean(), df3['New_Error'].mean(),
         df4['New_Error'].mean(), df5['New_Error'].mean(), df6['New_Error'].mean(),
         df7['New_Error'].mean(), df8['New_Error'].mean(), df9['New_Error'].mean()]
stdevs = [df1['New_Error'].std(), df2['New_Error'].std(), df3['New_Error'].std(),
          df4['New_Error'].std(), df5['New_Error'].std(), df6['New_Error'].std(),
          df7['New_Error'].std(), df8['New_Error'].std(), df9['New_Error'].std()]
mean_n = [df_1_n_mu, df_2_n_mu, df_3_n_mu, df_4_n_mu, df_5_n_mu, df_6_n_mu, df_7_n_mu, df_8_n_mu, df_9_n_mu]
std_n = [df_1_n_std,df_2_n_std,df_3_n_std, df_4_n_std, df_5_n_std, df_6_n_std, df_7_n_std, df_8_n_std,
          df_9_n_std ]

mean_t = [df_1_t_mu, df_2_t_mu, df_3_t_mu, df_4_t_mu, df_5_t_mu, df_6_t_mu, df_7_t_mu, df_8_t_mu, df_9_t_mu]
std_t = [df_1_t_std, df_2_t_std, df_3_t_std, df_4_t_std, df_5_t_std, df_6_t_std, 
         df_7_t_std, df_8_t_std, df_9_t_std]

n_sim = [300, 500, 700, 600, 1000, 1400, 900, 1500, 2100]
results = pd.DataFrame([n_sim, means, stdevs, mean_n, std_n, mean_t, std_t 
                       ], columns = [1,2,3,4,5,6,7,8,9])
results['Labels'] = ['Total Simulations Used', 'Mean Pwr. Error', 
                     'Pwr. Error, Std', 'Mean N', 'Std. N', 'Mean Time', 'Std Time']
results
# Out:
#               1             2             3             4             5  \
# 0    300.000000    500.000000    700.000000    600.000000   1000.000000
# 1      0.039940      0.034340     -0.007500      0.039500      0.024580
# 2      0.103962      0.033687      0.047232      0.088833      0.023884
# 3  25157.240000  23496.710000  21101.330000  24751.900000  22883.000000
# 4   5207.558861   1836.278908   2433.975283   4697.801389   1236.831525
# 5      0.761011      0.473650      0.659115      1.447057      1.239107
# 6      0.624997      0.100311      0.081226      1.116322      0.279564
#
#               6             7             8             9  \
# 0   1400.000000    900.000000   1500.000000   2100.000000
# 1     -0.022300      0.045640      0.025380     -0.020960
# 2      0.041107      0.060828      0.021897      0.032799
# 3  20244.190000  24925.390000  22956.250000  20230.630000
# 4   2035.684620   3690.340550   1053.527048   1490.633129
# 5      1.463752      1.878517      1.410944      1.976007
# 6      0.295266      1.409250      0.195864      0.198096
#
#                    Labels
# 0  Total Simulations Used
# 1         Mean Pwr. Error
# 2         Pwr. Error, Std
# 3                  Mean N
# 4                  Std. N
# 5               Mean Time
# 6                Std Time

# %% [markdown]
# http://blog.bharatbhole.com/creating-boxplots-with-matplotlib/

# %%
import matplotlib as mpl 
mpl.use('agg')
# %matplotlib inline
import matplotlib.pyplot as plt 
from matplotlib import rc, rcParams
rcParams['text.latex.preamble'] = [r'\usepackage{sfmath} \boldmath']
rc('text', usetex=True)
rc('axes', linewidth=2)
rc('font', weight='bold')
rcParams['text.latex.preamble'] = [r'\usepackage{sfmath} \boldmath']
## add patch_artist=True option to ax.boxplot() 
## to get fill color

# Create a figure instance
fig = plt.figure(1, figsize=(16, 6))

# Create an axes instance
ax = fig.add_subplot(111)

bp = ax.boxplot(data_to_plot, patch_artist=True)

## change outline color, fill color and linewidth of the boxes
for box in bp['boxes']:
    # change outline color
    box.set( color='#7570b3', linewidth=2)
    # change fill color
    box.set( facecolor = '#1b9e77' )

## change color and linewidth of the whiskers
for whisker in bp['whiskers']:
    whisker.set(color='#7570b3', linewidth=2)

## change color and linewidth of the caps
for cap in bp['caps']:
    cap.set(color='#7570b3', linewidth=2)

## change color and linewidth of the medians
for median in bp['medians']:
    median.set(color='#b2df8a', linewidth=2)

## change the style of fliers and their fill
for flier in bp['fliers']:
    flier.set(marker='o', color='#e7298a', alpha=0.5)
ax.axhline(y=0.8, xmin=0.0, xmax=1.0, color='r')    

## Custom x-axis labels
ax.tick_params(axis='y', which='major', labelsize=16)
ax.tick_params(axis='x', which='major', labelsize=16)
# label_1 = r"\textbf{Method I}" "\n" "$\mu \pm[1]\sigma$" "\n" "100 Iterations" "\n" " per Point" \
#            "\n" "X 3" "\n" "Total" "\n" "Iterations" "\n" "= 800"
# label_2 = r"\textbf{Method II}" "\n" "$\mu \pm[1,2]\sigma$" "\n" "100 Iterations" "\n" " per Point" \
#            "\n" "X 5" "\n" "Total" "\n" "Iterations" "\n" "= 1,000"
# label_3 = r"\textbf{Method III}" "\n" "$\mu \pm[1,2,3]\sigma$" "\n" "100 Iterations" "\n" " per Point" \
#            "\n" "X 7" "\n" "Total" "\n" "Iterations" "\n" "= 1,200"
# label_4 = r"\textbf{Method IV}" "\n" "$\mu \pm[1]\sigma$" "\n" "200 Iterations" "\n" " per Point" \
#            "\n" "X 3" "\n" "Total" "\n" "Iterations" "\n" "= 1,100"
# label_5 = r"\textbf{Method V}" "\n" "$\mu \pm[1,2]\sigma$" "\n" "200 Iterations" "\n" " per Point" \
#            "\n" "X 5" "\n" "Total" "\n" "Iterations" "\n" "= 1,500"
# label_6 = r"\textbf{Method VI}" "\n" "$\mu \pm[1,2,3]\sigma$" "\n" "200 Iterations" "\n" " per Point" \
#            "\n" "X 7" "\n" "Total" "\n" "Iterations" "\n" "= 1,900"
# label_7 = r"\textbf{Method VII}" "\n" "$\mu \pm[1]\sigma$" "\n" "300 Iterations" "\n" " per Point" \
#            "\n" "X 3" "\n" "Total" "\n" "Iterations" "\n" "= 1,400"
# label_8 = r"\textbf{Method VIII}" "\n" "$\mu \pm[1,2]\sigma$" "\n" "300 Iterations" "\n" " per Point" \
#            "\n" "X 5" "\n" "Total" "\n" "Iterations" "\n" "= 2,000"
# label_9 = r"\textbf{Method IX}" "\n" "$\mu \pm[1,2,3]\sigma$" "\n" "300 Iterations" "\n" " per Point" \
#            "\n" "X 7" "\n" "Total" "\n" "Iterations" "\n" "= 2,600"
label_1 = r"\textbf{Method}" "\n" "I"
label_2 = r"\textbf{Method}" "\n" "II"
label_3 = r"\textbf{Method}" "\n" "II"
label_4 = r"\textbf{Method}" "\n" "IV"
label_5 = r"\textbf{Method}" "\n" "V"
label_6 = r"\textbf{Method}" "\n" "VI"
label_7 = r"\textbf{Method}" "\n" "VII"
label_8 = r"\textbf{Method}" "\n" "VIII"
label_9 = r"\textbf{Method}" "\n" "IX"
ax.set_xticklabels([label_1,label_2,label_3,label_4,label_5,label_6,label_7,label_8,label_9])

# Y=Axis
plt.ylabel(r"\textbf{Estimated} \\\\ \phantom{aaaa}\textbf{Power:} \\\\ \phantom{aa}$\%$ \textbf{of 500} \\\\ "
           + r"\phantom{a}\textbf{Simulations} \\\\ \textbf{where NULL} \\\\ \textbf{was Rejected} \\\\" +
           r"\phantom{aa}$\alpha < 0.05$",
           rotation = 0, 
           labelpad = 70,
           size = 16)

ax.yaxis.set_label_coords(-0.10,0.25)
# Plot Title
# plt.title(r"""\Huge{Big title !} \newline \normalsize{Small subtitle !}""")
plt.figtext(.5,0.95,'Distributions of Estimated Statistical Power', 
            fontsize=36, ha='center')
plt.figtext(.5,.9,'Each distribution represents 100 iterations.' +\
            ' A single iteration uses between 300 and 2,100 simulations. ',
            fontsize=20, ha='center')


ax.axvline(x=3.5, color='black', ls='--', lw=1)  
ax.axvline(x=6.5, color='black', ls='--', lw=1)  

plt.annotate("100 Simulations \n Used per Point",
             xy=(290, 150), 
             xycoords='figure pixels',
             fontsize=18, ha='center',
             color='black')
# plt.annotate("n = [30k, 40k, 50k]",
#              xy=(370, 180), 
#              xycoords='figure pixels',
#              fontsize=16, ha='center',
#              color='black')

plt.annotate("200 Simulations \n Used per Point",
             xy=(590, 150), 
             xycoords='figure pixels',
             fontsize=18, ha='center',
             color='black')
# plt.annotate("n = [20k, 30k, 40k, \n 50k, 60k]",
#              xy=(665, 160), 
#              xycoords='figure pixels',
#              fontsize=16, ha='center',
#              color='black')


plt.annotate("300 Simulations \n Used per Point",
             xy=(885, 150), 
             xycoords='figure pixels',
             fontsize=18, ha='center',
             color='black')
# plt.annotate("n = [10k, 20k, 30k, 40k, \n 50k, 60k, 70k]",
#              xy=(945, 160), 
#              xycoords='figure pixels',
#              fontsize=16, ha='center',
#              color='black')

# Save the figure
fig.savefig('nine_model_results.png', bbox_inches='tight')
