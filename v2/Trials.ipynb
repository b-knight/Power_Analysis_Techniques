# %%
import pandas as pd
import supporting_functions as sf

observations = 2500000
num_retailers = 10000
retailer_loc = 100          
retailer_scale = 10
noise_loc = 0.0
noise_scale = 10
absolute_treatment_effect = 0.25

# file_name = sf.create_sim_data(absolute_treatment_effect, observations, num_retailers, retailer_loc,             
#                           retailer_scale, noise_loc, noise_scale)
data = pd.read_csv(file_name)

# %%
treatment_variable = 'Treated'
covariates = ['Mean_Retailer_Amount']
dependent_variable = 'Initial_Order_Amount'
absolute_mde          = 0.25
rejection_region      = 0.05
desired_power         = 0.8
search_orders         = 1
points_per_iteration  = 4
sims                  = 300
precison              = 0.025
model                 = 'isotonic'

############################################################

iterations   = 5
n_vector     = []
power_vector = []
sims_vector  = []
time_vector  = []
model_vector = []

for i in range(0, iterations):
    n, n_power, sims_used, time_taken = sf.derive_sample_size_recommendation(data, 
                                           treatment_variable, covariates, 
                                           dependent_variable, absolute_mde, 
                                           rejection_region, desired_power, 
                                           search_orders, points_per_iteration, 
                                           sims, precison, model) 
    n_vector.append(n)
    power_vector.append(n_power)
    sims_vector.append(sims_used)
    time_vector.append(time_taken) 
    model_vector.append(model)
    
model = 'exponential_cdf'

for i in range(0, iterations):
    n, n_power, sims_used, time_taken = sf.derive_sample_size_recommendation(data, 
                                           treatment_variable, covariates, 
                                           dependent_variable, absolute_mde, 
                                           rejection_region, desired_power, 
                                           search_orders, points_per_iteration, 
                                           sims, precison, model) 
    n_vector.append(n)
    power_vector.append(n_power)
    sims_vector.append(sims_used)
    time_vector.append(time_taken) 
    model_vector.append(model)
# Out:
# Determining direction of search.
# Starting sample size recommendation is 19,784.
# Estimating the effective power of n = 19,784 using 300 simulations.
# The effective power of sample size n = 19,784 is 47.18%.
# Starting power is 47.18%.
# Sample size of n = 19,784 is under-powered.
# Proposed sample size of 19,784 fails to meet desired power of 80%.
# The lower-bound for the proposed sample size search is 19,784.
# The upper-bound for the proposed sample size search is 197,840.
# 5 candidate sample sizes were recommended within the range 19,784 to 197,840.
# Proceeding with interpolation via isotonic regression.
# Estimating the effective power of n = 55,395 using 300 simulations.
# The effective power of sample size n = 55,395 is 85.71%.
# Estimating the effective power of n = 91,006 using 300 simulations.
# The effective power of sample size n = 91,006 is 94.35%.
# Estimating the effective power of n = 126,617 using 300 simulations.
# The effective power of sample size n = 126,617 is 99.67%.
# Estimating the effective power of n = 162,228 using 300 simulations.
# The effective power of sample size n = 162,228 is 99.67%.
# Estimating the effective power of n = 180,034 using 300 simulations.
# The effective power of sample size n = 180,034 is 100%.
# Specified range for isotonic regression failed to capture desired power.
# Now supplementing range.
# Estimating the effective power of n = 27,697 using 300 simulations.
# The effective power of sample size n = 27,697 is 55.15%.
# A sample size of 50,216 was recommended using 2,100 simulations.
# Estimating the effective power of n = 50,216 using 300 simulations.
# The effective power of sample size n = 50,216 is 82.72%.
# Results failed to meet required precision of +/- 2.5 points of statistical power.
# 5 candidate sample sizes were recommended within the range 27,697 to 50,216.
# Proceeding with interpolation via isotonic regression.
# Estimating the effective power of n = 32,200 using 300 simulations.
# The effective power of sample size n = 32,200 is 62.46%.
# Estimating the effective power of n = 36,704 using 300 simulations.
# The effective power of sample size n = 36,704 is 62.79%.
# Estimating the effective power of n = 41,208 using 300 simulations.
# The effective power of sample size n = 41,208 is 74.75%.
# Estimating the effective power of n = 45,712 using 300 simulations.
# The effective power of sample size n = 45,712 is 80.4%.
# Recommended sample size was attained after 3,600 simulations with (n = 45,712, power = 80.4%).
# The results meet the required precision of +/- 2.5 points of statistical power.
# Interpolation concluded after 3,600 simulations with
# a recommended sample size of 45,712 with 80.4% statistical power
# Power estimation took 7 minutes and 4 seconds.
# Determining direction of search.
# Starting sample size recommendation is 19,784.
# Estimating the effective power of n = 19,784 using 300 simulations.
# The effective power of sample size n = 19,784 is 45.51%.
# Starting power is 45.51%.
# Sample size of n = 19,784 is under-powered.
# Proposed sample size of 19,784 fails to meet desired power of 80%.
# The lower-bound for the proposed sample size search is 19,784.
# The upper-bound for the proposed sample size search is 197,840.
# 5 candidate sample sizes were recommended within the range 19,784 to 197,840.
# Proceeding with interpolation via isotonic regression.
# Estimating the effective power of n = 55,395 using 300 simulations.
# The effective power of sample size n = 55,395 is 79.73%.
# Recommended sample size was attained after 600 simulations with (n = 55,395, power = 79.73%).
# The results meet the required precision of +/- 2.5 points of statistical power.
# Interpolation concluded after 600 simulations with
# a recommended sample size of 55,395 with 79.73% statistical power
# Power estimation took 1 minutes and 15 seconds.
# Determining direction of search.
# Starting sample size recommendation is 19,784.
# Estimating the effective power of n = 19,784 using 300 simulations.
# The effective power of sample size n = 19,784 is 46.18%.
# Starting power is 46.18%.
# Sample size of n = 19,784 is under-powered.
# Proposed sample size of 19,784 fails to meet desired power of 80%.
# The lower-bound for the proposed sample size search is 19,784.
# The upper-bound for the proposed sample size search is 197,840.
# 5 candidate sample sizes were recommended within the range 19,784 to 197,840.
# Proceeding with interpolation via isotonic regression.
# Estimating the effective power of n = 55,395 using 300 simulations.
# The effective power of sample size n = 55,395 is 85.38%.
# Estimating the effective power of n = 91,006 using 300 simulations.
# The effective power of sample size n = 91,006 is 83.06%.
# Estimating the effective power of n = 126,617 using 300 simulations.
# The effective power of sample size n = 126,617 is 77.08%.
# Estimating the effective power of n = 162,228 using 300 simulations.
# The effective power of sample size n = 162,228 is 82.39%.
# Recommended sample size was attained after 1,500 simulations with (n = 162,228, power = 82.39%).
# The results meet the required precision of +/- 2.5 points of statistical power.
# Interpolation concluded after 1,500 simulations with
# a recommended sample size of 162,228 with 82.39% statistical power
# Power estimation took 4 minutes and 11 seconds.
# Determining direction of search.
# Starting sample size recommendation is 19,784.
# Estimating the effective power of n = 19,784 using 300 simulations.
# The effective power of sample size n = 19,784 is 46.18%.
# Starting power is 46.18%.
# Sample size of n = 19,784 is under-powered.
# Proposed sample size of 19,784 fails to meet desired power of 80%.
# The lower-bound for the proposed sample size search is 19,784.
# The upper-bound for the proposed sample size search is 197,840.
# 5 candidate sample sizes were recommended within the range 19,784 to 197,840.
# Proceeding with interpolation via isotonic regression.
# Estimating the effective power of n = 55,395 using 300 simulations.
# The effective power of sample size n = 55,395 is 82.39%.
# Recommended sample size was attained after 600 simulations with (n = 55,395, power = 82.39%).
# The results meet the required precision of +/- 2.5 points of statistical power.
# Interpolation concluded after 600 simulations with
# a recommended sample size of 55,395 with 82.39% statistical power
# Power estimation took 1 minutes and 16 seconds.
# Determining direction of search.
# Starting sample size recommendation is 19,784.
# Estimating the effective power of n = 19,784 using 300 simulations.
# The effective power of sample size n = 19,784 is 42.19%.
# Starting power is 42.19%.
# Sample size of n = 19,784 is under-powered.
# Proposed sample size of 19,784 fails to meet desired power of 80%.
# The lower-bound for the proposed sample size search is 19,784.
# The upper-bound for the proposed sample size search is 197,840.
# 5 candidate sample sizes were recommended within the range 19,784 to 197,840.
# Proceeding with interpolation via isotonic regression.
# Estimating the effective power of n = 55,395 using 300 simulations.
# The effective power of sample size n = 55,395 is 82.72%.
# Estimating the effective power of n = 91,006 using 300 simulations.
# The effective power of sample size n = 91,006 is 88.37%.
# Estimating the effective power of n = 126,617 using 300 simulations.
# The effective power of sample size n = 126,617 is 39.53%.
# Estimating the effective power of n = 162,228 using 300 simulations.
# The effective power of sample size n = 162,228 is 75.42%.
# Estimating the effective power of n = 180,034 using 300 simulations.
# The effective power of sample size n = 180,034 is 62.79%.
# A sample size of 123,056 was recommended using 1,800 simulations.
# Estimating the effective power of n = 123,056 using 300 simulations.
# The effective power of sample size n = 123,056 is 79.73%.
# Recommended sample size was attained after 2,100 simulations with (n = 123056, power = 79.73%).
# The results meet the required precision of +/- 2.5 points of statistical power.
# Interpolation concluded after 2,100 simulations with
# a recommended sample size of 123,056 with 79.73% statistical power
# Power estimation took 9 minutes and 22 seconds.
# Determining direction of search.
# Starting sample size recommendation is 19,784.
# Estimating the effective power of n = 19,784 using 300 simulations.
# The effective power of sample size n = 19,784 is 42.86%.
# Starting power is 42.86%.
# Sample size of n = 19,784 is under-powered.
# Proposed sample size of 19,784 fails to meet desired power of 80%.
# The lower-bound for the proposed sample size search is 19,784.
# The upper-bound for the proposed sample size search is 197,840.
# 5 candidate sample sizes were recommended within the range 19,784 to 197,840.
# Proceeding with interpolation using the CDF of the exponential distribution.
# Estimating the effective power of n = 55,395 using 300 simulations.
# The effective power of sample size n = 55,395 is 88.37%.
# Estimating the effective power of n = 91,006 using 300 simulations.
# The effective power of sample size n = 91,006 is 90.7%.
# Estimating the effective power of n = 126,617 using 300 simulations.
# The effective power of sample size n = 126,617 is 56.81%.
# Estimating the effective power of n = 162,228 using 300 simulations.
# The effective power of sample size n = 162,228 is 29.9%.
# Estimating the effective power of n = 180,034 using 300 simulations.
# The effective power of sample size n = 180,034 is 63.12%.
# A sample size of 115,630 was recommended using 1,800 simulations.
# Estimating the effective power of n = 115,630 using 300 simulations.
# The effective power of sample size n = 115,630 is 81.06%.
# Recommended sample size was attained after 2,100 simulations with (n = 115630, power = 81.06%).
# The results meet the required precision of +/- 2.5 points of statistical power.
# Interpolation concluded after 2,100 simulations with
# a recommended sample size of 115,630 with 81.06% statistical power
# Power estimation took 10 minutes and 42 seconds.
# Determining direction of search.
# Starting sample size recommendation is 19,784.
# Estimating the effective power of n = 19,784 using 300 simulations.
# The effective power of sample size n = 19,784 is 40.53%.
# Starting power is 40.53%.
# Sample size of n = 19,784 is under-powered.
# Proposed sample size of 19,784 fails to meet desired power of 80%.
# The lower-bound for the proposed sample size search is 19,784.
# The upper-bound for the proposed sample size search is 197,840.
# 5 candidate sample sizes were recommended within the range 19,784 to 197,840.
# Proceeding with interpolation using the CDF of the exponential distribution.
# Estimating the effective power of n = 55,395 using 300 simulations.
# The effective power of sample size n = 55,395 is 86.71%.
# Estimating the effective power of n = 91,006 using 300 simulations.
# The effective power of sample size n = 91,006 is 94.35%.
# Estimating the effective power of n = 126,617 using 300 simulations.
# The effective power of sample size n = 126,617 is 51.83%.
# Estimating the effective power of n = 162,228 using 300 simulations.
# The effective power of sample size n = 162,228 is 37.21%.
# Estimating the effective power of n = 180,034 using 300 simulations.
# The effective power of sample size n = 180,034 is 29.9%.
# SciPy curve_fit() failed to parameterize the inputted values.
# This can happen when the inputted power estimates have high variance.
# Consider increasing the number of simulations to reduce variance.
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-9-a18602a07c26> in <module>
#      41                                            rejection_region, desired_power,
#      42                                            search_orders, points_per_iteration,
# ---> 43                                            sims, precison, model)
#      44     n_vector.append(n)
#      45     power_vector.append(n_power)
#
# ~/Documents/Power_Analysis_Techniques/v2/supporting_functions.py in derive_sample_size_recommendation(data, treatment_variable, covariates, dependent_variable, absolute_mde, rejection_region, desired_power, search_orders, points_per_iteration, sims, precison, model)
#     442                                                                model, precison, desired_power,
#     443                                                                rejection_region, points_per_iteration,
# --> 444                                                                sims, prior_sims)
#     445     end = time.time()
#     446     time_elapsed = end - start
#
# ~/Documents/Power_Analysis_Techniques/v2/supporting_functions.py in create_interpolated_recommendation(data, candidates, treatment_variable, covariates, dependent_variable, model, precison, desired_power, rejection_region, points_per_iteration, sims, prior_sims)
#     409     a,b,c,d,e = interpolate_recommendation(data, candidates, treatment_variable, covariates,
#     410                                            dependent_variable, model, precison, desired_power,
# --> 411                                            rejection_region, sims, prior_sims)
#     412     while a != c:
#     413         candidates = create_range(a, c, points_per_iteration)
#
# ~/Documents/Power_Analysis_Techniques/v2/supporting_functions.py in interpolate_recommendation(data, candidates, treatment_variable, covariates, dependent_variable, model, precison, desired_power, rejection_region, sims, sims_used)
#     364             print("Consider increasing the number of simulations to reduce variance.")
#     365
# --> 366     print("A sample size of {:,} was recommended ".format(recommendation) +\
#     367           "using {:,} simulations.".format(sims_used))
#     368     final_power = assess_power(data, recommendation , treatment_variable,
#
# UnboundLocalError: local variable 'recommendation' referenced before assignment

# %%
labels = []
for i in range(0, iterations*2):
    labels.append(file_name)    
data = [labels, n_vector, power_vector, sims_vector, time_vector, model_vector]
df = pd.DataFrame.from_records(data).T
df.columns = ['File', 'Recommended n', 'Est. Power', 'Simulations Used', 'Seconds', 'Model']
df
# Out:
#                                     File Recommended n Est. Power  \
# 0  ./data/sim_data_2019_12_23_083149.csv         45712   0.803987
# 1  ./data/sim_data_2019_12_23_083149.csv         55395   0.797342
# 2  ./data/sim_data_2019_12_23_083149.csv        162228    0.82392
# 3  ./data/sim_data_2019_12_23_083149.csv         55395    0.82392
# 4  ./data/sim_data_2019_12_23_083149.csv        123056   0.797342
# 5  ./data/sim_data_2019_12_23_083149.csv        115630   0.810631
# 6  ./data/sim_data_2019_12_23_083149.csv          None       None
# 7  ./data/sim_data_2019_12_23_083149.csv          None       None
# 8  ./data/sim_data_2019_12_23_083149.csv          None       None
# 9  ./data/sim_data_2019_12_23_083149.csv          None       None
#
#   Simulations Used Seconds            Model
# 0             3600     424         isotonic
# 1              600      75         isotonic
# 2             1500     251         isotonic
# 3              600      76         isotonic
# 4             2100     562         isotonic
# 5             2100     642  exponential_cdf
# 6             None    None             None
# 7             None    None             None
# 8             None    None             None
# 9             None    None             None

# %%
df.to_csv('results.csv')
