# %%
import time
from olsEmpowered import sim_data      as sd
from olsEmpowered import interpolation as imp
from olsEmpowered import isotonic      as iso
from olsEmpowered import binary_search as bst
# Out:
# /home/bknight/anaconda3/lib/python3.7/site-packages/statsmodels/compat/pandas.py:49: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   data_klasses = (pandas.Series, pandas.DataFrame, pandas.Panel)

# %%
dgps_analyzed = 0

while dgps_analyzed < 10:
    start = time.time()
    dgp = sd.create_random_dgp(max_covariates = 10, 
                               permissible_distributions = ['normal', 
                                                            'exponential', 
                                                            'uniform'],
                               range_of_normal_loc = [50, 250], 
                               range_of_normal_scale = [5, 25],
                               range_of_exponential_scale = [0.5, 4],
                               range_of_uniform = [0,10],
                               range_of_betas = [0, 2.5],
                               range_of_abs_mde = [0.02, 0.5],
                               range_of_noise_loc = [-50.0, 50.0],
                               range_of_noise_scale = [10.00, 35.00],
                               sample_size = 4500000)
    dgp = imp.interpolation(dgp)
    starting_value = dgp.set_starting_value() 

    if ((starting_value > 450000) | (starting_value < 100000)) | \
       ((dgp.rsquared_adj < 0.01) | (dgp.rsquared_adj > 0.95)):
        sd.remove_data(dgp, drop_meta_data = True)
        print("DGP violated constraints.")
    else:
        iso_ob = iso.isotonic(dgp)
        n, p,  df1 = iso_ob.isotonic_interpolation()
        imp.save_results(df1, iso_ob)
        del iso_ob
        
        naive_bst = bst.binary_search(dgp, informed = 0)
        n, p,  df2 = naive_bst.binary_search()
        imp.save_results(df2, naive_bst)
        del naive_bst
        
        informed_bst = bst.binary_search(dgp, informed = 1)
        n, p,  df3 = informed_bst.binary_search()
        imp.save_results(df3, informed_bst)
        del informed_bst
        
        dgps_analyzed += 1
        sd.remove_data(dgp, drop_meta_data = False)
        end = time.time()
        time_elapsed = end - start
        time_min = int(time_elapsed/60)
        time_sec = int(time_elapsed - (time_min*60))
        print("Assessment took {} minutes and {} seconds.".format(time_min, time_sec))
# Out:
# 1 additional covariates will be created.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_30_230546.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_30_230546_log_file.txt.
# 4500000 observations of simulation data created in 0 minutes and 51 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_30_230546.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_30_230546_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_30_230546_log_file.txt.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data
# The file sim_data_2019_12_30_230546.csv was deleted.
# The the associated meta-data for file sim_data_2019_12_30_230546.csv was also deleted.
# DGP violated constraints.
# This D.G.P. has no covariates besides the treatment variable.
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_30_230642.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_30_230642_log_file.txt.
# 4500000 observations of simulation data created in 0 minutes and 40 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_30_230642.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_30_230642_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_30_230642_log_file.txt.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data
# The file sim_data_2019_12_30_230642.csv was deleted.
# The the associated meta-data for file sim_data_2019_12_30_230642.csv was also deleted.
# DGP violated constraints.
# 6 additional covariates will be created.
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_30_230727.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_30_230727_log_file.txt.
# 4500000 observations of simulation data created in 1 minutes and 50 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_30_230727.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_30_230727_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_30_230727_log_file.txt.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data
# The file sim_data_2019_12_30_230727.csv was deleted.
# The the associated meta-data for file sim_data_2019_12_30_230727.csv was also deleted.
# DGP violated constraints.
# 7 additional covariates will be created.
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_30_230929.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_30_230929_log_file.txt.
# 4500000 observations of simulation data created in 2 minutes and 7 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_30_230929.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_30_230929_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_30_230929_log_file.txt.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data
# The file sim_data_2019_12_30_230929.csv was deleted.
# The the associated meta-data for file sim_data_2019_12_30_230929.csv was also deleted.
# DGP violated constraints.
# 3 additional covariates will be created.
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_30_231150.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_30_231150_log_file.txt.
# 4500000 observations of simulation data created in 1 minutes and 10 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_30_231150.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_30_231150_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_30_231150_log_file.txt.
# Estimating the effective power of n = 18,588 using 200 simulations.
# The effective power of sample size n = 18,588 is 11.44%.
# Estimating the effective power of n = 185,885 using 200 simulations.
# The effective power of sample size n = 185,885 is 45.77%.
# Estimating the effective power of n = 1,858,850 using 200 simulations.
# The effective power of sample size n = 1,858,850 is 100%.
# Estimating the effective power of n = 1,022,367 using 200 simulations.
# The effective power of sample size n = 1,022,367 is 100%.
# Estimating the effective power of n = 977,857 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 977,857 is 100%.
# Estimating the effective power of n = 880,495 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 880,495 is 100%.
# Estimating the effective power of n = 816,451 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 816,451 is 99.0%.
# Estimating the effective power of n = 591,333 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 591,333 is 97.51%.
# Estimating the effective power of n = 454,104 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 454,104 is 83.58%.
# Estimating the effective power of n = 428,693 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 428,693 is 84.58%.
# Estimating the effective power of n = 417,191 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 417,191 is 84.58%.
# Estimating the effective power of n = 409,887 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 409,887 is 81.09%.
# Saved the results from sim_data_2019_12_30_231150.
# Binary search commenced, naively centered on n = 2,250,000.
# Estimating the effective power of n = 2,250,000 using 200 simulations.
# The effective power of sample size n = 2,250,000 is 100%.
# Binary search suggested the region of n = (0, 2,250,000).
# Now assessing the value 1,125,000 within the range n = (0, 2,250,000), and power = (0%, 100%).
# Estimating the effective power of n = 1,125,000 using 200 simulations.
# The effective power of sample size n = 1,125,000 is 100%.
# Now assessing the value 562,500 within the range n = (0, 1,125,000), and power = (0%, 100%).
# Estimating the effective power of n = 562,500 using 200 simulations.
# The effective power of sample size n = 562,500 is 95.52%.
# Now assessing the value 281,250 within the range n = (0, 562,500), and power = (0%, 95.52%).
# Estimating the effective power of n = 281,250 using 200 simulations.
# The effective power of sample size n = 281,250 is 65.17%.
# Now assessing the value 421,875 within the range n = (281,250, 562,500), and power = (65.17%, 95.52%).
# Estimating the effective power of n = 421,875 using 200 simulations.
# The effective power of sample size n = 421,875 is 85.57%.
# Now assessing the value 351,562 within the range n = (281,250, 421,875), and power = (65.17%, 85.57%).
# Estimating the effective power of n = 351,562 using 200 simulations.
# The effective power of sample size n = 351,562 is 69.65%.
# Now assessing the value 386,718 within the range n = (351,562, 421,875), and power = (69.65%, 85.57%).
# Estimating the effective power of n = 386,718 using 200 simulations.
# The effective power of sample size n = 386,718 is 81.59%.
# Saved the results from sim_data_2019_12_30_231150.
# Binary search commenced, centered on n = 185,885 informed by residual variance.
# Estimating the effective power of n = 185,885 using 200 simulations.
# The effective power of sample size n = 185,885 is 53.73%.
# Estimating the effective power of n = 1,858,850 using 200 simulations.
# The effective power of sample size n = 1,858,850 is 100%.
# Binary search suggested the region of n = (185,885, 1,858,850).
# Now assessing the value 1,022,367 within the range n = (185,885, 1,858,850), and power = (53.73%, 100%).
# Estimating the effective power of n = 1,022,367 using 200 simulations.
# The effective power of sample size n = 1,022,367 is 100%.
# Now assessing the value 604,126 within the range n = (185,885, 1,022,367), and power = (53.73%, 100%).
# Estimating the effective power of n = 604,126 using 200 simulations.
# The effective power of sample size n = 604,126 is 96.52%.
# Now assessing the value 395,005 within the range n = (185,885, 604,126), and power = (53.73%, 96.52%).
# Estimating the effective power of n = 395,005 using 200 simulations.
# The effective power of sample size n = 395,005 is 84.08%.
# Now assessing the value 290,445 within the range n = (185,885, 395,005), and power = (53.73%, 84.08%).
# Estimating the effective power of n = 290,445 using 200 simulations.
# The effective power of sample size n = 290,445 is 68.16%.
# Now assessing the value 342,725 within the range n = (290,445, 395,005), and power = (68.16%, 84.08%).
# Estimating the effective power of n = 342,725 using 200 simulations.
# The effective power of sample size n = 342,725 is 77.61%.
# Saved the results from sim_data_2019_12_30_231150.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data
# The file sim_data_2019_12_30_231150.csv was deleted.
# Assessment took 46 minutes and 7 seconds.
# 2 additional covariates will be created.
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_30_235758.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_30_235758_log_file.txt.
# 4500000 observations of simulation data created in 0 minutes and 56 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_30_235758.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_30_235758_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_30_235758_log_file.txt.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data
# The file sim_data_2019_12_30_235758.csv was deleted.
# The the associated meta-data for file sim_data_2019_12_30_235758.csv was also deleted.
# DGP violated constraints.
# 1 additional covariates will be created.
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_30_235900.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_30_235900_log_file.txt.
# 4500000 observations of simulation data created in 0 minutes and 46 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_30_235900.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_30_235900_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_30_235900_log_file.txt.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data
# The file sim_data_2019_12_30_235900.csv was deleted.
# The the associated meta-data for file sim_data_2019_12_30_235900.csv was also deleted.
# DGP violated constraints.
# 6 additional covariates will be created.
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_30_235951.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_30_235951_log_file.txt.
# 4500000 observations of simulation data created in 1 minutes and 40 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_30_235951.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_30_235951_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_30_235951_log_file.txt.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data
# The file sim_data_2019_12_30_235951.csv was deleted.
# The the associated meta-data for file sim_data_2019_12_30_235951.csv was also deleted.
# DGP violated constraints.
# 1 additional covariates will be created.
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_000143.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_000143_log_file.txt.
# 4500000 observations of simulation data created in 0 minutes and 49 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_000143.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_000143_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_000143_log_file.txt.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data
# The file sim_data_2019_12_31_000143.csv was deleted.
# The the associated meta-data for file sim_data_2019_12_31_000143.csv was also deleted.
# DGP violated constraints.
# This D.G.P. has no covariates besides the treatment variable.
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_000237.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_000237_log_file.txt.
# 4500000 observations of simulation data created in 0 minutes and 38 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_000237.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_000237_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_000237_log_file.txt.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data
# The file sim_data_2019_12_31_000237.csv was deleted.
# The the associated meta-data for file sim_data_2019_12_31_000237.csv was also deleted.
# DGP violated constraints.
# 3 additional covariates will be created.
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_000320.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_000320_log_file.txt.
# 4500000 observations of simulation data created in 1 minutes and 6 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_000320.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_000320_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_000320_log_file.txt.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data
# The file sim_data_2019_12_31_000320.csv was deleted.
# The the associated meta-data for file sim_data_2019_12_31_000320.csv was also deleted.
# DGP violated constraints.
# 6 additional covariates will be created.
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_000433.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_000433_log_file.txt.
# 4500000 observations of simulation data created in 1 minutes and 48 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_000433.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_000433_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_000433_log_file.txt.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data
# The file sim_data_2019_12_31_000433.csv was deleted.
# The the associated meta-data for file sim_data_2019_12_31_000433.csv was also deleted.
# DGP violated constraints.
# 7 additional covariates will be created.
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_000635.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_000635_log_file.txt.
# 4500000 observations of simulation data created in 1 minutes and 49 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_000635.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_000635_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_000635_log_file.txt.
# Estimating the effective power of n = 12,189 using 200 simulations.
# The effective power of sample size n = 12,189 is 4.48%.
# Estimating the effective power of n = 121,897 using 200 simulations.
# The effective power of sample size n = 121,897 is 41.79%.
# Estimating the effective power of n = 1,218,970 using 200 simulations.
# The effective power of sample size n = 1,218,970 is 100%.
# Estimating the effective power of n = 67,043 using 200 simulations.
# The effective power of sample size n = 67,043 is 20.9%.
# Estimating the effective power of n = 670,433 using 200 simulations.
# The effective power of sample size n = 670,433 is 99.5%.
# Estimating the effective power of n = 485,065 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 485,065 is 95.02%.
# Estimating the effective power of n = 382,563 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 382,563 is 87.56%.
# Estimating the effective power of n = 339,496 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 339,496 is 89.05%.
# Estimating the effective power of n = 321,520 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 321,520 is 82.09%.
# Saved the results from sim_data_2019_12_31_000635.
# Binary search commenced, naively centered on n = 2,250,000.
# Estimating the effective power of n = 2,250,000 using 200 simulations.
# The effective power of sample size n = 2,250,000 is 100%.
# Binary search suggested the region of n = (0, 2,250,000).
# Now assessing the value 1,125,000 within the range n = (0, 2,250,000), and power = (0%, 100%).
# Estimating the effective power of n = 1,125,000 using 200 simulations.
# The effective power of sample size n = 1,125,000 is 100%.
# Now assessing the value 562,500 within the range n = (0, 1,125,000), and power = (0%, 100%).
# Estimating the effective power of n = 562,500 using 200 simulations.
# The effective power of sample size n = 562,500 is 96.52%.
# Now assessing the value 281,250 within the range n = (0, 562,500), and power = (0%, 96.52%).
# Estimating the effective power of n = 281,250 using 200 simulations.
# The effective power of sample size n = 281,250 is 73.63%.
# Now assessing the value 421,875 within the range n = (281,250, 562,500), and power = (73.63%, 96.52%).
# Estimating the effective power of n = 421,875 using 200 simulations.
# The effective power of sample size n = 421,875 is 93.53%.
# Now assessing the value 351,562 within the range n = (281,250, 421,875), and power = (73.63%, 93.53%).
# Estimating the effective power of n = 351,562 using 200 simulations.
# The effective power of sample size n = 351,562 is 84.08%.
# Now assessing the value 316,406 within the range n = (281,250, 351,562), and power = (73.63%, 84.08%).
# Estimating the effective power of n = 316,406 using 200 simulations.
# The effective power of sample size n = 316,406 is 77.11%.
# Now assessing the value 333,984 within the range n = (316,406, 351,562), and power = (77.11%, 84.08%).
# Estimating the effective power of n = 333,984 using 200 simulations.
# The effective power of sample size n = 333,984 is 86.07%.
# Now assessing the value 325,195 within the range n = (316,406, 333,984), and power = (77.11%, 86.07%).
# Estimating the effective power of n = 325,195 using 200 simulations.
# The effective power of sample size n = 325,195 is 78.61%.
# Saved the results from sim_data_2019_12_31_000635.
# Binary search commenced, centered on n = 121,897 informed by residual variance.
# Estimating the effective power of n = 121,897 using 200 simulations.
# The effective power of sample size n = 121,897 is 41.29%.
# Estimating the effective power of n = 1,218,970 using 200 simulations.
# The effective power of sample size n = 1,218,970 is 100%.
# Binary search suggested the region of n = (121,897, 1,218,970).
# Now assessing the value 670,433 within the range n = (121,897, 1,218,970), and power = (41.29%, 100%).
# Estimating the effective power of n = 670,433 using 200 simulations.
# The effective power of sample size n = 670,433 is 99.0%.
# Now assessing the value 396,165 within the range n = (121,897, 670,433), and power = (41.29%, 99.0%).
# Estimating the effective power of n = 396,165 using 200 simulations.
# The effective power of sample size n = 396,165 is 88.06%.
# Now assessing the value 259,031 within the range n = (121,897, 396,165), and power = (41.29%, 88.06%).
# Estimating the effective power of n = 259,031 using 200 simulations.
# The effective power of sample size n = 259,031 is 67.66%.
# Now assessing the value 327,598 within the range n = (259,031, 396,165), and power = (67.66%, 88.06%).
# Estimating the effective power of n = 327,598 using 200 simulations.
# The effective power of sample size n = 327,598 is 85.07%.
# Now assessing the value 293,314 within the range n = (259,031, 327,598), and power = (67.66%, 85.07%).
# Estimating the effective power of n = 293,314 using 200 simulations.
# The effective power of sample size n = 293,314 is 82.09%.
# Saved the results from sim_data_2019_12_31_000635.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data
# The file sim_data_2019_12_31_000635.csv was deleted.
# Assessment took 57 minutes and 59 seconds.
# 1 additional covariates will be created.
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_010435.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_010435_log_file.txt.
# 4500000 observations of simulation data created in 0 minutes and 47 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_010435.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_010435_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_010435_log_file.txt.
# Estimating the effective power of n = 12,669 using 200 simulations.
# The effective power of sample size n = 12,669 is 8.96%.
# Estimating the effective power of n = 126,696 using 200 simulations.
# The effective power of sample size n = 126,696 is 36.32%.
# Estimating the effective power of n = 1,266,960 using 200 simulations.
# The effective power of sample size n = 1,266,960 is 100%.
# Estimating the effective power of n = 696,828 using 200 simulations.
# The effective power of sample size n = 696,828 is 99.0%.
# Estimating the effective power of n = 523,978 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 523,978 is 93.53%.
# Estimating the effective power of n = 430,012 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 430,012 is 85.57%.
# Estimating the effective power of n = 395,697 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 395,697 is 83.08%.
# Estimating the effective power of n = 377,954 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 377,954 is 83.08%.
# Estimating the effective power of n = 369,668 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 369,668 is 84.08%.
# Estimating the effective power of n = 364,326 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 364,326 is 83.08%.
# Estimating the effective power of n = 360,407 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 360,407 is 85.07%.
# Estimating the effective power of n = 357,324 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 357,324 is 79.1%.
# Saved the results from sim_data_2019_12_31_010435.
# Binary search commenced, naively centered on n = 2,250,000.
# Estimating the effective power of n = 2,250,000 using 200 simulations.
# The effective power of sample size n = 2,250,000 is 100%.
# Binary search suggested the region of n = (0, 2,250,000).
# Now assessing the value 1,125,000 within the range n = (0, 2,250,000), and power = (0%, 100%).
# Estimating the effective power of n = 1,125,000 using 200 simulations.
# The effective power of sample size n = 1,125,000 is 99.5%.
# Now assessing the value 562,500 within the range n = (0, 1,125,000), and power = (0%, 99.5%).
# Estimating the effective power of n = 562,500 using 200 simulations.
# The effective power of sample size n = 562,500 is 96.02%.
# Now assessing the value 281,250 within the range n = (0, 562,500), and power = (0%, 96.02%).
# Estimating the effective power of n = 281,250 using 200 simulations.
# The effective power of sample size n = 281,250 is 76.12%.
# Now assessing the value 421,875 within the range n = (281,250, 562,500), and power = (76.12%, 96.02%).
# Estimating the effective power of n = 421,875 using 200 simulations.
# The effective power of sample size n = 421,875 is 89.55%.
# Now assessing the value 351,562 within the range n = (281,250, 421,875), and power = (76.12%, 89.55%).
# Estimating the effective power of n = 351,562 using 200 simulations.
# The effective power of sample size n = 351,562 is 84.58%.
# Now assessing the value 316,406 within the range n = (281,250, 351,562), and power = (76.12%, 84.58%).
# Estimating the effective power of n = 316,406 using 200 simulations.
# The effective power of sample size n = 316,406 is 79.6%.
# Saved the results from sim_data_2019_12_31_010435.
# Binary search commenced, centered on n = 126,696 informed by residual variance.
# Estimating the effective power of n = 126,696 using 200 simulations.
# The effective power of sample size n = 126,696 is 42.29%.
# Estimating the effective power of n = 1,266,960 using 200 simulations.
# The effective power of sample size n = 1,266,960 is 100%.
# Binary search suggested the region of n = (126,696, 1,266,960).
# Now assessing the value 696,828 within the range n = (126,696, 1,266,960), and power = (42.29%, 100%).
# Estimating the effective power of n = 696,828 using 200 simulations.
# The effective power of sample size n = 696,828 is 100%.
# Now assessing the value 411,762 within the range n = (126,696, 696,828), and power = (42.29%, 100%).
# Estimating the effective power of n = 411,762 using 200 simulations.
# The effective power of sample size n = 411,762 is 87.06%.
# Now assessing the value 269,229 within the range n = (126,696, 411,762), and power = (42.29%, 87.06%).
# Estimating the effective power of n = 269,229 using 200 simulations.
# The effective power of sample size n = 269,229 is 68.66%.
# Now assessing the value 340,495 within the range n = (269,229, 411,762), and power = (68.66%, 87.06%).
# Estimating the effective power of n = 340,495 using 200 simulations.
# The effective power of sample size n = 340,495 is 78.11%.
# Saved the results from sim_data_2019_12_31_010435.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data
# The file sim_data_2019_12_31_010435.csv was deleted.
# Assessment took 27 minutes and 22 seconds.
# 4 additional covariates will be created.
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_013157.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_013157_log_file.txt.
# 4500000 observations of simulation data created in 1 minutes and 16 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_013157.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_013157_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_013157_log_file.txt.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data
# The file sim_data_2019_12_31_013157.csv was deleted.
# The the associated meta-data for file sim_data_2019_12_31_013157.csv was also deleted.
# DGP violated constraints.
# 3 additional covariates will be created.
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_013322.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_013322_log_file.txt.
# 4500000 observations of simulation data created in 1 minutes and 6 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_013322.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_013322_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_013322_log_file.txt.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data
# The file sim_data_2019_12_31_013322.csv was deleted.
# The the associated meta-data for file sim_data_2019_12_31_013322.csv was also deleted.
# DGP violated constraints.
# 4 additional covariates will be created.
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_013435.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_013435_log_file.txt.
# 4500000 observations of simulation data created in 1 minutes and 17 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_013435.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_013435_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_013435_log_file.txt.
# Estimating the effective power of n = 15,478 using 200 simulations.
# The effective power of sample size n = 15,478 is 6.47%.
# Estimating the effective power of n = 154,780 using 200 simulations.
# The effective power of sample size n = 154,780 is 30.85%.
# Estimating the effective power of n = 1,547,800 using 200 simulations.
# The effective power of sample size n = 1,547,800 is 100%.
# Estimating the effective power of n = 851,290 using 200 simulations.
# The effective power of sample size n = 851,290 is 92.54%.
# Estimating the effective power of n = 709,741 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 709,741 is 88.56%.
# Estimating the effective power of n = 627,453 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 627,453 is 79.1%.
# Saved the results from sim_data_2019_12_31_013435.
# Binary search commenced, naively centered on n = 2,250,000.
# Estimating the effective power of n = 2,250,000 using 200 simulations.
# The effective power of sample size n = 2,250,000 is 100%.
# Binary search suggested the region of n = (0, 2,250,000).
# Now assessing the value 1,125,000 within the range n = (0, 2,250,000), and power = (0%, 100%).
# Estimating the effective power of n = 1,125,000 using 200 simulations.
# The effective power of sample size n = 1,125,000 is 99.5%.
# Now assessing the value 562,500 within the range n = (0, 1,125,000), and power = (0%, 99.5%).
# Estimating the effective power of n = 562,500 using 200 simulations.
# The effective power of sample size n = 562,500 is 80.1%.
# Saved the results from sim_data_2019_12_31_013435.
# Binary search commenced, centered on n = 154,780 informed by residual variance.
# Estimating the effective power of n = 154,780 using 200 simulations.
# The effective power of sample size n = 154,780 is 26.87%.
# Estimating the effective power of n = 1,547,800 using 200 simulations.
# The effective power of sample size n = 1,547,800 is 100%.
# Binary search suggested the region of n = (154,780, 1,547,800).
# Now assessing the value 851,290 within the range n = (154,780, 1,547,800), and power = (26.87%, 100%).
# Estimating the effective power of n = 851,290 using 200 simulations.
# The effective power of sample size n = 851,290 is 90.55%.
# Now assessing the value 503,035 within the range n = (154,780, 851,290), and power = (26.87%, 90.55%).
# Estimating the effective power of n = 503,035 using 200 simulations.
# The effective power of sample size n = 503,035 is 68.16%.
# Now assessing the value 677,162 within the range n = (503,035, 851,290), and power = (68.16%, 90.55%).
# Estimating the effective power of n = 677,162 using 200 simulations.
# The effective power of sample size n = 677,162 is 86.07%.
# Now assessing the value 590,098 within the range n = (503,035, 677,162), and power = (68.16%, 86.07%).
# Estimating the effective power of n = 590,098 using 200 simulations.
# The effective power of sample size n = 590,098 is 82.59%.
# Now assessing the value 546,566 within the range n = (503,035, 590,098), and power = (68.16%, 82.59%).
# Estimating the effective power of n = 546,566 using 200 simulations.
# The effective power of sample size n = 546,566 is 75.62%.
# Now assessing the value 568,332 within the range n = (546,566, 590,098), and power = (75.62%, 82.59%).
# Estimating the effective power of n = 568,332 using 200 simulations.
# The effective power of sample size n = 568,332 is 81.09%.
# Saved the results from sim_data_2019_12_31_013435.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data
# The file sim_data_2019_12_31_013435.csv was deleted.
# Assessment took 34 minutes and 14 seconds.
# 3 additional covariates will be created.
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_020849.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_020849_log_file.txt.
# 4500000 observations of simulation data created in 1 minutes and 4 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_020849.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_020849_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_020849_log_file.txt.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data
# The file sim_data_2019_12_31_020849.csv was deleted.
# The the associated meta-data for file sim_data_2019_12_31_020849.csv was also deleted.
# DGP violated constraints.
# 4 additional covariates will be created.
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_021000.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_021000_log_file.txt.
# 4500000 observations of simulation data created in 1 minutes and 14 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_021000.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_021000_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_021000_log_file.txt.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data
# The file sim_data_2019_12_31_021000.csv was deleted.
# The the associated meta-data for file sim_data_2019_12_31_021000.csv was also deleted.
# DGP violated constraints.
# 5 additional covariates will be created.
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_021123.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_021123_log_file.txt.
# 4500000 observations of simulation data created in 1 minutes and 24 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_021123.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_021123_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_021123_log_file.txt.
# Estimating the effective power of n = 26,139 using 200 simulations.
# The effective power of sample size n = 26,139 is 8.96%.
# Estimating the effective power of n = 261,398 using 200 simulations.
# The effective power of sample size n = 261,398 is 27.86%.
# Estimating the effective power of n = 2,613,980 using 200 simulations.
# The effective power of sample size n = 2,613,980 is 100%.
# Estimating the effective power of n = 1,437,689 using 200 simulations.
# The effective power of sample size n = 1,437,689 is 98.51%.
# Estimating the effective power of n = 1,129,533 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 1,129,533 is 95.52%.
# Estimating the effective power of n = 930,372 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 930,372 is 87.56%.
# Estimating the effective power of n = 845,635 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 845,635 is 83.58%.
# Estimating the effective power of n = 808,076 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 808,076 is 83.08%.
# Estimating the effective power of n = 777,540 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 777,540 is 76.12%.
# Estimating the effective power of n = 794,552 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 794,552 is 81.09%.
# Saved the results from sim_data_2019_12_31_021123.
# Binary search commenced, naively centered on n = 2,250,000.
# Estimating the effective power of n = 2,250,000 using 200 simulations.
# The effective power of sample size n = 2,250,000 is 100%.
# Binary search suggested the region of n = (0, 2,250,000).
# Now assessing the value 1,125,000 within the range n = (0, 2,250,000), and power = (0%, 100%).
# Estimating the effective power of n = 1,125,000 using 200 simulations.
# The effective power of sample size n = 1,125,000 is 89.55%.
# Now assessing the value 562,500 within the range n = (0, 1,125,000), and power = (0%, 89.55%).
# ...
# 4500000 observations of simulation data created in 0 minutes and 38 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_072715.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_072715_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_072715_log_file.txt.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data
# The file sim_data_2019_12_31_072715.csv was deleted.
# The the associated meta-data for file sim_data_2019_12_31_072715.csv was also deleted.
# DGP violated constraints.
# 1 additional covariates will be created.
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_072756.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_072756_log_file.txt.
# 4500000 observations of simulation data created in 0 minutes and 46 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_072756.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_072756_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_072756_log_file.txt.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data
# The file sim_data_2019_12_31_072756.csv was deleted.
# The the associated meta-data for file sim_data_2019_12_31_072756.csv was also deleted.
# DGP violated constraints.
# 6 additional covariates will be created.
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_072847.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_072847_log_file.txt.
# 4500000 observations of simulation data created in 1 minutes and 38 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_072847.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_072847_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_072847_log_file.txt.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data
# The file sim_data_2019_12_31_072847.csv was deleted.
# The the associated meta-data for file sim_data_2019_12_31_072847.csv was also deleted.
# DGP violated constraints.
# 9 additional covariates will be created.
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_073036.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_073036_log_file.txt.
# 4500000 observations of simulation data created in 2 minutes and 15 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_073036.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_073036_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_073036_log_file.txt.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data
# The file sim_data_2019_12_31_073036.csv was deleted.
# The the associated meta-data for file sim_data_2019_12_31_073036.csv was also deleted.
# DGP violated constraints.
# 4 additional covariates will be created.
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_073306.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_073306_log_file.txt.
# 4500000 observations of simulation data created in 1 minutes and 16 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_073306.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_073306_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_073306_log_file.txt.
# Estimating the effective power of n = 10,409 using 200 simulations.
# The effective power of sample size n = 10,409 is 9.45%.
# Estimating the effective power of n = 104,092 using 200 simulations.
# The effective power of sample size n = 104,092 is 42.79%.
# Estimating the effective power of n = 1,040,920 using 200 simulations.
# The effective power of sample size n = 1,040,920 is 100%.
# Estimating the effective power of n = 572,506 using 200 simulations.
# The effective power of sample size n = 572,506 is 99.5%.
# Estimating the effective power of n = 411,437 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 411,437 is 94.53%.
# Estimating the effective power of n = 325,143 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 325,143 is 89.55%.
# Estimating the effective power of n = 279,992 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 279,992 is 81.59%.
# Saved the results from sim_data_2019_12_31_073306.
# Binary search commenced, naively centered on n = 2,250,000.
# Estimating the effective power of n = 2,250,000 using 200 simulations.
# The effective power of sample size n = 2,250,000 is 100%.
# Binary search suggested the region of n = (0, 2,250,000).
# Now assessing the value 1,125,000 within the range n = (0, 2,250,000), and power = (0%, 100%).
# Estimating the effective power of n = 1,125,000 using 200 simulations.
# The effective power of sample size n = 1,125,000 is 100%.
# Now assessing the value 562,500 within the range n = (0, 1,125,000), and power = (0%, 100%).
# Estimating the effective power of n = 562,500 using 200 simulations.
# The effective power of sample size n = 562,500 is 99.5%.
# Now assessing the value 281,250 within the range n = (0, 562,500), and power = (0%, 99.5%).
# Estimating the effective power of n = 281,250 using 200 simulations.
# The effective power of sample size n = 281,250 is 81.09%.
# Saved the results from sim_data_2019_12_31_073306.
# Binary search commenced, centered on n = 104,092 informed by residual variance.
# Estimating the effective power of n = 104,092 using 200 simulations.
# The effective power of sample size n = 104,092 is 41.79%.
# Estimating the effective power of n = 1,040,920 using 200 simulations.
# The effective power of sample size n = 1,040,920 is 100%.
# Binary search suggested the region of n = (104,092, 1,040,920).
# Now assessing the value 572,506 within the range n = (104,092, 1,040,920), and power = (41.79%, 100%).
# Estimating the effective power of n = 572,506 using 200 simulations.
# The effective power of sample size n = 572,506 is 99.0%.
# Now assessing the value 338,299 within the range n = (104,092, 572,506), and power = (41.79%, 99.0%).
# Estimating the effective power of n = 338,299 using 200 simulations.
# The effective power of sample size n = 338,299 is 90.55%.
# Now assessing the value 221,195 within the range n = (104,092, 338,299), and power = (41.79%, 90.55%).
# Estimating the effective power of n = 221,195 using 200 simulations.
# The effective power of sample size n = 221,195 is 73.63%.
# Now assessing the value 279,747 within the range n = (221,195, 338,299), and power = (73.63%, 90.55%).
# Estimating the effective power of n = 279,747 using 200 simulations.
# The effective power of sample size n = 279,747 is 80.1%.
# Saved the results from sim_data_2019_12_31_073306.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data
# The file sim_data_2019_12_31_073306.csv was deleted.
# Assessment took 27 minutes and 3 seconds.
# 6 additional covariates will be created.
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_080010.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_080010_log_file.txt.
# 4500000 observations of simulation data created in 1 minutes and 39 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_31_080010.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_080010_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_31_080010_log_file.txt.
# Estimating the effective power of n = 19,756 using 200 simulations.
# The effective power of sample size n = 19,756 is 8.46%.
# Estimating the effective power of n = 197,561 using 200 simulations.
# The effective power of sample size n = 197,561 is 36.82%.
# Estimating the effective power of n = 1,975,610 using 200 simulations.
# The effective power of sample size n = 1,975,610 is 100%.
# Estimating the effective power of n = 1,086,585 using 200 simulations.
# The effective power of sample size n = 1,086,585 is 100%.
# Estimating the effective power of n = 1,108,985 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 1,108,985 is 100%.
# Estimating the effective power of n = 1,012,819 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 1,012,819 is 99.5%.
# Estimating the effective power of n = 759,183 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 759,183 is 96.02%.
# Estimating the effective power of n = 607,214 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 607,214 is 88.56%.
# Estimating the effective power of n = 539,463 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 539,463 is 87.06%.
# Estimating the effective power of n = 491,393 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 491,393 is 86.07%.
# Estimating the effective power of n = 455,183 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 455,183 is 81.09%.
# Saved the results from sim_data_2019_12_31_080010.
# Binary search commenced, naively centered on n = 2,250,000.
# Estimating the effective power of n = 2,250,000 using 200 simulations.
# The effective power of sample size n = 2,250,000 is 100%.
# Binary search suggested the region of n = (0, 2,250,000).
# Now assessing the value 1,125,000 within the range n = (0, 2,250,000), and power = (0%, 100%).
# Estimating the effective power of n = 1,125,000 using 200 simulations.
# The effective power of sample size n = 1,125,000 is 100%.
# Now assessing the value 562,500 within the range n = (0, 1,125,000), and power = (0%, 100%).
# Estimating the effective power of n = 562,500 using 200 simulations.
# The effective power of sample size n = 562,500 is 89.05%.
# Now assessing the value 281,250 within the range n = (0, 562,500), and power = (0%, 89.05%).
# Estimating the effective power of n = 281,250 using 200 simulations.
# The effective power of sample size n = 281,250 is 61.19%.
# Now assessing the value 421,875 within the range n = (281,250, 562,500), and power = (61.19%, 89.05%).
# Estimating the effective power of n = 421,875 using 200 simulations.
# The effective power of sample size n = 421,875 is 76.12%.
# Now assessing the value 492,187 within the range n = (421,875, 562,500), and power = (76.12%, 89.05%).
# Estimating the effective power of n = 492,187 using 200 simulations.
# The effective power of sample size n = 492,187 is 88.56%.
# Now assessing the value 457,031 within the range n = (421,875, 492,187), and power = (76.12%, 88.56%).
# Estimating the effective power of n = 457,031 using 200 simulations.
# The effective power of sample size n = 457,031 is 80.1%.
# Saved the results from sim_data_2019_12_31_080010.
# Binary search commenced, centered on n = 197,561 informed by residual variance.
# Estimating the effective power of n = 197,561 using 200 simulations.
# The effective power of sample size n = 197,561 is 49.75%.
# Estimating the effective power of n = 1,975,610 using 200 simulations.
# The effective power of sample size n = 1,975,610 is 100%.
# Binary search suggested the region of n = (197,561, 1,975,610).
# Now assessing the value 1,086,585 within the range n = (197,561, 1,975,610), and power = (49.75%, 100%).
# Estimating the effective power of n = 1,086,585 using 200 simulations.
# The effective power of sample size n = 1,086,585 is 100%.
# Now assessing the value 642,073 within the range n = (197,561, 1,086,585), and power = (49.75%, 100%).
# Estimating the effective power of n = 642,073 using 200 simulations.
# The effective power of sample size n = 642,073 is 94.53%.
# Now assessing the value 419,817 within the range n = (197,561, 642,073), and power = (49.75%, 94.53%).
# Estimating the effective power of n = 419,817 using 200 simulations.
# The effective power of sample size n = 419,817 is 81.59%.
# Saved the results from sim_data_2019_12_31_080010.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data
# The file sim_data_2019_12_31_080010.csv was deleted.
# Assessment took 58 minutes and 18 seconds.

# %%
import pandas as pd
import os, os.path

files_found = len([name for name in os.listdir('./results/')])
print("{} files were found in total.".format(files_found))
print("{} iterations.".format(int(files_found/3)))
isotonic_results        = []
naive_binary_results    = []
informed_binary_results = []
[isotonic_results.append(name) for name in os.listdir('./results/') if "isotonic" in name]
[naive_binary_results.append(name) for name in os.listdir('./results/') if "naive_binary" in name]
[informed_binary_results.append(name) for name in os.listdir('./results/') if "informed_binary" in name]
isotonic_results.sort()
naive_binary_results.sort()
informed_binary_results.sort()


iso_sims, iso_time, iso_n = [], [], []
for i in isotonic_results:
    df = pd.read_csv('./results/' + i)
    df['delta'] = abs(df['power'] - 0.8)
    df.sort_values('delta',ascending=True, inplace=True)
    n = df.iat[0,0]
    iso_sims.append(df['sims_used'][0])
    iso_time.append(df['seconds_used'][0])
    iso_n.append(n)
   # print(df)
    
naive_sims, naive_time, naive_n = [], [], []
for j in naive_binary_results:
    df = pd.read_csv('./results/' + j)
    df['delta'] = abs(df['power'] - 0.8)
    df.sort_values('delta',ascending=True, inplace=True)
    n = df.iat[0,0]
    naive_sims.append(df['sims_used'][0])
    naive_time.append(df['seconds_used'][0])
    naive_n.append(n)
   # print(df)
    
informed_sims, informed_time, informed_n = [], [], []
for k in informed_binary_results:
    df = pd.read_csv('./results/' + k)
    df['delta'] = abs(df['power'] - 0.8)
    df.sort_values('delta',ascending=True, inplace=True)
    n = df.iat[0,0]
    informed_sims.append(df['sims_used'][0])
    informed_time.append(df['seconds_used'][0])
    informed_n.append(n)
#     print(df)
# Out:
# 168 files were found in total.
# 56 iterations.

# %%
results_df = pd.DataFrame([iso_sims, iso_time, iso_n, 
                           naive_sims, naive_time, naive_n, 
                           informed_sims, informed_time, informed_n]).T
results_df.columns = ['iso_sims', 'iso_time', 'iso_n', 
                      'naive_sims', 'naive_time', 'naive_n', 
                      'informed_sims', 'informed_time', 'informed_n']
results_df
# Out:
#     iso_sims     iso_time     iso_n  naive_sims   naive_time   naive_n  \
# 0     1400.0   186.870240   25654.0      2000.0  1100.916537   24413.0
# 1     2000.0   226.614795   54430.0      2200.0   515.909657   56151.0
# 2     1600.0   163.364054   26082.0      2000.0   813.088393   24413.0
# 3     1200.0   207.421850  255325.0      1400.0   340.255747  195312.0
# 4     1600.0   155.855299    8276.0      2200.0   501.531684    7323.0
# 5     1400.0   151.598957   51722.0      1800.0   672.171868   48827.0
# 6     2400.0   306.044040   15269.0      2000.0   424.369903   14648.0
# 7     1800.0   169.633031   12729.0      2200.0   465.253993   12206.0
# 8     1600.0   306.777187   83322.0      1800.0  1035.649396   87890.0
# 9     1400.0   138.297982    8982.0      2400.0   987.747879    8544.0
# 10    2000.0   341.523986  103828.0      1400.0   684.139256  117187.0
# 11    1600.0   135.099750   15639.0      2000.0   361.911925   14648.0
# 12    1600.0   186.323281   40194.0      2000.0   407.287731   43944.0
# 13    2000.0   729.695568  460507.0      1000.0   571.485404  468750.0
# 14    1400.0   197.185688   44365.0      1400.0   537.758183   39062.0
# 15    1600.0   175.800691   17967.0      2800.0   566.891966   18615.0
# 16    2000.0   388.308901  106347.0      2000.0  1069.862799  102538.0
# 17    1400.0   200.423016   71691.0      1800.0   630.101042   68359.0
# 18    1400.0   186.129759  242928.0      1600.0   304.163272  214843.0
# 19    1600.0   520.236675  150120.0      1800.0  1038.287374  146484.0
# 20    1600.0   201.366417   84886.0      1200.0   481.865442   78125.0
# 21    2400.0   296.632161   46562.0      2400.0  1000.516612   45164.0
# 22    1400.0   811.787490  417591.0      1400.0   943.164055  351562.0
# 23    1600.0   381.322299  156923.0      2400.0  1017.398460  157470.0
# 24    2200.0   580.258577  205284.0      1400.0   674.722919  195312.0
# 25    1600.0   178.405765   91611.0      1600.0   394.845129   97656.0
# 26    1200.0   157.508773  388925.0      1200.0   248.993060  390625.0
# 27    1400.0   191.770203   69638.0      1800.0   872.261982   68359.0
# 28    1800.0   168.706332   46307.0      2800.0   490.711655   38756.0
# 29    2200.0   465.557169  196773.0      2000.0   580.984509  200194.0
# 30    1800.0   217.717321   59506.0      2000.0   627.171567   53710.0
# 31    2000.0   224.811199   60126.0      1600.0   488.451885   58593.0
# 32    1600.0   329.153554  276350.0      1600.0   468.891405  253906.0
# 33    2600.0   284.945233   60669.0      2200.0   605.942425   56151.0
# 34    2000.0   511.740422  141728.0      1600.0   909.898039  136718.0
# 35    1600.0   206.288911   46532.0      1800.0   645.432009   48827.0
# 36    1600.0   827.504693  330900.0      1200.0   909.362973  281250.0
# 37    1400.0   384.521352  413258.0       800.0   377.188206  375000.0
# 38    1400.0   684.344017  226484.0      1600.0  1689.909305  218750.0
# 39    1800.0   697.852242  322030.0      2200.0  1205.912188  312011.0
# 40    2000.0   855.332973  352213.0      1400.0   826.747175  351562.0
# 41    1800.0  1251.460395  264178.0      2000.0  2052.618700  254882.0
# 42    1600.0  1066.822327  508456.0      1200.0  1084.537500  421875.0
# 43    2000.0  2040.396609  725121.0      1200.0  1888.524858  703125.0
# 44    2800.0  2632.916060  608691.0      1200.0  1060.876231  703125.0
# 45    1800.0   897.719826  380177.0      1200.0  1080.798647  421875.0
# 46    2400.0  1150.595460  409887.0      1600.0   971.890521  386718.0
# 47    1800.0  1109.331549  321520.0      2000.0  2034.615612  325195.0
# 48    2400.0   683.483779  357324.0      1600.0   712.265640  316406.0
# 49    1200.0   624.273269  627453.0       800.0   817.148484  562500.0
# 50    2000.0  1568.663179  794552.0      1200.0  1169.208882  703125.0
# 51    2400.0  3520.494684  878480.0      1000.0  1544.278792  843750.0
# 52    1600.0  1270.847709  748233.0      1600.0  1474.574492  808593.0
# 53    1800.0  1398.422438  631148.0      1600.0  1379.100085  597656.0
# 54    1400.0   509.520418  279992.0      1000.0   863.766850  281250.0
# 55    2200.0  1552.703006  455183.0      1600.0  1391.223531  457031.0
#
#     informed_sims  informed_time  informed_n
# 0          1200.0     172.514374     25041.0
# 1          1600.0     226.426226     66668.0
# 2          1600.0     172.525409     26783.0
# 3          1800.0     294.838571    218060.0
# 4          1600.0     172.283137      7839.0
# 5          1200.0     171.078179     46514.0
# 6          1600.0     175.313675     15665.0
# 7          2000.0     194.952454     12825.0
# 8          2400.0     487.101268     76763.0
# 9          1600.0     182.250646      7957.0
# 10         1800.0     428.684814     89816.0
# 11         1600.0     134.144591     14826.0
# 12         2000.0     242.742399     40566.0
# 13         1200.0     769.302388    450235.0
# 14         1600.0     216.489031     46797.0
# 15         2000.0     224.865541     19759.0
# 16         1600.0     387.510327     99348.0
# 17         1600.0     268.493795     65386.0
# 18         1200.0     182.944175    223096.0
# 19         1800.0     625.290959    157613.0
# 20         1800.0     253.398258     83400.0
# 21         2400.0     328.711987     42076.0
# 22         2400.0    1465.746984    398505.0
# 23         1600.0     504.140358    177493.0
# 24         1800.0     556.224857    204204.0
# 25         1600.0     193.413788     83908.0
# 26         1000.0     151.340206    402803.0
# 27         1600.0     250.165091     65790.0
# 28         1800.0     176.769005     45282.0
# 29         1600.0     472.112824    169729.0
# 30         1600.0     199.113132     59605.0
# 31         1400.0     182.530515     60783.0
# 32         1800.0     414.048376    270515.0
# 33         1600.0     194.820576     55767.0
# 34         2000.0     532.921871    139066.0
# 35         1400.0     205.667147     40995.0
# 36         1800.0    1031.318291    318137.0
# 37         1600.0     520.416377    383723.0
# 38         1400.0    1066.644226    226363.0
# 39         1800.0     860.898965    272424.0
# 40         2200.0    1116.647831    347968.0
# 41         1400.0     983.582016    219674.0
# 42         1400.0    1148.297765    460183.0
# 43         1200.0    1776.680673    739544.0
# 44         1600.0    1971.191102    598873.0
# 45         1600.0    1002.128656    398749.0
# 46         1800.0    1079.834373    342725.0
# 47         1800.0    1021.672142    293314.0
# 48         1600.0     507.336203    340495.0
# 49         2000.0    1066.707895    568332.0
# 50         1600.0    1457.455377    702506.0
# 51         2000.0    3255.021756    756820.0
# 52         2200.0    1829.236283    764438.0
# 53         2400.0    1688.707349    624669.0
# 54         1600.0     626.392931    279747.0
# 55         1400.0    1202.645354    419817.0

# %%
results_df.describe()
# Out:
#           iso_sims     iso_time          iso_n   naive_sims   naive_time  \
# count    56.000000    56.000000      56.000000    56.000000    56.000000
# mean   1775.000000   625.149689  246072.642857  1692.857143   857.403283
# std     373.801114   655.798904  231484.418204   463.918936   432.005222
# min    1200.000000   135.099750    8276.000000   800.000000   248.993060
# 25%    1550.000000   195.831817   53753.000000  1400.000000   512.315164
# 50%    1600.000000   361.423143  176848.000000  1600.000000   815.118438
# 75%    2000.000000   815.716791  382364.000000  2000.000000  1063.122873
# max    2800.000000  3520.494684  878480.000000  2800.000000  2052.618700
#
#              naive_n  informed_sims  informed_time     informed_n
# count      56.000000      56.000000      56.000000      56.000000
# mean   236981.500000    1692.857143     661.137366  233392.482143
# std    225703.058036     319.008203     614.054196  218367.594159
# min      7323.000000    1000.000000     134.144591    7839.000000
# 25%     52489.250000    1600.000000     198.072963   53524.500000
# 50%    176391.000000    1600.000000     450.398819  173611.000000
# 75%    357421.500000    1800.000000    1024.083679  356906.750000
# max    843750.000000    2400.000000    3255.021756  764438.000000

# %%
import seaborn as sns
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure


fig, ax = plt.subplots()
fig.set_size_inches(12, 4.8, forward=True)

# x1 = results_df[results_df['iso_n'] <= 500000]['iso_n']
# y1 = results_df[results_df['iso_n'] <= 500000]['iso_time']
x1 = results_df['iso_n']
y1 = results_df['iso_time']

# x2 = results_df[results_df['informed_n'] <= 500000]['informed_n']
# y2 = results_df[results_df['informed_n'] <= 500000]['informed_time']
x2 = results_df['informed_n']
y2 = results_df['informed_time']

# x3 = results_df[results_df['naive_n'] <= 500000]['naive_n']
# y3 = results_df[results_df['naive_n'] <= 500000]['naive_time']
x3 = results_df['naive_n'] 
y3 = results_df['naive_time']

sns.regplot(x1, y1, lowess=True, 
            color = '#b300b3', 
            marker='o', scatter_kws={'s':10})
sns.regplot(x2, y2, lowess=True, 
            color = '#006600', 
            marker='o', scatter_kws={'s':10})
sns.regplot(x3, y3, lowess=True, 
            color = '#3333cc', 
            marker='o', scatter_kws={'s':10})

labels = ['Isotonic Interpolation', 'Informed Binary Search', 'Naive Binary Search']
plt.legend(labels, prop={'size': 14})
plt.ylabel('Estimation \nTIme \nin \nSeconds', size = 18).set_rotation(0)
plt.xlabel('Estimated Sample Size Required', size = 18)
# plt.xlim(0,500000)

ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,}'.format(int(x))))

ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,}'.format(int(x))))

ax.tick_params(axis='both', which='major', labelsize=16)
ax.yaxis.set_label_coords(-0.16,0.35)

# plt.show()
plt.savefig('v1.png')
plt.clf()
