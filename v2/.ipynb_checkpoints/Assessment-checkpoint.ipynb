# %%
import pandas as pd
from olsEmpowered import sim_data  as sd

# %%
x = sd.create_random_dgp(max_covariates = 10, 
                         permissible_distributions = ['normal', 
                                                      'exponential', 
                                                      'uniform'],
                         range_of_normal_loc = [50, 250], 
                         range_of_normal_scale = [5, 25],
                         range_of_exponential_scale = [0.5, 4],
                         range_of_uniform = [0,10],
                         range_of_betas = [0, 2.5],
                         range_of_abs_mde = [0.05, 1.00],
                         range_of_noise_loc = [-0.50, 0.50],
                         range_of_noise_scale = [0.00, 25.00],
                         sample_size = 25)
x.data.head(25)
# Out:
# 2 additional covariates will be created.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_28_204307.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_28_204307_log_file.txt.
# 25 observations of simulation data created in 0 minutes and 0 seconds.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/sim_data_2019_12_28_204307.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_28_204307_log_file.txt
# b
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v2/data/log_files/sim_data_2019_12_28_204307_log_file.txt.
#     ID           Y  treated        X0          X1      noise
# 0    1  203.796740        1  8.749414  144.818020  -7.014744
# 1    2  219.354217        1  7.992153  148.032987   3.979852
# 2    3  213.850972        0  8.392461  148.954585  -2.463924
# 3    4  213.285985        1  7.831206  144.711852   2.731685
# 4    5  192.016539        0  7.145451  133.942864  -2.452727
# 5    6  223.838839        1  8.191552  150.258363   5.224381
# 6    7  193.238408        0  7.514627  141.757210 -12.570982
# 7    8  194.985940        1  7.047151  139.969733  -8.623396
# 8    9  224.558816        0  8.740937  153.956282   0.972826
# 9   10  177.458999        0  8.420161  128.918757  -9.890051
# 10  11  213.609459        1  8.594358  144.747098   2.918027
# 11  12  219.365715        1  9.115425  147.027883   5.317754
# 12  13  199.919082        0  7.803883  142.985052  -7.698256
# 13  14  227.717640        0  7.083813  155.235052   2.469842
# 14  15  212.778809        1  7.883872  149.304888  -4.422318
# 15  16  208.648483        0  7.548463  141.933826   2.579910
# 16  17  202.909526        1  8.324073  146.494037 -10.277213
# 17  18  212.242406        1  9.142178  141.031127   6.861887
# 18  19  193.635603        0  7.338839  137.901879  -6.579674
# 19  20  202.971092        0  6.808828  138.482450   1.976238
# 20  21  217.536210        1  8.688637  147.920039   2.246509
# 21  22  204.212069        0  7.380374  139.824841   1.211771
# 22  23  209.709568        1  8.460802  145.063306  -1.423975
# 23  24  222.689738        1  8.062152  152.384033   1.016472
# 24  25  218.174274        0  7.691930  147.448373   4.116247
