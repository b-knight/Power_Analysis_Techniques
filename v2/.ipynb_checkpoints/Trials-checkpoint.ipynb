# %%
import pandas as pd
import supporting_functions as sf

observations = 2500000
num_retailers = 10000
retailer_loc = 100          
retailer_scale = 10
noise_loc = 0.0
noise_scale = 10
absolute_treatment_effect = 0.25

file_name = sf.create_sim_data(absolute_treatment_effect, observations, num_retailers, retailer_loc,             
                          retailer_scale, noise_loc, noise_scale)
data = pd.read_csv(file_name)

# %%
treatment_variable = 'Treated'
covariates = ['Mean_Retailer_Amount']
dependent_variable = 'Initial_Order_Amount'
absolute_mde          = 0.25
rejection_region      = 0.05
desired_power         = 0.8
search_orders         = 1
points_per_iteration  = 4
sims                  = 300
precison              = 0.025
model                 = 'isotonic'

############################################################

iterations   = 5
n_vector     = []
power_vector = []
sims_vector  = []
time_vector  = []
model_vector = []

for i in range(0, iterations):
    n, n_power, sims_used, time_taken = sf.derive_sample_size_recommendation(data, 
                                           treatment_variable, covariates, 
                                           dependent_variable, absolute_mde, 
                                           rejection_region, desired_power, 
                                           search_orders, points_per_iteration, 
                                           sims, precison, model) 
    n_vector.append(n)
    power_vector.append(n_power)
    sims_vector.append(sims_used)
    time_vector.append(time_taken) 
    model_vector.append(model)
    
model = 'exponential_cdf'

for i in range(0, iterations):
    n, n_power, sims_used, time_taken = sf.derive_sample_size_recommendation(data, 
                                           treatment_variable, covariates, 
                                           dependent_variable, absolute_mde, 
                                           rejection_region, desired_power, 
                                           search_orders, points_per_iteration, 
                                           sims, precison, model) 
    n_vector.append(n)
    power_vector.append(n_power)
    sims_vector.append(sims_used)
    time_vector.append(time_taken) 
    model_vector.append(model)
# Out:
# Determining direction of search.
# Starting sample size recommendation is 19,784.
# Estimating the effective power of n = 19,784 using 300 simulations.
# The effective power of sample size n = 19,784 is 41.2%.
# Starting power is 41.2%.
# Sample size of n = 19,784 is under-powered.
# Proposed sample size of 19,784 fails to meet desired power of 80%.
# The lower-bound for the proposed sample size search is 19,784.
# The upper-bound for the proposed sample size search is 197,840.
# 5 candidate sample sizes were recommended within the range 19,784 to 197,840.
# Proceeding with interpolation via isotonic regression.
# Estimating the effective power of n = 55,395 using 300 simulations.
# The effective power of sample size n = 55,395 is 85.71%.
# Estimating the effective power of n = 91,006 using 300 simulations.
# The effective power of sample size n = 91,006 is 98.34%.
# Estimating the effective power of n = 126,617 using 300 simulations.
# The effective power of sample size n = 126,617 is 99.34%.
# Estimating the effective power of n = 162,228 using 300 simulations.
# The effective power of sample size n = 162,228 is 100%.
# Estimating the effective power of n = 180,034 using 300 simulations.
# The effective power of sample size n = 180,034 is 100%.
# Specified range for isotonic regression failed to capture desired power.
# Now supplementing range.
# Estimating the effective power of n = 27,697 using 300 simulations.
# The effective power of sample size n = 27,697 is 57.81%.
# A sample size of 49,723 was recommended using 2,100 simulations.
# Estimating the effective power of n = 49,723 using 300 simulations.
# The effective power of sample size n = 49,723 is 83.06%.
# Results failed to meet required precision of +/- 2.5 points of statistical power.
# 5 candidate sample sizes were recommended within the range 27,697 to 49,723.
# Proceeding with interpolation via isotonic regression.
# Estimating the effective power of n = 32,102 using 300 simulations.
# The effective power of sample size n = 32,102 is 64.12%.
# Estimating the effective power of n = 36,507 using 300 simulations.
# The effective power of sample size n = 36,507 is 66.11%.
# Estimating the effective power of n = 40,912 using 300 simulations.
# The effective power of sample size n = 40,912 is 72.76%.
# Estimating the effective power of n = 45,317 using 300 simulations.
# The effective power of sample size n = 45,317 is 78.74%.
# Recommended sample size was attained after 3,600 simulations with (n = 45,317, power = 78.74%).
# The results meet the required precision of +/- 2.5 points of statistical power.
# Interpolation concluded after 3,600 simulations with
# a recommended sample size of 45,317 with 78.74% statistical power
# Power estimation took 6 minutes and 14 seconds.
# Determining direction of search.
# Starting sample size recommendation is 19,784.
# Estimating the effective power of n = 19,784 using 300 simulations.
# The effective power of sample size n = 19,784 is 42.86%.
# Starting power is 42.86%.
# Sample size of n = 19,784 is under-powered.
# Proposed sample size of 19,784 fails to meet desired power of 80%.
# The lower-bound for the proposed sample size search is 19,784.
# The upper-bound for the proposed sample size search is 197,840.
# 5 candidate sample sizes were recommended within the range 19,784 to 197,840.
# Proceeding with interpolation via isotonic regression.
# Estimating the effective power of n = 55,395 using 300 simulations.
# The effective power of sample size n = 55,395 is 85.05%.
# Estimating the effective power of n = 91,006 using 300 simulations.
# The effective power of sample size n = 91,006 is 92.69%.
# Estimating the effective power of n = 126,617 using 300 simulations.
# The effective power of sample size n = 126,617 is 58.47%.
# Estimating the effective power of n = 162,228 using 300 simulations.
# The effective power of sample size n = 162,228 is 28.24%.
# Estimating the effective power of n = 180,034 using 300 simulations.
# The effective power of sample size n = 180,034 is 74.09%.
# A sample size of 123,056 was recommended using 1,800 simulations.
# Estimating the effective power of n = 123,056 using 300 simulations.
# The effective power of sample size n = 123,056 is 85.71%.
# Results failed to meet required precision of +/- 2.5 points of statistical power.
# 5 candidate sample sizes were recommended within the range 123,056 to 180,034.
# Proceeding with interpolation via isotonic regression.
# Estimating the effective power of n = 134,451 using 300 simulations.
# The effective power of sample size n = 134,451 is 85.71%.
# Estimating the effective power of n = 145,847 using 300 simulations.
# The effective power of sample size n = 145,847 is 78.74%.
# Recommended sample size was attained after 2,700 simulations with (n = 145,847, power = 78.74%).
# The results meet the required precision of +/- 2.5 points of statistical power.
# Interpolation concluded after 2,700 simulations with
# a recommended sample size of 145,847 with 78.74% statistical power
# Power estimation took 9 minutes and 38 seconds.
# Determining direction of search.
# Starting sample size recommendation is 19,784.
# Estimating the effective power of n = 19,784 using 300 simulations.
# The effective power of sample size n = 19,784 is 45.51%.
# Starting power is 45.51%.
# Sample size of n = 19,784 is under-powered.
# Proposed sample size of 19,784 fails to meet desired power of 80%.
# The lower-bound for the proposed sample size search is 19,784.
# The upper-bound for the proposed sample size search is 197,840.
# 5 candidate sample sizes were recommended within the range 19,784 to 197,840.
# Proceeding with interpolation via isotonic regression.
# Estimating the effective power of n = 55,395 using 300 simulations.
# The effective power of sample size n = 55,395 is 81.73%.
# Recommended sample size was attained after 600 simulations with (n = 55,395, power = 81.73%).
# The results meet the required precision of +/- 2.5 points of statistical power.
# Interpolation concluded after 600 simulations with
# a recommended sample size of 55,395 with 81.73% statistical power
# Power estimation took 1 minutes and 21 seconds.
# Determining direction of search.
# Starting sample size recommendation is 19,784.
# Estimating the effective power of n = 19,784 using 300 simulations.
# The effective power of sample size n = 19,784 is 45.85%.
# Starting power is 45.85%.
# Sample size of n = 19,784 is under-powered.
# Proposed sample size of 19,784 fails to meet desired power of 80%.
# The lower-bound for the proposed sample size search is 19,784.
# The upper-bound for the proposed sample size search is 197,840.
# 5 candidate sample sizes were recommended within the range 19,784 to 197,840.
# Proceeding with interpolation via isotonic regression.
# Estimating the effective power of n = 55,395 using 300 simulations.
# The effective power of sample size n = 55,395 is 82.72%.
# Estimating the effective power of n = 91,006 using 300 simulations.
# The effective power of sample size n = 91,006 is 94.68%.
# Estimating the effective power of n = 126,617 using 300 simulations.
# The effective power of sample size n = 126,617 is 79.4%.
# Recommended sample size was attained after 1,200 simulations with (n = 126,617, power = 79.4%).
# The results meet the required precision of +/- 2.5 points of statistical power.
# Interpolation concluded after 1,200 simulations with
# a recommended sample size of 126,617 with 79.4% statistical power
# Power estimation took 4 minutes and 14 seconds.
# Determining direction of search.
# Starting sample size recommendation is 19,784.
# Estimating the effective power of n = 19,784 using 300 simulations.
# The effective power of sample size n = 19,784 is 49.17%.
# Starting power is 49.17%.
# Sample size of n = 19,784 is under-powered.
# Proposed sample size of 19,784 fails to meet desired power of 80%.
# The lower-bound for the proposed sample size search is 19,784.
# The upper-bound for the proposed sample size search is 197,840.
# 5 candidate sample sizes were recommended within the range 19,784 to 197,840.
# Proceeding with interpolation via isotonic regression.
# Estimating the effective power of n = 55,395 using 300 simulations.
# The effective power of sample size n = 55,395 is 84.39%.
# Estimating the effective power of n = 91,006 using 300 simulations.
# The effective power of sample size n = 91,006 is 93.36%.
# Estimating the effective power of n = 126,617 using 300 simulations.
# The effective power of sample size n = 126,617 is 51.16%.
# Estimating the effective power of n = 162,228 using 300 simulations.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-0b24d963a456> in <module>
#      26                                            rejection_region, desired_power,
#      27                                            search_orders, points_per_iteration,
# ---> 28                                            sims, precison, model)
#      29     n_vector.append(n)
#      30     power_vector.append(n_power)
#
# ~/Documents/Power_Analysis_Techniques/v2/supporting_functions.py in derive_sample_size_recommendation(data, treatment_variable, covariates, dependent_variable, absolute_mde, rejection_region, desired_power, search_orders, points_per_iteration, sims, precison, model)
#     442                                                                model, precison, desired_power,
#     443                                                                rejection_region, points_per_iteration,
# --> 444                                                                sims, prior_sims)
#     445     end = time.time()
#     446     time_elapsed = end - start
#
# ~/Documents/Power_Analysis_Techniques/v2/supporting_functions.py in create_interpolated_recommendation(data, candidates, treatment_variable, covariates, dependent_variable, model, precison, desired_power, rejection_region, points_per_iteration, sims, prior_sims)
#     409     a,b,c,d,e = interpolate_recommendation(data, candidates, treatment_variable, covariates,
#     410                                            dependent_variable, model, precison, desired_power,
# --> 411                                            rejection_region, sims, prior_sims)
#     412     while a != c:
#     413         candidates = create_range(a, c, points_per_iteration)
#
# ~/Documents/Power_Analysis_Techniques/v2/supporting_functions.py in interpolate_recommendation(data, candidates, treatment_variable, covariates, dependent_variable, model, precison, desired_power, rejection_region, sims, sims_used)
#     297     for i in candidates:
#     298         power = assess_power(data, i, treatment_variable,
# --> 299                              covariates, dependent_variable, rejection_region, sims)
#     300         sims_used += sims
#     301         delta = abs(desired_power - power)
#
# ~/Documents/Power_Analysis_Techniques/v2/supporting_functions.py in assess_power(data, candidate_n, treatment_variable, covariates, dependent_variable, rejection_region, sims)
#     155             x = sm.add_constant(x)
#     156             y = subsample[dependent_variable]
# --> 157             model = sm.OLS(y.astype(float), x.astype(float)).fit()
#     158             if model.pvalues[1] < rejection_region:
#     159                 results.append(1)
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/regression/linear_model.py in fit(self, method, cov_type, cov_kwds, use_t, **kwargs)
#     271                     hasattr(self, 'rank')):
#     272
# --> 273                 self.pinv_wexog, singular_values = pinv_extended(self.wexog)
#     274                 self.normalized_cov_params = np.dot(
#     275                     self.pinv_wexog, np.transpose(self.pinv_wexog))
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tools/tools.py in pinv_extended(X, rcond)
#     340     X = np.asarray(X)
#     341     X = X.conjugate()
# --> 342     u, s, vt = np.linalg.svd(X, 0)
#     343     s_orig = np.copy(s)
#     344     m = u.shape[0]
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py in svd(a, full_matrices, compute_uv)
#    1560
#    1561         signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1562         u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1563         u = u.astype(result_t, copy=False)
#    1564         s = s.astype(_realType(result_t), copy=False)
#
# KeyboardInterrupt:

# %%
labels = []
for i in range(0, iterations*2):
    labels.append(file_name)    
data = [labels, n_vector, power_vector, sims_vector, time_vector, model_vector]
df = pd.DataFrame.from_records(data).T
df.columns = ['File', 'Recommended n', 'Est. Power', 'Simulations Used', 'Seconds', 'Model']
df
# Out:
#                                       File Recommended n Est. Power  \
# 0    ./data/sim_data_2019_12_23_083149.csv         45317   0.787375
# 1    ./data/sim_data_2019_12_23_083149.csv        145847   0.787375
# 2    ./data/sim_data_2019_12_23_083149.csv         55395   0.817276
# 3    ./data/sim_data_2019_12_23_083149.csv        126617    0.79402
# 4    ./data/sim_data_2019_12_23_083149.csv          None       None
# 5    ./data/sim_data_2019_12_23_083149.csv          None       None
# 6    ./data/sim_data_2019_12_23_083149.csv          None       None
# 7    ./data/sim_data_2019_12_23_083149.csv          None       None
# 8    ./data/sim_data_2019_12_23_083149.csv          None       None
# 9    ./data/sim_data_2019_12_23_083149.csv          None       None
# 10   ./data/sim_data_2019_12_23_083149.csv          None       None
# 11   ./data/sim_data_2019_12_23_083149.csv          None       None
# 12   ./data/sim_data_2019_12_23_083149.csv          None       None
# 13   ./data/sim_data_2019_12_23_083149.csv          None       None
# 14   ./data/sim_data_2019_12_23_083149.csv          None       None
# 15   ./data/sim_data_2019_12_23_083149.csv          None       None
# 16   ./data/sim_data_2019_12_23_083149.csv          None       None
# 17   ./data/sim_data_2019_12_23_083149.csv          None       None
# 18   ./data/sim_data_2019_12_23_083149.csv          None       None
# 19   ./data/sim_data_2019_12_23_083149.csv          None       None
# 20   ./data/sim_data_2019_12_23_083149.csv          None       None
# 21   ./data/sim_data_2019_12_23_083149.csv          None       None
# 22   ./data/sim_data_2019_12_23_083149.csv          None       None
# 23   ./data/sim_data_2019_12_23_083149.csv          None       None
# 24   ./data/sim_data_2019_12_23_083149.csv          None       None
# 25   ./data/sim_data_2019_12_23_083149.csv          None       None
# 26   ./data/sim_data_2019_12_23_083149.csv          None       None
# 27   ./data/sim_data_2019_12_23_083149.csv          None       None
# 28   ./data/sim_data_2019_12_23_083149.csv          None       None
# 29   ./data/sim_data_2019_12_23_083149.csv          None       None
# ..                                     ...           ...        ...
