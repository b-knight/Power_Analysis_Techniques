# %%
import pandas as pd
import numpy as np
from OLSPA import f_stat as f
import statsmodels.api as sm

# %%
result_df = pd.DataFrame(columns=['Abs_MDE', 'r_squared', 
                                  'n_recommendation_f_stat',       'pow_est_f_stat',
                                  'n_recommendation_t_test',       'pow_est_t_test',
                                  'n_recommendation_t_test_PRESS', 'pow_est_t_test_PRESS'])

# %%
candidates = list(np.linspace(0, 10, 20))[1:]
candidates.sort()

# %%
for i in candidates:
    mde = i
    df = f.create_data(n=1000000, mu=100, sigma=25, mde=mde)
    X = df['Treated']
    X = sm.add_constant(X)
    Y = df['DV']
    model = sm.OLS(Y.astype(float), X.astype(float)).fit()
    rsquared = model.rsquared
    delta = f.extract_r_delta(df)
    f_stat_n = f.get_f_stat_n(1, delta)
    recommended_n_norm, recommended_n_press = f.acquire_sample_sizes_via_hueristic(df, mde)
    print("f-stat:{}, std:{}, PRESS:{}".format(f_stat_n, recommended_n_norm, recommended_n_press))

    f_stat_pow  = f.assess_power(df, f_stat_n, iterations = 1000)
    n_norm_pow  = f.assess_power(df, recommended_n_norm, iterations = 1000)
    n_press_pow = f.assess_power(df, recommended_n_press, iterations = 1000)

    result_df = result_df.append({'Abs_MDE' : mde, 
                                  'r_squared' : rsquared, 
                                  'n_recommendation_f_stat' : f_stat_n,      
                                  'pow_est_f_stat' : f_stat_pow,
                                  'n_recommendation_t_test' : recommended_n_norm,       
                                  'pow_est_t_test' : n_norm_pow,
                                  'n_recommendation_t_test_PRESS' : recommended_n_press, 
                                  'pow_est_t_test_PRESS' : n_press_pow}, 
                                  ignore_index=True)
# Out:
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The s.e. of the regressed residuals is 25.006879519149166.
# The s.e. of the regressed PRESS residuals is 25.006929533092105.
# The estimated effect size via normal residuals is 0.02104683989342432.
# The estimated effect size via PRESS residuals is 0.02104679779967394.
# f-stat:63933, std:27914, PRESS:27914
# The s.e. of the regressed residuals is 25.002991762801692.
# The s.e. of the regressed PRESS residuals is 25.003041768920873.
# The estimated effect size via normal residuals is 0.042100225002410535.
# The estimated effect size via PRESS residuals is 0.04210014080190051.
# f-stat:15937, std:6977, PRESS:6977
# The s.e. of the regressed residuals is 25.01908562146985.
# The s.e. of the regressed PRESS residuals is 25.01913565968441.
# The estimated effect size via normal residuals is 0.06310971521141831.
# The estimated effect size via PRESS residuals is 0.06310958899213105.
# f-stat:8007, std:3105, PRESS:3105
# The s.e. of the regressed residuals is 25.014067061290657.
# The s.e. of the regressed PRESS residuals is 25.014117089664612.
# The estimated effect size via normal residuals is 0.08416316917742007.
# The estimated effect size via PRESS residuals is 0.08416300085061143.
# f-stat:4808, std:1746, PRESS:1746
# The s.e. of the regressed residuals is 24.98417625449212.
# The s.e. of the regressed PRESS residuals is 24.984226222870397.
# The estimated effect size via normal residuals is 0.10532982638942386.
# The estimated effect size via PRESS residuals is 0.10532961573008376.
# f-stat:2946, std:1115, PRESS:1115
# The s.e. of the regressed residuals is 24.967253061589975.
# The s.e. of the regressed PRESS residuals is 24.967302996056247.
# The estimated effect size via normal residuals is 0.12648146470306987.
# The estimated effect size via PRESS residuals is 0.12648121174084825.
# f-stat:1854, std:773, PRESS:773
# The s.e. of the regressed residuals is 24.989110486863908.
# The s.e. of the regressed PRESS residuals is 24.989160465225865.
# The estimated effect size via normal residuals is 0.14743263983936036.
# The estimated effect size via PRESS residuals is 0.1474323449738386.
# f-stat:1451, std:569, PRESS:569
# The s.e. of the regressed residuals is 25.006316294890055.
# The s.e. of the regressed PRESS residuals is 25.00636630736772.
# The estimated effect size via normal residuals is 0.16837851149830807.
# The estimated effect size via PRESS residuals is 0.16837817474300176.
# f-stat:1112, std:436, PRESS:436
# The s.e. of the regressed residuals is 24.965171448015784.
# The s.e. of the regressed PRESS residuals is 24.965221378463962.
# The estimated effect size via normal residuals is 0.18973801622498526.
# The estimated effect size via PRESS residuals is 0.18973763674891161.
# f-stat:909, std:344, PRESS:344
# The s.e. of the regressed residuals is 25.007883592678702.
# The s.e. of the regressed PRESS residuals is 25.007933608672705.
# The estimated effect size via normal residuals is 0.2104599485690857.
# The estimated effect size via PRESS residuals is 0.21045952764812156.
# f-stat:731, std:279, PRESS:279
# The s.e. of the regressed residuals is 25.02717209396729.
# The s.e. of the regressed PRESS residuals is 25.02722214840807.
# The estimated effect size via normal residuals is 0.231327521242644.
# The estimated effect size via PRESS residuals is 0.23132705858763403.
# f-stat:595, std:231, PRESS:231
# /home/bknight/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:162: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# The s.e. of the regressed residuals is 24.998172412764216.
# The s.e. of the regressed PRESS residuals is 24.998222409203795.
# The estimated effect size via normal residuals is 0.25265004854752227.
# The estimated effect size via PRESS residuals is 0.2526495432474781.
# f-stat:1000, std:194, PRESS:194
# The s.e. of the regressed residuals is 25.036070390059898.
# The s.e. of the regressed PRESS residuals is 25.03612046229352.
# The estimated effect size via normal residuals is 0.27328990358943966.
# The estimated effect size via PRESS residuals is 0.2732893570097122.
# f-stat:1000, std:166, PRESS:166
# The s.e. of the regressed residuals is 24.9845178473517.
# The s.e. of the regressed PRESS residuals is 24.984567816460522.
# The estimated effect size via normal residuals is 0.2949194816426131.
# The estimated effect size via PRESS residuals is 0.2949188918039663.
# f-stat:1000, std:142, PRESS:142
# The s.e. of the regressed residuals is 24.990131002485427.
# The s.e. of the regressed PRESS residuals is 24.990180982847473.
# The estimated effect size via normal residuals is 0.31591418393605386.
# The estimated effect size via PRESS residuals is 0.31591355210768496.
# f-stat:1000, std:124, PRESS:124
# The s.e. of the regressed residuals is 24.990447138770467.
# The s.e. of the regressed PRESS residuals is 24.990497119807475.
# The estimated effect size via normal residuals is 0.3369708667002772.
# The estimated effect size via PRESS residuals is 0.33697019275796714.
# f-stat:1000, std:109, PRESS:109
# The s.e. of the regressed residuals is 24.98828843168944.
# The s.e. of the regressed PRESS residuals is 24.98833840840942.
# The estimated effect size via normal residuals is 0.3580624757678814.
# The estimated effect size via PRESS residuals is 0.3580617596423114.
# f-stat:1000, std:97, PRESS:97
# The s.e. of the regressed residuals is 24.99950409134562.
# The s.e. of the regressed PRESS residuals is 24.999554090379675.
# The estimated effect size via normal residuals is 0.37895488550134615.
# The estimated effect size via PRESS residuals is 0.3789541275926988.
# f-stat:1000, std:86, PRESS:86
# The s.e. of the regressed residuals is 24.991259025228253.
# The s.e. of the regressed PRESS residuals is 24.991309007802077.
# The estimated effect size via normal residuals is 0.4001399045124205.
# The estimated effect size via PRESS residuals is 0.40013910423331905.
# f-stat:1000, std:77, PRESS:77

# %%
result_df
# Out:
#       Abs_MDE  r_squared  n_recommendation_f_stat  pow_est_f_stat  \
# 0    0.526316   0.000123                  63933.0           0.812
# 1    1.052632   0.000492                  15937.0           0.789
# 2    1.578947   0.000980                   8007.0           0.799
# 3    2.105263   0.001632                   4808.0           0.779
# 4    2.631579   0.002664                   2946.0           0.811
# 5    3.157895   0.004233                   1854.0           0.811
# 6    3.684211   0.005408                   1451.0           0.818
# 7    4.210526   0.007057                   1112.0           0.808
# 8    4.736842   0.008632                    909.0           0.811
# 9    5.263158   0.010731                    731.0           0.816
# 10   5.789474   0.013185                    595.0           0.801
# 11   6.315789   0.015660                   1000.0           0.982
# 12   6.842105   0.018481                   1000.0           0.989
# 13   7.368421   0.021740                   1000.0           0.998
# 14   7.894737   0.024568                   1000.0           1.000
# 15   8.421053   0.027810                   1000.0           0.999
# 16   8.947368   0.031382                   1000.0           1.000
# 17   9.473684   0.034145                   1000.0           1.000
# 18  10.000000   0.038687                   1000.0           1.000
#
#     n_recommendation_t_test  pow_est_t_test  n_recommendation_t_test_PRESS  \
# 0                   27914.0           0.458                        27914.0
# 1                    6977.0           0.470                         6977.0
# 2                    3105.0           0.404                         3105.0
# 3                    1746.0           0.394                         1746.0
# 4                    1115.0           0.407                         1115.0
# 5                     773.0           0.431                          773.0
# 6                     569.0           0.377                          569.0
# 7                     436.0           0.440                          436.0
# 8                     344.0           0.412                          344.0
# 9                     279.0           0.448                          279.0
# 10                    231.0           0.456                          231.0
# 11                    194.0           0.428                          194.0
# 12                    166.0           0.453                          166.0
# 13                    142.0           0.402                          142.0
# 14                    124.0           0.419                          124.0
# 15                    109.0           0.399                          109.0
# 16                     97.0           0.411                           97.0
# 17                     86.0           0.392                           86.0
# 18                     77.0           0.413                           77.0
#
#     pow_est_t_test_PRESS
# 0                  0.471
# 1                  0.478
# 2                  0.404
# 3                  0.412
# 4                  0.404
# 5                  0.461
# 6                  0.412
# 7                  0.426
# 8                  0.414
# 9                  0.398
# 10                 0.414
# 11                 0.442
# 12                 0.461
# 13                 0.422
# 14                 0.427
# 15                 0.432
# 16                 0.402
# 17                 0.382
# 18                 0.400

# %%
import seaborn as sns
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure


fig, ax = plt.subplots()
fig.set_size_inches(12, 4.8, forward=True)



x1 = result_df['r_squared']
y1 = result_df['pow_est_f_stat']


x2 = result_df['r_squared']
y2 = result_df['pow_est_t_test']

x3 = result_df['r_squared'] 
y3 = result_df['pow_est_t_test_PRESS']

sns.regplot(x1, y1, 
            lowess=True, 
            ci=95, 
            color = '#b300b3', 
            marker='o', 
#             scatter_kws={'s':10}
           )
# sns.regplot(x2, y2, 
#             lowess=True, 
#             ci=95, 
#             color = '#006600', 
#             marker='o', 
# #             scatter_kws={'s':10}
#            )
# sns.regplot(x3, y3, 
#             lowess=True, 
#             ci=95, 
#             color = '#3333cc', 
#             marker='o', 
#             scatter_kws={'s':10}
#            )

# labels = [
#          'Isotonic Interpolation', 
#          'Binary Search (with Starting Value)', 
#          'Binary Search (Uninformed)'
#          ]
# plt.legend(labels, prop={'size': 14})
plt.title("Linear Trends of Power Estimation Runtimes \nfor 100 Simulated A/B Tests (with 95% C.I.)", 
          size = 24, y=1.08)
plt.ylabel('Estimated Power', size = 18).set_rotation(0)
plt.xlabel('r-Squared', size = 18)
# plt.xlim(0,0.01)

# ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,}'.format(int(x))))

# ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,}'.format(int(x))))

ax.tick_params(axis='both', which='major', labelsize=16)
ax.yaxis.set_label_coords(-0.16,0.35)

plt.show()
# plt.savefig('v1.png',bbox_inches='tight')
plt.clf()

# %%
def get_f_stat_n(u, f2, sig_level = 0.05):
    from scipy.stats import f
    from scipy import special
    from scipy.optimize import fsolve
    """Returns recommended sample size using the f-test.

    Keyword arguments:
    u  -- DF Numerator = (k-1) where k is the number of covariates + 1 for the intercept  
    f2 -- R2/(1−R2) where R2 is the coefficient of determination
    """
    def my_func(v):
        return 1-special.ncfdtr(u, v, f2*(u+v+1), f.ppf(1-sig_level, u, v))-0.8
    return int(fsolve(my_func, 1000))

# %%
get_f_stat_n(1, 0.038687, sig_level = 0.05)
# Out:
# /home/bknight/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:162: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# 1000
