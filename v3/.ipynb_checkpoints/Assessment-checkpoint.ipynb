# %%
import time
from olsEmpowered import sim_data         as sd
from olsEmpowered import power_estimation as pe
from olsEmpowered import isotonic         as iso
from olsEmpowered import binary_search    as bst
# Out:
# /home/bknight/anaconda3/lib/python3.7/site-packages/statsmodels/compat/pandas.py:49: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   data_klasses = (pandas.Series, pandas.DataFrame, pandas.Panel)

# %%
dgps_analyzed = 0

while dgps_analyzed < 2:
    start = time.time()
    dgp = sd.create_random_dgp(max_covariates             = 10, 
                               permissible_distributions  = ['normal', 
                                                             'exponential', 
                                                             'uniform'],
                               range_of_normal_loc        = [50, 250], 
                               range_of_normal_scale      = [5, 25],
                               range_of_exponential_scale = [0.5, 4],
                               range_of_uniform           = [0,10],
                               range_of_betas             = [0, 2.5],
                               range_of_abs_mde           = [0.10, 0.20],
                               range_of_noise_loc         = [25.0, 50.0],
                               range_of_noise_scale       = [20.00, 35.00],
                               sample_size                = 4500000)
    pe_ob = pe.power_estimation(dgp)
    print("############## Starting value is n = {:,}.    ###########".format(pe_ob.starting_value))
    print("############## Starting adj. R-squared is {}. ###########".format(round(pe_ob.rsquared_adj,2)))
    if pe_ob.starting_value > 475000: 
        sd.remove_data(dgp, drop_meta_data = True)
        print("Starting value too high.")
        continue
    if pe_ob.starting_value < 500: 
        sd.remove_data(dgp, drop_meta_data = True)
        print("Starting value too low.")
        continue       
    if pe_ob.rsquared_adj > 0.95:
        sd.remove_data(dgp, drop_meta_data = True)
        print("r-squared too high.")
        continue 
    
    iso_ob = iso.isotonic(pe_ob)
    n1, p1,  df1 = iso_ob.isotonic_interpolation()
   
    naive_bst = bst.binary_search(pe_ob, informed = 0)
    n2, p2,  df2 = naive_bst.binary_search()

    informed_bst = bst.binary_search(pe_ob, informed = 1)
    n3, p3,  df3 = informed_bst.binary_search()
    
    pe.save_results(df1, iso_ob)
    del iso_ob
    pe.save_results(df2, naive_bst)
    del naive_bst
    pe.save_results(df3, informed_bst)
    del informed_bst

    dgps_analyzed += 1
    sd.remove_data(dgp, drop_meta_data = False)
    end = time.time()
    time_elapsed = end - start
    time_min = int(time_elapsed/60)
    time_sec = int(time_elapsed - (time_min*60))
    print("Assessment took {} minutes and {} seconds.".format(time_min, time_sec))
# Out:
# 4 additional covariates will be created.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v3/data/sim_data_2020_01_04_142227.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v3/data/log_files/sim_data_2020_01_04_142227_log_file.txt.
# 4500000 observations of simulation data created in 1 minutes and 16 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v3/data/sim_data_2020_01_04_142227.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v3/data/log_files/sim_data_2020_01_04_142227_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v3/data/log_files/sim_data_2020_01_04_142227_log_file.txt.
# ############## Starting value is n = 491,157.    ###########
# ############## Starting adj. R-squared is 0.65. ###########
# /home/bknight/Documents/Power_Analysis_Techniques/v3/data
# The file sim_data_2020_01_04_142227.csv was deleted.
# The the associated meta-data for file sim_data_2020_01_04_142227.csv was also deleted.
# Starting value too high.
# 2 additional covariates will be created.
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v3/data/sim_data_2020_01_04_142351.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v3/data/log_files/sim_data_2020_01_04_142351_log_file.txt.
# 4500000 observations of simulation data created in 0 minutes and 55 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v3/data/sim_data_2020_01_04_142351.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v3/data/log_files/sim_data_2020_01_04_142351_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v3/data/log_files/sim_data_2020_01_04_142351_log_file.txt.
# ############## Starting value is n = 519,339.    ###########
# ############## Starting adj. R-squared is 0.16. ###########
# /home/bknight/Documents/Power_Analysis_Techniques/v3/data
# The file sim_data_2020_01_04_142351.csv was deleted.
# The the associated meta-data for file sim_data_2020_01_04_142351.csv was also deleted.
# Starting value too high.
# 5 additional covariates will be created.
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v3/data/sim_data_2020_01_04_142452.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v3/data/log_files/sim_data_2020_01_04_142452_log_file.txt.
# 4500000 observations of simulation data created in 1 minutes and 25 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v3/data/sim_data_2020_01_04_142452.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v3/data/log_files/sim_data_2020_01_04_142452_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v3/data/log_files/sim_data_2020_01_04_142452_log_file.txt.
# ############## Starting value is n = 295,345.    ###########
# ############## Starting adj. R-squared is 0.07. ###########
# Estimating the effective power of n = 295,345 using 200 simulations.
# The effective power of sample size n = 295,345 is 42.29%.
# An upper-bound of n = 715,370 was specified.
# Estimating the effective power of n = 715,370 using 200 simulations.
# The effective power of sample size n = 715,370 is 85.07%.
# Estimating the effective power of n = 665,553 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 665,553 is 82.59%.
# Estimating the effective power of n = 641,786 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 641,786 is 85.07%.
# Estimating the effective power of n = 641,786 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 641,786 is 77.11%.
# Estimating the effective power of n = 654,317 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 654,317 is 76.12%.
# Estimating the effective power of n = 657,279 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 657,279 is 83.58%.
# Estimating the effective power of n = 655,098 using 200 simulations.
# /home/bknight/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# The effective power of sample size n = 655,098 is 79.1%.
# Binary search commenced, naively centered on n = 2,250,000.
# Estimating the effective power of n = 2,250,000 using 200 simulations.
# The effective power of sample size n = 2,250,000 is 100%.
# Binary search suggested the region of n = (0, 2,250,000).
# Now assessing the value 1,125,000 within the range n = (0, 2,250,000), and power = (0%, 100%).
# Estimating the effective power of n = 1,125,000 using 200 simulations.
# The effective power of sample size n = 1,125,000 is 98.01%.
# Now assessing the value 562,500 within the range n = (0, 1,125,000), and power = (0%, 98.01%).
# Estimating the effective power of n = 562,500 using 200 simulations.
# The effective power of sample size n = 562,500 is 70.65%.
# Now assessing the value 843,750 within the range n = (562,500, 1,125,000), and power = (70.65%, 98.01%).
# Estimating the effective power of n = 843,750 using 200 simulations.
# The effective power of sample size n = 843,750 is 85.07%.
# Now assessing the value 703,125 within the range n = (562,500, 843,750), and power = (70.65%, 85.07%).
# Estimating the effective power of n = 703,125 using 200 simulations.
# The effective power of sample size n = 703,125 is 83.58%.
# Now assessing the value 632,812 within the range n = (562,500, 703,125), and power = (70.65%, 83.58%).
# Estimating the effective power of n = 632,812 using 200 simulations.
# The effective power of sample size n = 632,812 is 81.59%.
# Binary search commenced, centered on n = 295,345 informed by residual variance.
# Estimating the effective power of n = 295,345 using 200 simulations.
# The effective power of sample size n = 295,345 is 48.26%.
# Estimating the effective power of n = 2,953,450 using 200 simulations.
# The effective power of sample size n = 2,953,450 is 100%.
# Binary search suggested the region of n = (295,345, 2,953,450).
# Now assessing the value 1,624,397 within the range n = (295,345, 2,953,450), and power = (48.26%, 100%).
# Estimating the effective power of n = 1,624,397 using 200 simulations.
# The effective power of sample size n = 1,624,397 is 99.0%.
# Now assessing the value 959,871 within the range n = (295,345, 1,624,397), and power = (48.26%, 99.0%).
# Estimating the effective power of n = 959,871 using 200 simulations.
# The effective power of sample size n = 959,871 is 95.52%.
# Now assessing the value 627,608 within the range n = (295,345, 959,871), and power = (48.26%, 95.52%).
# Estimating the effective power of n = 627,608 using 200 simulations.
# The effective power of sample size n = 627,608 is 77.61%.
# Saved the results from sim_data_2020_01_04_142452.
# Saved the results from sim_data_2020_01_04_142452.
# Saved the results from sim_data_2020_01_04_142452.
# /home/bknight/Documents/Power_Analysis_Techniques/v3/data
# The file sim_data_2020_01_04_142452.csv was deleted.
# Assessment took 48 minutes and 6 seconds.
# 7 additional covariates will be created.
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v3/data/sim_data_2020_01_04_151258.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v3/data/log_files/sim_data_2020_01_04_151258_log_file.txt.
# 4500000 observations of simulation data created in 1 minutes and 45 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v3/data/sim_data_2020_01_04_151258.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v3/data/log_files/sim_data_2020_01_04_151258_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v3/data/log_files/sim_data_2020_01_04_151258_log_file.txt.
# ############## Starting value is n = 694,394.    ###########
# ############## Starting adj. R-squared is 0.33. ###########
# /home/bknight/Documents/Power_Analysis_Techniques/v3/data
# The file sim_data_2020_01_04_151258.csv was deleted.
# The the associated meta-data for file sim_data_2020_01_04_151258.csv was also deleted.
# Starting value too high.
# 5 additional covariates will be created.
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v3/data/sim_data_2020_01_04_151455.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v3/data/log_files/sim_data_2020_01_04_151455_log_file.txt.
# 4500000 observations of simulation data created in 1 minutes and 22 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v3/data/sim_data_2020_01_04_151455.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v3/data/log_files/sim_data_2020_01_04_151455_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v3/data/log_files/sim_data_2020_01_04_151455_log_file.txt.
# ############## Starting value is n = 847,432.    ###########
# ############## Starting adj. R-squared is 0.42. ###########
# /home/bknight/Documents/Power_Analysis_Techniques/v3/data
# The file sim_data_2020_01_04_151455.csv was deleted.
# The the associated meta-data for file sim_data_2020_01_04_151455.csv was also deleted.
# Starting value too high.
# 6 additional covariates will be created.
# Now performing OLS to infer DGP parameters.
# Simulation data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v3/data/sim_data_2020_01_04_151627.csv.
# Meta-data was saved to:
#      /home/bknight/Documents/Power_Analysis_Techniques/v3/data/log_files/sim_data_2020_01_04_151627_log_file.txt.
# 4500000 observations of simulation data created in 1 minutes and 34 seconds.
# Reconstituting data object from file.
# Successfully read in the .csv file specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v3/data/sim_data_2020_01_04_151627.csv.
# /home/bknight/Documents/Power_Analysis_Techniques/v3/data/log_files/sim_data_2020_01_04_151627_log_file.txt
# Successfully read in the meta-data specified at:
#      /home/bknight/Documents/Power_Analysis_Techniques/v3/data/log_files/sim_data_2020_01_04_151627_log_file.txt.
# ############## Starting value is n = 472,405.    ###########
# ############## Starting adj. R-squared is 0.8. ###########
# Estimating the effective power of n = 472,405 using 200 simulations.
# The effective power of sample size n = 472,405 is 41.29%.
# An upper-bound of n = 1,180,157 was specified.
# Estimating the effective power of n = 1,180,157 using 200 simulations.
# The effective power of sample size n = 1,180,157 is 78.11%.
# Binary search commenced, naively centered on n = 2,250,000.
# Estimating the effective power of n = 2,250,000 using 200 simulations.
# The effective power of sample size n = 2,250,000 is 99.0%.
# Binary search suggested the region of n = (0, 2,250,000).
# Now assessing the value 1,125,000 within the range n = (0, 2,250,000), and power = (0%, 99.0%).
# Estimating the effective power of n = 1,125,000 using 200 simulations.
# The effective power of sample size n = 1,125,000 is 79.6%.
# Binary search commenced, centered on n = 472,405 informed by residual variance.
# Estimating the effective power of n = 472,405 using 200 simulations.
# The effective power of sample size n = 472,405 is 39.3%.
# The proposed size of the sub-sample exceeded the size of the parent sample.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-6d86a550ec34> in <module>
#      39
#      40     informed_bst = bst.binary_search(pe_ob, informed = 1)
# ---> 41     n3, p3,  df3 = informed_bst.binary_search()
#      42
#      43     pe.save_results(df1, iso_ob)
#
# ~/Documents/Power_Analysis_Techniques/v3/olsEmpowered/binary_search.py in binary_search(self)
#     183
#     184     def binary_search(self):
# --> 185         preliminary_dict = self.preliminary_screen()
#     186         current_n, current_p, recursion_dict = self.binary_parent(preliminary_dict)
#     187         final_n, final_p, results = self.combine_dfs(current_n, current_p,
#
# ~/Documents/Power_Analysis_Techniques/v3/olsEmpowered/binary_search.py in preliminary_screen(self)
#      58
#      59         for i in [mid, ub]:
# ---> 60             power_est, sims, secs = self.assess_power(i, self.sims_per_point)
#      61             results.append(power_est)
#      62             candidates.append(i)
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
import pandas as pd
import os, os.path

files_found = len([name for name in os.listdir('./results/')])
print("{} files were found in total.".format(files_found))
print("{} iterations.".format(int(files_found/3)))
isotonic_results        = []
naive_binary_results    = []
informed_binary_results = []
[isotonic_results.append(name) for name in os.listdir('./results/') if "isotonic" in name]
[naive_binary_results.append(name) for name in os.listdir('./results/') if "naive_binary" in name]
[informed_binary_results.append(name) for name in os.listdir('./results/') if "informed_binary" in name]
isotonic_results.sort()
naive_binary_results.sort()
informed_binary_results.sort()


iso_sims, iso_time, iso_n = [], [], []
for i in isotonic_results:
    df = pd.read_csv('./results/' + i)
    df['delta'] = abs(df['power'] - 0.8)
    df.sort_values('delta',ascending=True, inplace=True)
    n = df.iat[0,0]
    iso_sims.append(df['sims_used'][0])
    iso_time.append(df['seconds_used'][0])
    iso_n.append(n)
   # print(df)
    
naive_sims, naive_time, naive_n = [], [], []
for j in naive_binary_results:
    df = pd.read_csv('./results/' + j)
    df['delta'] = abs(df['power'] - 0.8)
    df.sort_values('delta',ascending=True, inplace=True)
    n = df.iat[0,0]
    naive_sims.append(df['sims_used'][0])
    naive_time.append(df['seconds_used'][0])
    naive_n.append(n)
   # print(df)
    
informed_sims, informed_time, informed_n = [], [], []
for k in informed_binary_results:
    df = pd.read_csv('./results/' + k)
    df['delta'] = abs(df['power'] - 0.8)
    df.sort_values('delta',ascending=True, inplace=True)
    n = df.iat[0,0]
    informed_sims.append(df['sims_used'][0])
    informed_time.append(df['seconds_used'][0])
    informed_n.append(n)
#     print(df)
# Out:
# 195 files were found in total.
# 65 iterations.

# %%
results_df = pd.DataFrame([iso_sims, iso_time, iso_n, 
                           naive_sims, naive_time, naive_n, 
                           informed_sims, informed_time, informed_n]).T
results_df.columns = ['iso_sims', 'iso_time', 'iso_n', 
                      'naive_sims', 'naive_time', 'naive_n', 
                      'informed_sims', 'informed_time', 'informed_n']
results_df.sort_values(by=['iso_n'], ascending=False)
# Out:
#     iso_sims    iso_time      iso_n  naive_sims   naive_time    naive_n  \
# 41     800.0  813.738768  1791028.0      1800.0  2013.753572  1669921.0
# 60     400.0  411.253572  1124377.0      1800.0  3411.946473  1283203.0
# 28     400.0  140.342840  1103751.0       600.0   402.861768  1125000.0
# 30     800.0  600.951839  1015499.0      1200.0  1366.980700   984375.0
# 61     600.0  457.698042   990042.0      1800.0  1734.993533  1001953.0
# ..       ...         ...        ...         ...          ...        ...
# 13     400.0   97.230166    18587.0      2400.0  1830.601297    19775.0
# 8     1000.0  212.575674    14468.0      2800.0   937.964401    12633.0
# 5      400.0   77.256223     9864.0      2400.0  2102.916926    10986.0
# 11     600.0  133.000199     9366.0      2800.0  1616.195602     9338.0
# 4      400.0   89.310615     6672.0      2400.0   728.309509     6591.0
#
#     informed_sims  informed_time  informed_n
# 41         1800.0    2312.154966   1745263.0
# 60         1800.0    4025.489231   1256677.0
# 28         2200.0    1119.934264   1054259.0
# 30         1200.0    1586.028987    994366.0
# 61         2600.0    3244.771182    943037.0
# ..            ...            ...         ...
# 13         1600.0     369.331944     21274.0
# 8          2200.0     481.100864     13741.0
# 5          1800.0     395.393849      9073.0
# 11         1800.0     417.401222      9653.0
# 4          1600.0     294.846578      8129.0
#
# [65 rows x 9 columns]

# %%
subset = results_df[ (results_df['iso_n'] <= 1000000)
                   & (results_df['informed_n'] <= 1000000)
                   & (results_df['naive_n'] <= 1000000)]
subset.describe()
# Out:
#           iso_sims     iso_time          iso_n   naive_sims   naive_time  \
# count    60.000000    60.000000      60.000000    60.000000    60.000000
# mean    753.333333   273.384412  308762.050000  1683.333333  1290.992191
# std     425.248349   242.310133  275596.510154   493.059170   519.227983
# min     400.000000    75.617206    6672.000000  1000.000000   404.704021
# 25%     400.000000   118.325400   62916.000000  1200.000000   887.731555
# 50%     600.000000   185.769915  255310.500000  1600.000000  1230.110099
# 75%    1000.000000   328.362715  480110.750000  2000.000000  1685.329577
# max    2200.000000  1352.286171  966726.000000  3000.000000  2452.588519
#
#              naive_n  informed_sims  informed_time     informed_n
# count      60.000000      60.000000      60.000000      60.000000
# mean   301029.566667    1706.666667     890.277713  306410.166667
# std    269606.927569     317.760525     637.690464  270256.409055
# min      6591.000000    1200.000000     278.669772    8129.000000
# 25%     65367.750000    1400.000000     466.160192   65623.250000
# 50%    237304.000000    1600.000000     679.257010  242256.000000
# 75%    430664.000000    1800.000000    1074.216816  476651.000000
# max    984375.000000    2600.000000    3300.991722  978115.000000

# %%
import seaborn as sns
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure


fig, ax = plt.subplots()
fig.set_size_inches(12, 4.8, forward=True)



x1 = subset['iso_n']
y1 = subset['iso_time']


x2 = subset['informed_n']
y2 = subset['informed_time']

x3 = subset['naive_n'] 
y3 = subset['naive_time']

sns.regplot(x1, y1, lowess=True, 
            color = '#b300b3', 
            marker='o', scatter_kws={'s':10})
sns.regplot(x2, y2, lowess=True, 
            color = '#006600', 
            marker='o', scatter_kws={'s':10})
sns.regplot(x3, y3, lowess=True, 
            color = '#3333cc', 
            marker='o', scatter_kws={'s':10})

labels = [
         'Isotonic Interpolation', 
         'Informed Binary Search', 
         'Naive Binary Search'
         ]
plt.legend(labels, prop={'size': 14})
plt.ylabel('Estimation \nTime \nin \nSeconds', size = 18).set_rotation(0)
plt.xlabel('Estimated Sample Size Required', size = 18)
plt.xlim(0,1000000)

ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,}'.format(int(x))))

ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,}'.format(int(x))))

ax.tick_params(axis='both', which='major', labelsize=16)
ax.yaxis.set_label_coords(-0.16,0.35)

plt.show()
# plt.savefig('v1.png',bbox_inches='tight')
plt.clf()
